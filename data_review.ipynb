# %%
import pandas as pd
import numpy as np
import boto3
import cv2 as cv
import os
import json
from config import key_, secret_, s3_bucket, kaggle_cookie

# %%
def download_video_from_s3_bucket(video_name, aws_key=key_, aws_secret=secret_, bucket=s3_bucket):
    '''
    ##Intended for use when not using Sagemaker##
    takes a video name as input, and returns the frame count, and the shape of the first frame of the video
    '''
    s3 = boto3.client('s3',
                      aws_access_key_id=key_, 
                      aws_secret_access_key=secret_,
                      region_name='us-east-2', #region is hardcoded - this is not a security risk to keep public
                      config= boto3.session.Config(signature_version='s3v4')) #the sig version needs to be s3v4 or the url will error
    video_url = s3.generate_presigned_url('get_object',
                                        Params={"Bucket": bucket,
                                               'Key': video_name},
                                        ExpiresIn=60)
    video = cv.VideoCapture(video_url)
    frame_count = int(video.get(cv.CAP_PROP_FRAME_COUNT))
    _, frame_array = video.read()
    frame_x, frame_y, RGB = frame_array.shape
    video.release()
    return video_name, frame_count, frame_x, frame_y, RGB

# %%
with open('meta.json') as m:
    meta = json.load(m)

# %%
video_names = []
frame_counts = []
x_shapes = []
y_shapes = []
RGB_shapes = []

# %%
for video in meta:
    try:
        video_, frames, x_frames, y_frames, RGB = download_video_from_s3_bucket(video)
    except:
        video_, frames, x_frames, y_frames, RGB = video, 0, 0, 0, 0
    video_names.append(video_)
    frame_counts.append(frames)
    x_shapes.append(x_frames)
    y_shapes.append(y_frames)
    RGB_shapes.append(RGB)

# %%
video_information_dictionary = {'video_names': video_names, 'number_of_frames': frame_counts, 
                               'number_of_x_pixels': x_shapes, 'number_of_y_pixels': y_shapes,
                               'RGB': RGB_shapes}

# %%
video_info_df = pd.DataFrame(video_information_dictionary)

# %%
video_info_df.to_csv('video_information.csv')

# %%
s3 = boto3.client('s3', aws_access_key_id=key_, aws_secret_access_key=secret_)

# %%
s3.upload_file('video_information.csv', s3_bucket, 'video_information.csv')

# %%
#read above CSV file 
video_info_df = pd.read_csv('video_information.csv')

# %%
video_info_df.head(1)
# Out:
#       video_names  number_of_frames  number_of_x_pixels  number_of_y_pixels  \
# 0  owxbbpjpch.mp4               300                1920                1080
#
#    RGB  total_pixels  pixels_by_frames
# 0    3       2073600         622080000

# %%
#create column for frame size in number of pixels
video_info_df['total_pixels'] = video_info_df['number_of_x_pixels'] * video_info_df['number_of_y_pixels']

#create column for total number of pixels when accounting for the number of frames
#this should help in calculating memory usage
video_info_df['pixels_by_frames'] = video_info_df['total_pixels'] * video_info_df['number_of_frames']

# %%
#drop index column from when the DF was previously saved as a csv file
# video_info_df = video_info_df.drop(columns=['Unnamed: 0'])

# %%
#preview DF
video_info_df.head()
# Out:
#       video_names  number_of_frames  number_of_x_pixels  number_of_y_pixels  \
# 0  owxbbpjpch.mp4               300                1920                1080
# 1  vpmyeepbep.mp4               300                1920                1080
# 2  fzvpbrzssi.mp4               300                1920                1080
# 3  htorvhbcae.mp4               300                1920                1080
# 4  fckxaqjbxk.mp4               300                1920                1080
#
#    RGB  total_pixels  pixels_by_frames
# 0    3       2073600         622080000
# 1    3       2073600         622080000
# 2    3       2073600         622080000
# 3    3       2073600         622080000
# 4    3       2073600         622080000

# %%
#find minimum value of total_pixels column
video_info_df['total_pixels'].min()
#the '0' value means there are some missing videos in the bucket
# Out:
# 76800

# %%
#create new DF with only 0 frames (the number_of_frames column is 0)
missing_videos_df = video_info_df[video_info_df['number_of_frames'] == 0]
#convert the video_name column in above DF to a list
missing_videos = missing_videos_df['video_names'].tolist()
print(f'there are {len(missing_videos)} videos potentially missing from bucket')
# Out:
# there are 0 videos potentially missing from bucket

# %%
#make additional attempt to obtain info from each video
for video in missing_videos:
    try:
        video_, frames, x_frames, y_frames, RGB = download_video_from_s3_bucket(video)
        print(f'{video} is in the S3 bucket')
    except:
        print(f'{video} is not in the S3 bucket')

# %%
#remove missing videos from df
video_info_df = video_info_df[video_info_df['number_of_frames'] != 0]

# %%
#find longest videos (by number of frames)
video_info_df[video_info_df['number_of_frames'] == video_info_df['number_of_frames'].max()]
# Out:
#           video_names  number_of_frames  number_of_x_pixels  \
# 54984  qanpwofprw.mp4               601                1920
# 54986  vninpbciju.mp4               601                1920
# 54990  xujbhvdrlx.mp4               601                1920
# 54993  kxxmijtqwn.mp4               601                1920
# 54997  pgvxcsjbts.mp4               601                1920
# 54999  nbyhqpaumb.mp4               601                1920
# 55000  ucuckkkwiz.mp4               601                1920
# 55009  tdytyxyttv.mp4               601                1920
# 55010  cyxdgyisae.mp4               601                1920
# 55017  emocjwfcqr.mp4               601                1920
# 55018  wscurxsmqd.mp4               601                1920
# 55019  ejdshfsqoh.mp4               601                1920
# 55021  staqnjvhzm.mp4               601                1920
# 55024  egymkdavul.mp4               601                1920
# 55025  vupkntqxrs.mp4               601                1920
# 55027  ggidelgrej.mp4               601                1920
# 55028  ivgotbhcdh.mp4               601                1920
# 55032  zstuohlfgc.mp4               601                1920
# 55033  ibfcxpsvaf.mp4               601                1920
# 55035  nrjsflekkm.mp4               601                1920
#
#        number_of_y_pixels  RGB  total_pixels  pixels_by_frames
# 54984                1080    3       2073600        1246233600
# 54986                1080    3       2073600        1246233600
# 54990                1080    3       2073600        1246233600
# 54993                1080    3       2073600        1246233600
# 54997                1080    3       2073600        1246233600
# 54999                1080    3       2073600        1246233600
# 55000                1080    3       2073600        1246233600
# 55009                1080    3       2073600        1246233600
# 55010                1080    3       2073600        1246233600
# 55017                1080    3       2073600        1246233600
# 55018                1080    3       2073600        1246233600
# 55019                1080    3       2073600        1246233600
# 55021                1080    3       2073600        1246233600
# 55024                1080    3       2073600        1246233600
# 55025                1080    3       2073600        1246233600
# 55027                1080    3       2073600        1246233600
# 55028                1080    3       2073600        1246233600
# 55032                1080    3       2073600        1246233600
# 55033                1080    3       2073600        1246233600
# 55035                1080    3       2073600        1246233600

# %%
#find videos with largest number of pixels
video_info_df[video_info_df['pixels_by_frames'] == video_info_df['pixels_by_frames'].max()]
#it would take approximately 6.7 GB to store one of the below videos in an array
#this is reduced to ~1.11 GB with inproved download_video_from_s3_bucket function that doesnt store all frames
# Out:
#           video_names  number_of_frames  number_of_x_pixels  \
# 85682  ldbldpvjab.mp4               269                3840
# 85686  qchgluoajg.mp4               269                3840
# 85687  pydicxfaui.mp4               269                3840
# 85689  ceoyuhoxof.mp4               269                3840
# 85690  wktdezchfx.mp4               269                3840
# 85692  zsqjihgilv.mp4               269                3840
# 85693  dsxvketzmt.mp4               269                3840
# 85695  wkjhpzukba.mp4               269                3840
# 85696  zcpdiajsfj.mp4               269                3840
# 85697  cngogfretb.mp4               269                3840
# 85699  alrjjpkdwb.mp4               269                3840
# 85704  itymdrkyyf.mp4               269                3840
# 85705  esiyzsjmfq.mp4               269                3840
# 85708  eqpeiboklv.mp4               269                3840
# 85713  jovlorawmz.mp4               269                3840
# 85714  unbshgwprn.mp4               269                3840
# 85715  wncdvjwyaf.mp4               269                3840
# 85722  exsteszbhp.mp4               269                3840
# 85723  ldwgfsxbty.mp4               269                3840
# 85726  csrqbscgxz.mp4               269                3840
# 85731  qjcsboclei.mp4               269                3840
# 85738  vaodijuuyp.mp4               269                3840
# 85739  ktnjhftfpo.mp4               269                3840
# 85744  nmarhxamlz.mp4               269                3840
# 85747  vnqbgrywgs.mp4               269                3840
# 85751  iyiojarsht.mp4               269                3840
# 85752  nxbqzrfgtj.mp4               269                3840
# 85754  kcqlyaqejj.mp4               269                3840
# 85755  ioafctqohg.mp4               269                3840
# 85757  qictduddwj.mp4               269                3840
# 85760  uctzrohtlt.mp4               269                3840
# 85763  hydytyakzr.mp4               269                3840
# 85770  ckbdjpflsu.mp4               269                3840
# 85772  trxunwqklo.mp4               269                3840
# 85776  ypxqtsvhyj.mp4               269                3840
#
#        number_of_y_pixels  RGB  total_pixels  pixels_by_frames
# 85682                2160    3       8294400        2231193600
# 85686                2160    3       8294400        2231193600
# 85687                2160    3       8294400        2231193600
# 85689                2160    3       8294400        2231193600
# 85690                2160    3       8294400        2231193600
# 85692                2160    3       8294400        2231193600
# 85693                2160    3       8294400        2231193600
# 85695                2160    3       8294400        2231193600
# 85696                2160    3       8294400        2231193600
# 85697                2160    3       8294400        2231193600
# 85699                2160    3       8294400        2231193600
# 85704                2160    3       8294400        2231193600
# 85705                2160    3       8294400        2231193600
# 85708                2160    3       8294400        2231193600
# 85713                2160    3       8294400        2231193600
# 85714                2160    3       8294400        2231193600
# 85715                2160    3       8294400        2231193600
# 85722                2160    3       8294400        2231193600
# 85723                2160    3       8294400        2231193600
# 85726                2160    3       8294400        2231193600
# 85731                2160    3       8294400        2231193600
# 85738                2160    3       8294400        2231193600
# 85739                2160    3       8294400        2231193600
# 85744                2160    3       8294400        2231193600
# 85747                2160    3       8294400        2231193600
# 85751                2160    3       8294400        2231193600
# 85752                2160    3       8294400        2231193600
# 85754                2160    3       8294400        2231193600
# 85755                2160    3       8294400        2231193600
# 85757                2160    3       8294400        2231193600
# 85760                2160    3       8294400        2231193600
# 85763                2160    3       8294400        2231193600
# 85770                2160    3       8294400        2231193600
# 85772                2160    3       8294400        2231193600
# 85776                2160    3       8294400        2231193600

# %%
#save updated DF as a CSV file
video_info_df.to_csv('video_information.csv', index=False)

# %%
#upload updated CSV file to S3 bucket
s3.upload_file('video_information.csv', s3_bucket, 'video_information.csv')

# %%
video_info_df[video_info_df['number_of_y_pixels'] == video_info_df['number_of_y_pixels'].min()]
# Out:
#            video_names  number_of_frames  number_of_x_pixels  \
# 45439   upntjwlcjh.mp4               301                 320
# 45440   sqmsmxhbaz.mp4               299                 320
# 45441   fivlogttny.mp4               301                 320
# 45442   hodrszynaa.mp4               301                 320
# 45443   hfjczthrqm.mp4               301                 320
# 45444   kdwsdpqhna.mp4               301                 320
# 45445   zmrdtdwdct.mp4               301                 320
# 45446   gilvyncglg.mp4               301                 320
# 45447   gcclmpcwyr.mp4               301                 320
# 45448   jiwwwkcyln.mp4               301                 320
# 45449   yoqlikjhqk.mp4               301                 320
# 45450   yysdbhsuwk.mp4               301                 320
# 45451   hicmrdeajp.mp4               301                 320
# 45452   vtgitjlexc.mp4               301                 320
# 45453   efdkxeccdb.mp4               301                 320
# 45454   ipnolrawqj.mp4               301                 320
# 45455   vamkopxvtj.mp4               301                 320
# 45456   ppmxmsjbbx.mp4               301                 320
# 45457   howqmjjpoz.mp4               301                 320
# 45458   gtcqcdmdtb.mp4               301                 320
# 45459   rvdetsdslx.mp4               301                 320
# 45460   uixnzwqwpz.mp4               301                 320
# 45461   watimdiuxs.mp4               299                 320
# 45462   dysjipkwuz.mp4               301                 320
# 45463   cwbwhsjrbz.mp4               301                 320
# 45464   dzmiebgfrr.mp4               301                 320
# 45465   jnjszosdox.mp4               299                 320
# 45466   ojssrtnase.mp4               301                 320
# 45467   fpmacwpaqr.mp4               301                 320
# 45468   ietunqyaar.mp4               301                 320
# ...                ...               ...                 ...
# 103900  wlixzmuzyi.mp4               300                 320
# 103901  mrfyaengfi.mp4               300                 320
# 103902  etagpnouis.mp4               300                 320
# 103903  whsdrgnrew.mp4               300                 320
# 103904  kwqhorfuuv.mp4               300                 320
# 103905  stkqpavaxn.mp4               300                 320
# 103906  lxueluejmz.mp4               300                 320
# 103907  lvswcztxap.mp4               300                 320
# 103908  jgdexanjjk.mp4               300                 320
# 103909  lrdziwxgql.mp4               300                 320
# 103910  khvjnymdxa.mp4               300                 320
# 103911  ngadlpokyf.mp4               300                 320
# 103912  knlpfccddv.mp4               300                 320
# 103913  zjulgvcxed.mp4               300                 320
# 103914  iksntpazti.mp4               300                 320
# 103915  fakquybnpz.mp4               300                 320
# 103916  rifiyadulj.mp4               300                 320
# 103917  ltnlxegeko.mp4               300                 320
# 103918  bwxcxqmuyo.mp4               300                 320
# 103919  rpojlagpxg.mp4               300                 320
# 103920  vkkmleainv.mp4               300                 320
# 103921  znkeatsnov.mp4               300                 320
# 103922  wxenkxwymo.mp4               300                 320
# 103923  xkspwcmsid.mp4               300                 320
# 103924  afcwvndury.mp4               300                 320
# 103925  ccjdqupbqr.mp4               300                 320
# 103926  yqejcaobin.mp4               300                 320
# 103927  uvyvbfhchf.mp4               300                 320
# 103928  zqlyovqwda.mp4               300                 320
# 103929  axkbdkcony.mp4               300                 320
#
#         number_of_y_pixels  RGB  total_pixels  pixels_by_frames
# 45439                  240    3         76800          23116800
# 45440                  240    3         76800          22963200
# 45441                  240    3         76800          23116800
# 45442                  240    3         76800          23116800
# 45443                  240    3         76800          23116800
# 45444                  240    3         76800          23116800
# 45445                  240    3         76800          23116800
# 45446                  240    3         76800          23116800
# 45447                  240    3         76800          23116800
# 45448                  240    3         76800          23116800
# 45449                  240    3         76800          23116800
# 45450                  240    3         76800          23116800
# 45451                  240    3         76800          23116800
# 45452                  240    3         76800          23116800
# 45453                  240    3         76800          23116800
# 45454                  240    3         76800          23116800
# 45455                  240    3         76800          23116800
# 45456                  240    3         76800          23116800
# 45457                  240    3         76800          23116800
# 45458                  240    3         76800          23116800
# 45459                  240    3         76800          23116800
# 45460                  240    3         76800          23116800
# 45461                  240    3         76800          22963200
# 45462                  240    3         76800          23116800
# 45463                  240    3         76800          23116800
# 45464                  240    3         76800          23116800
# 45465                  240    3         76800          22963200
# 45466                  240    3         76800          23116800
# 45467                  240    3         76800          23116800
# 45468                  240    3         76800          23116800
# ...                    ...  ...           ...               ...
# 103900                 240    3         76800          23040000
# 103901                 240    3         76800          23040000
# 103902                 240    3         76800          23040000
# 103903                 240    3         76800          23040000
# 103904                 240    3         76800          23040000
# 103905                 240    3         76800          23040000
# 103906                 240    3         76800          23040000
# 103907                 240    3         76800          23040000
# 103908                 240    3         76800          23040000
# 103909                 240    3         76800          23040000
# 103910                 240    3         76800          23040000
# 103911                 240    3         76800          23040000
# 103912                 240    3         76800          23040000
# 103913                 240    3         76800          23040000
# 103914                 240    3         76800          23040000
# 103915                 240    3         76800          23040000
# 103916                 240    3         76800          23040000
# 103917                 240    3         76800          23040000
# 103918                 240    3         76800          23040000
# 103919                 240    3         76800          23040000
# 103920                 240    3         76800          23040000
# 103921                 240    3         76800          23040000
# 103922                 240    3         76800          23040000
# 103923                 240    3         76800          23040000
# 103924                 240    3         76800          23040000
# 103925                 240    3         76800          23040000
# 103926                 240    3         76800          23040000
# 103927                 240    3         76800          23040000
# 103928                 240    3         76800          23040000
# 103929                 240    3         76800          23040000
#
# [601 rows x 7 columns]

# %%
video_info_df[video_info_df['total_pixels'] == video_info_df['total_pixels'].max()]
# Out:
#           video_names  number_of_frames  number_of_x_pixels  \
# 85680  ojlxhospsm.mp4               242                3840
# 85681  jekyhkswtp.mp4               193                3840
# 85682  ldbldpvjab.mp4               269                3840
# 85683  kfqvqklplx.mp4               242                3840
# 85684  zowiiqindc.mp4               242                3840
# 85686  qchgluoajg.mp4               269                3840
# 85687  pydicxfaui.mp4               269                3840
# 85688  znxooikpiq.mp4               193                3840
# 85689  ceoyuhoxof.mp4               269                3840
# 85690  wktdezchfx.mp4               269                3840
# 85691  sjocionvvn.mp4               193                3840
# 85692  zsqjihgilv.mp4               269                3840
# 85693  dsxvketzmt.mp4               269                3840
# 85695  wkjhpzukba.mp4               269                3840
# 85696  zcpdiajsfj.mp4               269                3840
# 85697  cngogfretb.mp4               269                3840
# 85699  alrjjpkdwb.mp4               269                3840
# 85700  oefzonhfga.mp4               193                3840
# 85701  gltpndcohp.mp4               242                3840
# 85702  owlkhaplbc.mp4               193                3840
# 85704  itymdrkyyf.mp4               269                3840
# 85705  esiyzsjmfq.mp4               269                3840
# 85708  eqpeiboklv.mp4               269                3840
# 85712  bjlwgiuuxv.mp4               242                3840
# 85713  jovlorawmz.mp4               269                3840
# 85714  unbshgwprn.mp4               269                3840
# 85715  wncdvjwyaf.mp4               269                3840
# 85716  pigsuchqbh.mp4               242                3840
# 85717  dqsjrwfcim.mp4               242                3840
# 85718  tjkxdsvhtn.mp4               193                3840
# ...               ...               ...                 ...
# 85736  xfchpjbfby.mp4               193                3840
# 85738  vaodijuuyp.mp4               269                3840
# 85739  ktnjhftfpo.mp4               269                3840
# 85740  fjubmqudgd.mp4               193                3840
# 85741  hccujersgb.mp4               242                3840
# 85742  tnmuokilgt.mp4               242                3840
# 85743  hccoyhfnsf.mp4               242                3840
# 85744  nmarhxamlz.mp4               269                3840
# 85746  vslzefizav.mp4               193                3840
# 85747  vnqbgrywgs.mp4               269                3840
# 85748  fyygtwpvcc.mp4               242                3840
# 85751  iyiojarsht.mp4               269                3840
# 85752  nxbqzrfgtj.mp4               269                3840
# 85754  kcqlyaqejj.mp4               269                3840
# 85755  ioafctqohg.mp4               269                3840
# 85757  qictduddwj.mp4               269                3840
# 85758  abvpqidzxi.mp4               242                3840
# 85760  uctzrohtlt.mp4               269                3840
# 85761  wxfbrkllqs.mp4               242                3840
# 85762  hrpdutntqq.mp4               242                3840
# 85763  hydytyakzr.mp4               269                3840
# 85765  nvhosphkdk.mp4               242                3840
# 85766  dilfumvxqx.mp4               193                3840
# 85769  zpaopdvzho.mp4               193                3840
# 85770  ckbdjpflsu.mp4               269                3840
# 85771  ylznlnmfeu.mp4               193                3840
# 85772  trxunwqklo.mp4               269                3840
# 85774  lhrdeqnnqh.mp4               242                3840
# 85776  ypxqtsvhyj.mp4               269                3840
# 85777  roqkadbbap.mp4               193                3840
#
#        number_of_y_pixels  RGB  total_pixels  pixels_by_frames
# 85680                2160    3       8294400        2007244800
# 85681                2160    3       8294400        1600819200
# 85682                2160    3       8294400        2231193600
# 85683                2160    3       8294400        2007244800
# 85684                2160    3       8294400        2007244800
# 85686                2160    3       8294400        2231193600
# 85687                2160    3       8294400        2231193600
# 85688                2160    3       8294400        1600819200
# 85689                2160    3       8294400        2231193600
# 85690                2160    3       8294400        2231193600
# 85691                2160    3       8294400        1600819200
# 85692                2160    3       8294400        2231193600
# 85693                2160    3       8294400        2231193600
# 85695                2160    3       8294400        2231193600
# 85696                2160    3       8294400        2231193600
# 85697                2160    3       8294400        2231193600
# 85699                2160    3       8294400        2231193600
# 85700                2160    3       8294400        1600819200
# 85701                2160    3       8294400        2007244800
# 85702                2160    3       8294400        1600819200
# 85704                2160    3       8294400        2231193600
# 85705                2160    3       8294400        2231193600
# 85708                2160    3       8294400        2231193600
# 85712                2160    3       8294400        2007244800
# 85713                2160    3       8294400        2231193600
# 85714                2160    3       8294400        2231193600
# 85715                2160    3       8294400        2231193600
# 85716                2160    3       8294400        2007244800
# 85717                2160    3       8294400        2007244800
# 85718                2160    3       8294400        1600819200
# ...                   ...  ...           ...               ...
# 85736                2160    3       8294400        1600819200
# 85738                2160    3       8294400        2231193600
# 85739                2160    3       8294400        2231193600
# 85740                2160    3       8294400        1600819200
# 85741                2160    3       8294400        2007244800
# 85742                2160    3       8294400        2007244800
# 85743                2160    3       8294400        2007244800
# 85744                2160    3       8294400        2231193600
# 85746                2160    3       8294400        1600819200
# 85747                2160    3       8294400        2231193600
# 85748                2160    3       8294400        2007244800
# 85751                2160    3       8294400        2231193600
# 85752                2160    3       8294400        2231193600
# 85754                2160    3       8294400        2231193600
# 85755                2160    3       8294400        2231193600
# 85757                2160    3       8294400        2231193600
# 85758                2160    3       8294400        2007244800
# 85760                2160    3       8294400        2231193600
# 85761                2160    3       8294400        2007244800
# 85762                2160    3       8294400        2007244800
# 85763                2160    3       8294400        2231193600
# 85765                2160    3       8294400        2007244800
# 85766                2160    3       8294400        1600819200
# 85769                2160    3       8294400        1600819200
# 85770                2160    3       8294400        2231193600
# 85771                2160    3       8294400        1600819200
# 85772                2160    3       8294400        2231193600
# 85774                2160    3       8294400        2007244800
# 85776                2160    3       8294400        2231193600
# 85777                2160    3       8294400        1600819200
#
# [75 rows x 7 columns]
