# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.cloud import storage
from google.oauth2 import service_account
import os

# %%
from google.cloud import storage
try:
    from google.colab import auth
    auth.authenticate_user()
    credentials=None
except ModuleNotFoundError:

    credentials = service_account.Credentials.from_service_account_file( #file location of GCS private key
        '/Users/jeremiahherberg/Downloads/deepfake-research-a6b5e4f02da6.json')

# %%
client = storage.Client(project='deepfake-research', credentials=credentials)
video_frame_bucket_name = 'deepfake-dataset'
#bucket containing test data
video_frame_bucket = client.bucket(video_frame_bucket_name)
model_bucket_name = 'jh-gan-testing'
#bucket containing model
model_bucket = client.bucket(model_bucket_name)

# %%
#download and load model
model_name =  'disc5_epoch410.h5' #
model_blob = model_bucket.blob(model_name)
model_blob.download_to_filename(model_name)
model = tf.keras.models.load_model(model_name)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
def make_single_prediction(frame,
                          frame_shape=(225, 146, 3),
                          model_input_shape=(192, 128, 3),
                          model=model):
    '''
    function to make a prediction if a single frame in test dataset is real or not
    
    inputs:
        frame - array with a shape of (frame_shape[0] * frame_shape[1] * frame_shape[2],)
        
        frame_shape - tuple that describes the shape of the image, defaults to (225, 146, 3)
        the last dim must be 3 (RGB)
        
        model_input_shape - tuple that describes the shape of the input that will be passed into model
        defaults to (192, 128, 3), the last dim must be 3 (RGB)
        
        model - tensorflow model that will be used to make prediction, defaults to 'model'
    returns:
        prediction - Bool, True if model predicts frame is real, False if prediction is frame is fake
        raw_prediction - float, range of -inf to inf, negative number indicates prediction is that 
        frame is fake and positive indicates the prediction is the frame is real
        the closer to 0 the raw_prediction, the less confident the model is
    ''' 
    assert(frame_shape[2] == model_input_shape[2] == 3), 'the last dim must equal 3 in the model and frame shapes'
    frame_reshaped = frame.reshape(frame_shape)
    #resize frame to be compatable with model
    frame_resized = tf.image.resize_with_pad(frame_reshaped, model_input_shape[0], model_input_shape[1])
    # (H, W, RGB) -> (1, H, W, RGB)
    frame_expanded = tf.expand_dims(frame_resized, 0)
    #convert values to between -1 and 1 (0 to 255 -> -1 to 1) (this is how the model was trained)
    frame_expanded = (tf.cast(frame_expanded, tf.float32) - 127.5) / 127.5
    #we are only making a single prediction
    raw_prediction = model.predict(frame_expanded)[0][0]
    
    if raw_prediction > 0:
        prediction = True
    else:
        prediction = False
    
    return prediction, raw_prediction

# %%
def prediction_batch(idx,
                    bucket=video_frame_bucket,
                    test_ds_file_name='face_arrays',
                    ground_file_name='labels_and_video_names'):
    '''
    function to make a batch of predictions 
    test dataset is split up into 5 files
    
    inputs:
        idx - int with a value between 1 to 5 that represents which test ds file is being used for predictions
        
        bucket - GCS bucket variable that contains files with test data, default is video_frame_bucket
        
        test_ds_file_name - str - beginning of file name of files containing test ds, default is face_arrays
        
        ground_file_name - str - beginning of file name of files containing the ground truth of each frame 
    
    returns:
        correct_real - int - the number of real frames correctly predicted
        
        total_real - int - total number of real frames
        
        correct_fake - int - the number of fake frames correctly predicted
        
        total_fake - int - total number of fake frames
        
        prediction_df - DataFrame  with the following columns:
            raw_prediction - float, range of -inf to inf, negative number indicates prediction
            is frame is fake and postive indicates the prediction is frame is real
            the closer to 0 of the value, the less confident the model is regarding the prediction
            
            accurate - Bool - reflects if the model accurately predicted if the frame is real or fake
            
            ground_truth - Bool - reflects if the frame is real or fake

    '''
    #downlaod files:
    ds_file_name = '{}{}.npz'.format(test_ds_file_name, idx)
    ground_file_name = '{}{}.csv'.format(ground_file_name, idx)
    ds_blob = bucket.blob('aaa_frames/' + ds_file_name)
    ds_blob.download_to_filename(ds_file_name)
    ground_blob = bucket.blob('aaa_frames/' + ground_file_name)
    ground_blob.download_to_filename(ground_file_name)
    
    data_file = np.load(ds_file_name)
    data = [data_file[key] for key in data_file]
    ground = pd.read_csv(ground_file_name)
    ground_list = ground['face_labels'].to_list()
    assert(len(ground_list) == len(data)), 'The len of the DS and ground truth do not match'
    
    total_real, total_fake, correct_real, correct_fake = 0, 0, 0, 0
    predictions = []
    ground_truths = []
    accurate_predictions = []
    
    for frame in range(len(data)):
        prediction, raw_prediction = make_single_prediction(data[frame])
        real = ground_list[frame]
        accurate_prediction = (real == prediction)
        if real:
            total_real +=1
            if accurate_prediction:
                correct_real +=1
        else:
            total_fake +=1
            if accurate_prediction: 
                correct_fake +=1
        predictions.append(raw_prediction)
        ground_truths.append(real)
        accurate_predictions.append(accurate_prediction)
        if frame % 1000 == 999:
          print('real frames:')
          print('accurate: {}, total: {}'.format(correct_real, total_real))
          print('fake frames:')
          print('accurate: {}, total: {} '.format(correct_fake, total_fake))
    
    
    preds_dictionary = {
        'raw_prediction':predictions,
        'accurate': accurate_predictions,
        'ground_truth': ground_truths
    }
    prediction_df = pd.DataFrame(preds_dictionary)
        
    return correct_real, total_real, correct_fake, total_fake, prediction_df

# %%
def make_predictions(start, end):
    '''
    function to make predictions on entire dataset
    
    inputs:
        start - int, starting file number in test dataset
        
        end - int, ending file number in test dataset, must be greater than or equal to start
        
    returns:
    correct_real - int - the number of real frames correctly predicted

    total_real - int - total number of real frames

    correct_fake - int - the number of fake frames correctly predicted

    total_fake - int - total number of fake frames

    prediction_df - DataFrame  with the following columns:
        raw_prediction - float, range of -inf to inf, negative number indicates prediction
        is frame is fake and postive indicates the prediction is frame is real
        the closer to 0 of the value, the less confident the model is regarding the prediction

        accurate - Bool - reflects if the model accurately predicted if the frame is real or fake

        ground_truth - Bool - reflects if the frame is real or fake
    '''
    
    assert(start <= end), 'start must be less than or equal to end'
    
    total_real, total_fake, correct_real, correct_fake = 0, 0, 0, 0
    prediction_dfs = []
    for file in np.arange(start, end+1):
        cor_real_batch, real_batch, cor_fake_batch, fake_batch, df_batch = prediction_batch(file)
        total_real += real_batch
        total_fake += fake_batch
        correct_real +=cor_real_batch
        correct_fake += cor_fake_batch
        prediction_dfs.append(df_batch)
    
    prediction_df = pd.concat(prediction_dfs)
    
    return total_real, total_fake, correct_real, correct_fake, prediction_df

# %%
with tf.device('/device:GPU:0'):
    total_real, total_fake, correct_real, correct_fake, prediction_df = make_predictions(1, 5)
# Out:
# real frames:
# accurate: 47, total: 52
# fake frames:
# accurate: 68, total: 948
# real frames:
# accurate: 118, total: 127
# fake frames:
# accurate: 131, total: 1873
# real frames:
# accurate: 196, total: 206
# fake frames:
# accurate: 218, total: 2794
# real frames:
# accurate: 271, total: 281
# fake frames:
# accurate: 324, total: 3719
# real frames:
# accurate: 320, total: 333
# fake frames:
# accurate: 428, total: 4667
# real frames:
# accurate: 358, total: 373
# fake frames:
# accurate: 528, total: 5627
# real frames:
# accurate: 420, total: 443
# fake frames:
# accurate: 630, total: 6557
# real frames:
# accurate: 484, total: 513
# fake frames:
# accurate: 741, total: 7487
# real frames:
# accurate: 542, total: 579
# fake frames:
# accurate: 862, total: 8421
# real frames:
# accurate: 619, total: 674
# fake frames:
# accurate: 984, total: 9326
# real frames:
# accurate: 844, total: 946
# fake frames:
# accurate: 1053, total: 10054
# real frames:
# accurate: 921, total: 1024
# fake frames:
# accurate: 1081, total: 10976
# real frames:
# accurate: 1025, total: 1131
# fake frames:
# accurate: 1101, total: 11869
# real frames:
# accurate: 1276, total: 1400
# fake frames:
# accurate: 1149, total: 12600
# real frames:
# accurate: 1318, total: 1442
# fake frames:
# accurate: 1188, total: 13558
# real frames:
# accurate: 1385, total: 1512
# fake frames:
# accurate: 1228, total: 14488
# real frames:
# accurate: 1453, total: 1581
# fake frames:
# accurate: 1261, total: 15419
# real frames:
# accurate: 1615, total: 1761
# fake frames:
# accurate: 1312, total: 16239
# real frames:
# accurate: 1665, total: 1842
# fake frames:
# accurate: 1647, total: 17158
# real frames:
# accurate: 1692, total: 1906
# fake frames:
# accurate: 2009, total: 18094
# real frames:
# accurate: 1724, total: 1946
# fake frames:
# accurate: 2431, total: 19054
# real frames:
# accurate: 1765, total: 2000
# fake frames:
# accurate: 2810, total: 20000
# real frames:
# accurate: 1884, total: 2132
# fake frames:
# accurate: 3074, total: 20868
# real frames:
# accurate: 2231, total: 2514
# fake frames:
# accurate: 3154, total: 21486
# real frames:
# accurate: 2403, total: 2688
# fake frames:
# accurate: 3180, total: 22312
# real frames:
# accurate: 2451, total: 2736
# fake frames:
# accurate: 3218, total: 23264
# real frames:
# accurate: 2523, total: 2808
# fake frames:
# accurate: 3259, total: 24192
# real frames:
# accurate: 2598, total: 2883
# fake frames:
# accurate: 3281, total: 25117
# real frames:
# accurate: 2646, total: 2931
# fake frames:
# accurate: 3297, total: 26069
# real frames:
# accurate: 2709, total: 2994
# fake frames:
# accurate: 3335, total: 27006
# real frames:
# accurate: 2849, total: 3153
# fake frames:
# accurate: 3438, total: 27847
# real frames:
# accurate: 3153, total: 3547
# fake frames:
# accurate: 3572, total: 28453
# real frames:
# accurate: 3253, total: 3651
# fake frames:
# accurate: 3603, total: 29349
# real frames:
# accurate: 3324, total: 3722
# fake frames:
# accurate: 3631, total: 30278
# real frames:
# accurate: 3391, total: 3789
# fake frames:
# accurate: 3652, total: 31211
# real frames:
# accurate: 3466, total: 3864
# fake frames:
# accurate: 3675, total: 32136
# real frames:
# accurate: 3650, total: 4068
# fake frames:
# accurate: 3738, total: 32932
# real frames:
# accurate: 3912, total: 4361
# fake frames:
# accurate: 3853, total: 33639
# real frames:
# accurate: 3988, total: 4439
# fake frames:
# accurate: 3894, total: 34561
# real frames:
# accurate: 4068, total: 4525
# fake frames:
# accurate: 3945, total: 35475
# real frames:
# accurate: 4271, total: 4736
# fake frames:
# accurate: 4000, total: 36264
# real frames:
# accurate: 4518, total: 4994
# fake frames:
# accurate: 4062, total: 37006
# real frames:
# accurate: 4578, total: 5062
# fake frames:
# accurate: 4178, total: 37938
# real frames:
# accurate: 4688, total: 5182
# fake frames:
# accurate: 4265, total: 38818
# real frames:
# accurate: 4883, total: 5408
# fake frames:
# accurate: 4349, total: 39592
# real frames:
# accurate: 5043, total: 5615
# fake frames:
# accurate: 4521, total: 40385
# real frames:
# accurate: 5089, total: 5667
# fake frames:
# accurate: 4765, total: 41333
# real frames:
# accurate: 5119, total: 5701
# fake frames:
# accurate: 5001, total: 42299
# real frames:
# accurate: 5156, total: 5744
# fake frames:
# accurate: 5242, total: 43256
# real frames:
# accurate: 5208, total: 5804
# fake frames:
# accurate: 5512, total: 44196
# real frames:
# accurate: 5233, total: 5837
# fake frames:
# accurate: 5723, total: 45163
# real frames:
# accurate: 5268, total: 5878
# fake frames:
# accurate: 5973, total: 46122
# real frames:
# accurate: 5359, total: 6051
# fake frames:
# accurate: 6274, total: 46949
# real frames:
# accurate: 5570, total: 6363
# fake frames:
# accurate: 6520, total: 47637
# real frames:
# accurate: 5704, total: 6509
# fake frames:
# accurate: 6618, total: 48491
# real frames:
# accurate: 104, total: 114
# fake frames:
# accurate: 129, total: 886
# real frames:
# accurate: 348, total: 371
# fake frames:
# accurate: 166, total: 1629
# real frames:
# accurate: 622, total: 669
# fake frames:
# accurate: 208, total: 2331
# real frames:
# accurate: 677, total: 725
# fake frames:
# accurate: 239, total: 3275
# real frames:
# accurate: 726, total: 781
# fake frames:
# accurate: 264, total: 4219
# real frames:
# accurate: 786, total: 847
# fake frames:
# accurate: 322, total: 5153
# real frames:
# accurate: 940, total: 1050
# fake frames:
# accurate: 593, total: 5950
# real frames:
# accurate: 1218, total: 1335
# fake frames:
# accurate: 645, total: 6665
# real frames:
# accurate: 1258, total: 1377
# fake frames:
# accurate: 710, total: 7623
# real frames:
# accurate: 1298, total: 1420
# fake frames:
# accurate: 759, total: 8580
# real frames:
# accurate: 1355, total: 1477
# fake frames:
# accurate: 807, total: 9523
# real frames:
# accurate: 1393, total: 1516
# fake frames:
# accurate: 875, total: 10484
# real frames:
# accurate: 1426, total: 1551
# fake frames:
# accurate: 941, total: 11449
# real frames:
# accurate: 1456, total: 1585
# fake frames:
# accurate: 997, total: 12415
# real frames:
# accurate: 1597, total: 1739
# fake frames:
# accurate: 1093, total: 13261
# real frames:
# accurate: 1789, total: 1942
# fake frames:
# accurate: 1146, total: 14058
# real frames:
# accurate: 2073, total: 2287
# fake frames:
# accurate: 1274, total: 14713
# real frames:
# accurate: 2157, total: 2398
# fake frames:
# accurate: 1507, total: 15602
# real frames:
# accurate: 2210, total: 2475
# fake frames:
# accurate: 1764, total: 16525
# real frames:
# accurate: 2301, total: 2575
# fake frames:
# accurate: 1904, total: 17425
# real frames:
# accurate: 2420, total: 2702
# fake frames:
# accurate: 1974, total: 18298
# real frames:
# accurate: 2710, total: 2996
# fake frames:
# accurate: 2011, total: 19004
# real frames:
# accurate: 2895, total: 3184
# fake frames:
# accurate: 2085, total: 19816
# real frames:
# accurate: 3008, total: 3320
# fake frames:
# accurate: 2244, total: 20680
# real frames:
# accurate: 3111, total: 3454
# fake frames:
# accurate: 2530, total: 21546
# real frames:
# accurate: 3224, total: 3589
# fake frames:
# accurate: 2640, total: 22411
# real frames:
# accurate: 3468, total: 3892
# fake frames:
# accurate: 2813, total: 23108
# real frames:
# accurate: 3538, total: 3962
# fake frames:
# accurate: 2824, total: 24038
# real frames:
# accurate: 3661, total: 4085
# fake frames:
# accurate: 2827, total: 24915
# real frames:
# accurate: 3795, total: 4264
# fake frames:
# accurate: 3049, total: 25736
# real frames:
# accurate: 4081, total: 4618
# fake frames:
# accurate: 3182, total: 26382
# real frames:
# accurate: 4212, total: 4750
# fake frames:
# accurate: 3191, total: 27250
# real frames:
# accurate: 4309, total: 4851
# fake frames:
# accurate: 3230, total: 28149
# real frames:
# accurate: 4428, total: 4982
# fake frames:
# accurate: 3322, total: 29018
# real frames:
# accurate: 4591, total: 5160
# fake frames:
# accurate: 3395, total: 29840
# real frames:
# accurate: 4873, total: 5470
# fake frames:
# accurate: 3481, total: 30530
# real frames:
# accurate: 5002, total: 5627
# fake frames:
# accurate: 3644, total: 31373
# real frames:
# accurate: 5057, total: 5693
# fake frames:
# accurate: 3812, total: 32307
# real frames:
# accurate: 5104, total: 5751
# fake frames:
# accurate: 4008, total: 33249
# real frames:
# accurate: 5241, total: 5909
# fake frames:
# accurate: 4170, total: 34091
# real frames:
# accurate: 5395, total: 6105
# fake frames:
# accurate: 4356, total: 34895
# real frames:
# accurate: 5737, total: 6483
# fake frames:
# accurate: 4509, total: 35517
# real frames:
# accurate: 5817, total: 6563
# fake frames:
# accurate: 4515, total: 36437
# real frames:
# accurate: 5889, total: 6643
# fake frames:
# accurate: 4567, total: 37357
# real frames:
# accurate: 5971, total: 6786
# fake frames:
# accurate: 5042, total: 38214
# real frames:
# accurate: 6184, total: 7000
# fake frames:
# accurate: 5061, total: 39000
# real frames:
# accurate: 6435, total: 7301
# fake frames:
# accurate: 5143, total: 39699
# real frames:
# accurate: 6496, total: 7397
# fake frames:
# accurate: 5429, total: 40603
# real frames:
# accurate: 6588, total: 7506
# fake frames:
# accurate: 5611, total: 41494
# real frames:
# accurate: 6673, total: 7607
# fake frames:
# accurate: 5777, total: 42393
# real frames:
# accurate: 6844, total: 7784
# fake frames:
# accurate: 5810, total: 43216
# real frames:
# accurate: 7066, total: 8010
# fake frames:
# accurate: 5834, total: 43990
# real frames:
# accurate: 232, total: 241
# fake frames:
# accurate: 48, total: 759
# real frames:
# accurate: 303, total: 312
# fake frames:
# accurate: 49, total: 1688
# real frames:
# accurate: 401, total: 410
# fake frames:
# accurate: 58, total: 2590
# real frames:
# accurate: 555, total: 566
# fake frames:
# accurate: 79, total: 3434
# real frames:
# accurate: 808, total: 844
# fake frames:
# accurate: 149, total: 4156
# real frames:
# accurate: 953, total: 1013
# fake frames:
# accurate: 312, total: 4987
# real frames:
# accurate: 1041, total: 1126
# fake frames:
# accurate: 484, total: 5874
# real frames:
# accurate: 1131, total: 1283
# fake frames:
# accurate: 759, total: 6717
# real frames:
# accurate: 1298, total: 1487
# fake frames:
# accurate: 902, total: 7513
# real frames:
# accurate: 1609, total: 1840
# fake frames:
# accurate: 966, total: 8160
# real frames:
# accurate: 1754, total: 2015
# fake frames:
# accurate: 1043, total: 8985
# real frames:
# accurate: 1820, total: 2086
# fake frames:
# accurate: 1088, total: 9914
# real frames:
# accurate: 1955, total: 2221
# fake frames:
# accurate: 1097, total: 10779
# real frames:
# accurate: 2124, total: 2392
# fake frames:
# accurate: 1109, total: 11608
# real frames:
# accurate: 2336, total: 2651
# fake frames:
# accurate: 1274, total: 12349
# real frames:
# accurate: 2532, total: 2877
# fake frames:
# accurate: 1357, total: 13123
# real frames:
# accurate: 2622, total: 2972
# fake frames:
# accurate: 1440, total: 14028
# real frames:
# accurate: 2724, total: 3084
# fake frames:
# accurate: 1539, total: 14916
# real frames:
# accurate: 2801, total: 3187
# fake frames:
# accurate: 1712, total: 15813
# real frames:
# accurate: 2943, total: 3346
# fake frames:
# accurate: 1879, total: 16654
# real frames:
# accurate: 3180, total: 3618
# fake frames:
# accurate: 1963, total: 17382
# real frames:
# accurate: 3362, total: 3814
# fake frames:
# accurate: 2018, total: 18186
# real frames:
# accurate: 3416, total: 3868
# fake frames:
# accurate: 2050, total: 19132
# real frames:
# accurate: 3476, total: 3977
# fake frames:
# accurate: 2435, total: 20023
# real frames:
# accurate: 3616, total: 4163
# fake frames:
# accurate: 2677, total: 20837
# real frames:
# accurate: 3834, total: 4402
# fake frames:
# accurate: 2764, total: 21598
# real frames:
# accurate: 4090, total: 4677
# fake frames:
# accurate: 2801, total: 22323
# real frames:
# accurate: 4211, total: 4798
# fake frames:
# accurate: 2816, total: 23202
# real frames:
# accurate: 4303, total: 4908
# fake frames:
# accurate: 2895, total: 24092
# real frames:
# accurate: 4446, total: 5075
# fake frames:
# accurate: 3051, total: 24925
# real frames:
# accurate: 4657, total: 5294
# fake frames:
# accurate: 3100, total: 25706
# real frames:
# accurate: 4866, total: 5533
# fake frames:
# accurate: 3139, total: 26467
# real frames:
# accurate: 5003, total: 5688
# fake frames:
# accurate: 3218, total: 27312
# real frames:
# accurate: 5088, total: 5780
# fake frames:
# accurate: 3290, total: 28220
# real frames:
# accurate: 5217, total: 5915
# fake frames:
# accurate: 3387, total: 29085
# real frames:
# accurate: 5397, total: 6114
# fake frames:
# accurate: 3522, total: 29886
# real frames:
# accurate: 5627, total: 6443
# fake frames:
# accurate: 3687, total: 30557
# real frames:
# accurate: 5701, total: 6537
# fake frames:
# accurate: 3945, total: 31463
# real frames:
# accurate: 5829, total: 6691
# fake frames:
# accurate: 4103, total: 32309
# real frames:
# accurate: 6094, total: 6975
# fake frames:
# accurate: 4159, total: 33025
# real frames:
# accurate: 6305, total: 7206
# fake frames:
# accurate: 4204, total: 33794
# real frames:
# accurate: 6482, total: 7394
# fake frames:
# accurate: 4233, total: 34606
# real frames:
# accurate: 6533, total: 7447
# fake frames:
# accurate: 4244, total: 35553
# real frames:
# accurate: 6651, total: 7573
# fake frames:
# accurate: 4282, total: 36427
# real frames:
# accurate: 6775, total: 7729
# fake frames:
# accurate: 4465, total: 37271
# real frames:
# accurate: 7019, total: 8005
# fake frames:
# accurate: 4616, total: 37995
# real frames:
# accurate: 7301, total: 8333
# fake frames:
# accurate: 4797, total: 38667
# real frames:
# accurate: 7426, total: 8461
# fake frames:
# accurate: 4810, total: 39539
# real frames:
# accurate: 7542, total: 8580
# fake frames:
# accurate: 4842, total: 40420
# real frames:
# accurate: 7717, total: 8799
# fake frames:
# accurate: 4974, total: 41201
# real frames:
# accurate: 285, total: 347
# fake frames:
# accurate: 127, total: 653
# real frames:
# accurate: 401, total: 486
# fake frames:
# accurate: 274, total: 1514
# real frames:
# accurate: 475, total: 568
# fake frames:
# accurate: 392, total: 2432
# real frames:
# accurate: 657, total: 754
# fake frames:
# accurate: 439, total: 3246
# real frames:
# accurate: 831, total: 952
# fake frames:
# accurate: 556, total: 4048
# real frames:
# accurate: 998, total: 1148
# fake frames:
# accurate: 662, total: 4852
# real frames:
# accurate: 1198, total: 1407
# fake frames:
# accurate: 770, total: 5593
# real frames:
# accurate: 1397, total: 1607
# fake frames:
# accurate: 798, total: 6393
# real frames:
# accurate: 1512, total: 1725
# fake frames:
# accurate: 845, total: 7275
# real frames:
# accurate: 1671, total: 1884
# fake frames:
# accurate: 859, total: 8116
# real frames:
# accurate: 1893, total: 2108
# fake frames:
# accurate: 883, total: 8892
# real frames:
# accurate: 2098, total: 2314
# fake frames:
# accurate: 943, total: 9686
# real frames:
# accurate: 2149, total: 2409
# fake frames:
# accurate: 1229, total: 10591
# real frames:
# accurate: 2229, total: 2541
# fake frames:
# accurate: 1620, total: 11459
# real frames:
# accurate: 2409, total: 2757
# fake frames:
# accurate: 1784, total: 12243
# real frames:
# accurate: 2664, total: 3035
# fake frames:
# accurate: 1908, total: 12965
# real frames:
# accurate: 2777, total: 3181
# fake frames:
# accurate: 2151, total: 13819
# real frames:
# accurate: 2860, total: 3303
# fake frames:
# accurate: 2464, total: 14697
# real frames:
# accurate: 2931, total: 3412
# fake frames:
# accurate: 2820, total: 15588
# real frames:
# accurate: 3041, total: 3550
# fake frames:
# accurate: 2989, total: 16450
# real frames:
# accurate: 3215, total: 3727
# fake frames:
# accurate: 2995, total: 17273
# real frames:
# accurate: 3440, total: 3972
# fake frames:
# accurate: 3065, total: 18028
# real frames:
# accurate: 3567, total: 4135
# fake frames:
# accurate: 3289, total: 18865
# real frames:
# accurate: 3654, total: 4238
# fake frames:
# accurate: 3512, total: 19762
# real frames:
# accurate: 3807, total: 4404
# fake frames:
# accurate: 3569, total: 20596
# real frames:
# accurate: 3945, total: 4567
# fake frames:
# accurate: 3664, total: 21433
# real frames:
# accurate: 4080, total: 4709
# fake frames:
# accurate: 3680, total: 22291
# real frames:
# accurate: 4352, total: 5004
# fake frames:
# accurate: 3749, total: 22996
# real frames:
# accurate: 4435, total: 5092
# fake frames:
# accurate: 3813, total: 23908
# real frames:
# accurate: 4481, total: 5144
# fake frames:
# accurate: 3886, total: 24856
# real frames:
# accurate: 4577, total: 5273
# fake frames:
# accurate: 4063, total: 25727
# real frames:
# accurate: 4749, total: 5554
# fake frames:
# accurate: 4383, total: 26446
# real frames:
# accurate: 4911, total: 5779
# fake frames:
# accurate: 4766, total: 27221
# real frames:
# accurate: 4979, total: 5897
# fake frames:
# accurate: 5206, total: 28103
# real frames:
# accurate: 5066, total: 5984
# fake frames:
# accurate: 5233, total: 29016
# real frames:
# accurate: 5205, total: 6133
# fake frames:
# accurate: 5265, total: 29867
# real frames:
# accurate: 5411, total: 6340
# fake frames:
# accurate: 5274, total: 30660
# real frames:
# accurate: 5738, total: 6685
# fake frames:
# accurate: 5337, total: 31315
# real frames:
# accurate: 5802, total: 6809
# fake frames:
# accurate: 5893, total: 32191
# real frames:
# accurate: 5869, total: 6929
# fake frames:
# accurate: 6403, total: 33071
# real frames:
# accurate: 6046, total: 7109
# fake frames:
# accurate: 6481, total: 33891
# real frames:
# accurate: 6208, total: 7283
# fake frames:
# accurate: 6565, total: 34717
# real frames:
# accurate: 6504, total: 7606
# fake frames:
# accurate: 6663, total: 35394
# real frames:
# accurate: 6689, total: 7797
# fake frames:
# accurate: 6715, total: 36203
# real frames:
# accurate: 6786, total: 7909
# fake frames:
# accurate: 6853, total: 37091
# real frames:
# accurate: 6836, total: 8023
# fake frames:
# accurate: 7356, total: 37977
# real frames:
# accurate: 6927, total: 8121
# fake frames:
# accurate: 7439, total: 38879
# real frames:
# accurate: 7100, total: 8301
# fake frames:
# accurate: 7526, total: 39699
# real frames:
# accurate: 7396, total: 8620
# fake frames:
# accurate: 7588, total: 40380
# real frames:
# accurate: 7537, total: 8761
# fake frames:
# accurate: 7606, total: 41239
# real frames:
# accurate: 7613, total: 8866
# fake frames:
# accurate: 7847, total: 42134
# real frames:
# accurate: 76, total: 131
# fake frames:
# accurate: 300, total: 869
# real frames:
# accurate: 279, total: 363
# fake frames:
# accurate: 432, total: 1637
# real frames:
# accurate: 567, total: 686
# fake frames:
# accurate: 503, total: 2314
# real frames:
# accurate: 687, total: 813
# fake frames:
# accurate: 576, total: 3187
# real frames:
# accurate: 794, total: 927
# fake frames:
# accurate: 612, total: 4073
# real frames:
# accurate: 871, total: 1004
# fake frames:
# accurate: 621, total: 4996
# real frames:
# accurate: 1065, total: 1211
# fake frames:
# accurate: 669, total: 5789
# real frames:
# accurate: 1306, total: 1489
# fake frames:
# accurate: 747, total: 6511
# real frames:
# accurate: 1455, total: 1656
# fake frames:
# accurate: 801, total: 7344
# real frames:
# accurate: 1549, total: 1758
# fake frames:
# accurate: 842, total: 8242
# real frames:
# accurate: 1701, total: 1919
# fake frames:
# accurate: 888, total: 9081
# real frames:
# accurate: 1824, total: 2061
# fake frames:
# accurate: 1015, total: 9939
# real frames:
# accurate: 1927, total: 2196
# fake frames:
# accurate: 1249, total: 10804
# real frames:
# accurate: 2061, total: 2361
# fake frames:
# accurate: 1428, total: 11639
# real frames:
# accurate: 2372, total: 2698
# fake frames:
# accurate: 1483, total: 12302
# real frames:
# accurate: 2518, total: 2863
# fake frames:
# accurate: 1524, total: 13137
# real frames:
# accurate: 2601, total: 2946
# fake frames:
# accurate: 1528, total: 14054
# real frames:
# accurate: 2675, total: 3050
# fake frames:
# accurate: 1770, total: 14950
# real frames:
# accurate: 2749, total: 3163
# fake frames:
# accurate: 2099, total: 15837
# real frames:
# accurate: 2876, total: 3329
# fake frames:
# accurate: 2224, total: 16671
# real frames:
# accurate: 3210, total: 3702
# fake frames:
# accurate: 2332, total: 17298
# real frames:
# accurate: 3313, total: 3821
# fake frames:
# accurate: 2571, total: 18179
# real frames:
# accurate: 3412, total: 3946
# fake frames:
# accurate: 2910, total: 19054
# real frames:
# accurate: 3481, total: 4053
# fake frames:
# accurate: 3275, total: 19947
# real frames:
# accurate: 3621, total: 4199
# fake frames:
# accurate: 3423, total: 20801
# real frames:
# accurate: 3813, total: 4399
# fake frames:
# accurate: 3448, total: 21601
# real frames:
# accurate: 4037, total: 4709
# fake frames:
# accurate: 3531, total: 22291
# real frames:
# accurate: 4180, total: 4871
# fake frames:
# accurate: 3648, total: 23129
# real frames:
# accurate: 4244, total: 4994
# fake frames:
# accurate: 4134, total: 24006
# real frames:
# accurate: 4338, total: 5128
# fake frames:
# accurate: 4467, total: 24872
# real frames:
# accurate: 4503, total: 5375
# fake frames:
# accurate: 4649, total: 25625
# real frames:
# accurate: 4731, total: 5633
# fake frames:
# accurate: 4830, total: 26367
# real frames:
# accurate: 4828, total: 5785
# fake frames:
# accurate: 5106, total: 27215
# real frames:
# accurate: 4935, total: 5906
# fake frames:
# accurate: 5165, total: 28094
# real frames:
# accurate: 5072, total: 6046
# fake frames:
# accurate: 5228, total: 28954
# real frames:
# accurate: 5286, total: 6275
# fake frames:
# accurate: 5316, total: 29725
# real frames:
# accurate: 5519, total: 6513
# fake frames:
# accurate: 5334, total: 30487
# real frames:
# accurate: 5616, total: 6610
# fake frames:
# accurate: 5338, total: 31390
# real frames:
# accurate: 5766, total: 6760
# fake frames:
# accurate: 5339, total: 32240
# real frames:
# accurate: 5878, total: 6872
# fake frames:
# accurate: 5339, total: 33128
# real frames:
# accurate: 6125, total: 7137
# fake frames:
# accurate: 5404, total: 33863
# real frames:
# accurate: 6376, total: 7405
# fake frames:
# accurate: 5485, total: 34595
# real frames:
# accurate: 6509, total: 7544
# fake frames:
# accurate: 5609, total: 35456
# real frames:
# accurate: 6626, total: 7672
# fake frames:
# accurate: 5646, total: 36328
# real frames:
# accurate: 6759, total: 7808
# fake frames:
# accurate: 5665, total: 37192
# real frames:
# accurate: 6939, total: 7996
# fake frames:
# accurate: 5723, total: 38004
# real frames:
# accurate: 7125, total: 8233
# fake frames:
# accurate: 5921, total: 38767
# real frames:
# accurate: 7270, total: 8388
# fake frames:
# accurate: 5941, total: 39612
# real frames:
# accurate: 7408, total: 8528
# fake frames:
# accurate: 5972, total: 40472
# real frames:
# accurate: 7514, total: 8654
# fake frames:
# accurate: 6080, total: 41346
# real frames:
# accurate: 7646, total: 8790
# fake frames:
# accurate: 6116, total: 42210
# real frames:
# accurate: 7804, total: 8949
# fake frames:
# accurate: 6146, total: 43051
# real frames:
# accurate: 7993, total: 9138
# fake frames:
# accurate: 6180, total: 43862
# real frames:
# accurate: 8118, total: 9266
# fake frames:
# accurate: 6230, total: 44734

# %%
print('{}/{} real frames predicted correctly, and {}/{} fake frames predicted correctly'.format(correct_real,
                                                                                                total_real,
                                                                                                correct_fake,
                                                                                                total_fake))
# Out:
# 36680/42036 real frames predicted correctly, and 31818/222156 fake frames predicted correctly

# %%
prediction_df.to_csv('predictions130.csv')

# %%
blob = model_bucket.blob('predictions130.csv')
blob.upload_from_filename('predictions130.csv')
