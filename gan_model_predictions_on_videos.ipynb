# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.cloud import storage
from google.oauth2 import service_account
import os

# %%
from google.cloud import storage
try:
    from google.colab import auth
    auth.authenticate_user()
    credentials=None
except ModuleNotFoundError:

    credentials = service_account.Credentials.from_service_account_file( #file location of GCS private key
        '/Users/jeremiahherberg/Downloads/deepfake-research-a6b5e4f02da6.json')

# %%
client = storage.Client(project='deepfake-research', credentials=credentials)
video_frame_bucket_name = 'deepfake-dataset'
#bucket containing test data
video_frame_bucket = client.bucket(video_frame_bucket_name)
model_bucket_name = 'jh-gan-testing'
#bucket containing model
model_bucket = client.bucket(model_bucket_name)

# %%
#download and load model
model_name = 'disc_4.h5'
model_blob = model_bucket.blob(model_name)
model_blob.download_to_filename(model_name)
model = tf.keras.models.load_model(model_name)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
def make_single_prediction(frame,
                          frame_shape=(225, 146, 3),
                          model_input_shape=(192, 128, 3),
                          model=model):
    '''
    function to make a prediction if a single frame in test dataset is real or not
    
    inputs:
        frame - array with a shape of (frame_shape[0] * frame_shape[1] * frame_shape[2],)
        
        frame_shape - tuple that describes the shape of the image, defaults to (225, 146, 3)
        the last dim must be 3 (RGB)
        
        model_input_shape - tuple that describes the shape of the input that will be passed into model
        defaults to (192, 128, 3), the last dim must be 3 (RGB)
        
        model - tensorflow model that will be used to make prediction, defaults to 'model'
    returns:
        prediction - Bool, True if model predicts frame is real, False if prediction is frame is fake
        raw_prediction - float, range of -inf to inf, negative number indicates prediction is that 
        frame is fake and positive indicates the prediction is the frame is real
        the closer to 0 the raw_prediction, the less confident the model is
    ''' 
    assert(frame_shape[2] == model_input_shape[2] == 3), 'the last dim must equal 3 in the model and frame shapes'
    frame_reshaped = frame.reshape(frame_shape)
    #resize frame to be compatable with model
    frame_resized = tf.image.resize_with_pad(frame_reshaped, model_input_shape[0], model_input_shape[1])
    # (H, W, RGB) -> (1, H, W, RGB)
    frame_expanded = tf.expand_dims(frame_resized, 0)
    #convert values to between -1 and 1 (0 to 255 -> -1 to 1) (this is how the model was trained)
    frame_expanded = (tf.cast(frame_expanded, tf.float32) - 127.5) / 127.5
    #we are only making a single prediction
    raw_prediction = model.predict(frame_expanded)[0][0]
    
    if raw_prediction > 0:
        prediction = True
    else:
        prediction = False
    
    return prediction, raw_prediction

# %%
def prediction_batch(idx,
                    bucket=video_frame_bucket,
                    test_ds_file_name='face_arrays',
                    ground_file_name='labels_and_video_names'):
    '''
    function to make a batch of predictions 
    test dataset is split up into 5 files
    
    inputs:
        idx - int with a value between 1 to 5 that represents which test ds file is being used for predictions
        
        bucket - GCS bucket variable that contains files with test data, default is video_frame_bucket
        
        test_ds_file_name - str - beginning of file name of files containing test ds, default is face_arrays
        
        ground_file_name - str - beginning of file name of files containing the ground truth of each frame 
    
    returns:
        correct_real - int - the number of real frames correctly predicted
        
        total_real - int - total number of real frames
        
        correct_fake - int - the number of fake frames correctly predicted
        
        total_fake - int - total number of fake frames
        
        prediction_df - DataFrame  with the following columns:
            raw_prediction - float, range of -inf to inf, negative number indicates prediction
            is frame is fake and postive indicates the prediction is frame is real
            the closer to 0 of the value, the less confident the model is regarding the prediction
            
            accurate - Bool - reflects if the model accurately predicted if the frame is real or fake
            
            ground_truth - Bool - reflects if the frame is real or fake

    '''
    #downlaod files:
    ds_file_name = '{}{}.npz'.format(test_ds_file_name, idx)
    ground_file_name = '{}{}.csv'.format(ground_file_name, idx)
    ds_blob = bucket.blob('aaa_frames/' + ds_file_name)
    ds_blob.download_to_filename(ds_file_name)
    ground_blob = bucket.blob('aaa_frames/' + ground_file_name)
    ground_blob.download_to_filename(ground_file_name)
    
    data_file = np.load(ds_file_name)
    data = [data_file[key] for key in data_file]
    ground = pd.read_csv(ground_file_name)
    ground_list = ground['face_labels'].to_list()
    assert(len(ground_list) == len(data)), 'The len of the DS and ground truth do not match'
    
    total_real, total_fake, correct_real, correct_fake = 0, 0, 0, 0
    predictions = []
    ground_truths = []
    accurate_predictions = []
    
    for frame in range(len(data)):
        prediction, raw_prediction = make_single_prediction(data[frame])
        real = ground_list[frame]
        accurate_prediction = (real == prediction)
        if real:
            total_real +=1
            if accurate_prediction:
                correct_real +=1
        else:
            total_fake +=1
            if accurate_prediction: 
                correct_fake +=1
        predictions.append(raw_prediction)
        ground_truths.append(real)
        accurate_predictions.append(accurate_prediction)
        if frame % 1000 == 999:
          print('real frames:')
          print('accurate: {}, total: {}'.format(correct_real, total_real))
          print('fake frames:')
          print('accurate: {}, total: {} '.format(correct_fake, total_fake))
    
    
    preds_dictionary = {
        'raw_prediction':predictions,
        'accurate': accurate_predictions,
        'ground_truth': ground_truths
    }
    prediction_df = pd.DataFrame(preds_dictionary)
        
    return correct_real, total_real, correct_fake, total_fake, prediction_df

# %%
def make_predictions(start, end):
    '''
    function to make predictions on entire dataset
    
    inputs:
        start - int, starting file number in test dataset
        
        end - int, ending file number in test dataset, must be greater than or equal to start
        
    returns:
    correct_real - int - the number of real frames correctly predicted

    total_real - int - total number of real frames

    correct_fake - int - the number of fake frames correctly predicted

    total_fake - int - total number of fake frames

    prediction_df - DataFrame  with the following columns:
        raw_prediction - float, range of -inf to inf, negative number indicates prediction
        is frame is fake and postive indicates the prediction is frame is real
        the closer to 0 of the value, the less confident the model is regarding the prediction

        accurate - Bool - reflects if the model accurately predicted if the frame is real or fake

        ground_truth - Bool - reflects if the frame is real or fake
    '''
    
    assert(start <= end), 'start must be less than or equal to end'
    
    total_real, total_fake, correct_real, correct_fake = 0, 0, 0, 0
    prediction_dfs = []
    for file in np.arange(start, end+1):
        cor_real_batch, real_batch, cor_fake_batch, fake_batch, df_batch = prediction_batch(file)
        total_real += real_batch
        total_fake += fake_batch
        correct_real +=cor_real_batch
        correct_fake += cor_fake_batch
        prediction_dfs.append(df_batch)
    
    prediction_df = pd.concat(prediction_dfs)
    
    return total_real, total_fake, correct_real, correct_fake, prediction_df

# %%
with tf.device('/device:GPU:0'):
    total_real, total_fake, correct_real, correct_fake, prediction_df = make_predictions(1, 5)
# Out:
# real frames:
# accurate: 44, total: 52
# fake frames:
# accurate: 190, total: 948
# real frames:
# accurate: 112, total: 127
# fake frames:
# accurate: 362, total: 1873
# real frames:
# accurate: 181, total: 206
# fake frames:
# accurate: 607, total: 2794
# real frames:
# accurate: 244, total: 281
# fake frames:
# accurate: 911, total: 3719
# real frames:
# accurate: 287, total: 333
# fake frames:
# accurate: 1230, total: 4667
# real frames:
# accurate: 320, total: 373
# fake frames:
# accurate: 1573, total: 5627
# real frames:
# accurate: 374, total: 443
# fake frames:
# accurate: 1732, total: 6557
# real frames:
# accurate: 436, total: 513
# fake frames:
# accurate: 1861, total: 7487
# real frames:
# accurate: 495, total: 579
# fake frames:
# accurate: 1995, total: 8421
# real frames:
# accurate: 557, total: 674
# fake frames:
# accurate: 2143, total: 9326
# real frames:
# accurate: 764, total: 946
# fake frames:
# accurate: 2221, total: 10054
# real frames:
# accurate: 841, total: 1024
# fake frames:
# accurate: 2238, total: 10976
# real frames:
# accurate: 944, total: 1131
# fake frames:
# accurate: 2258, total: 11869
# real frames:
# accurate: 1182, total: 1400
# fake frames:
# accurate: 2279, total: 12600
# real frames:
# accurate: 1223, total: 1442
# fake frames:
# accurate: 2353, total: 13558
# real frames:
# accurate: 1288, total: 1512
# fake frames:
# accurate: 2423, total: 14488
# real frames:
# accurate: 1354, total: 1581
# fake frames:
# accurate: 2474, total: 15419
# real frames:
# accurate: 1492, total: 1761
# fake frames:
# accurate: 2531, total: 16239
# real frames:
# accurate: 1522, total: 1842
# fake frames:
# accurate: 3042, total: 17158
# real frames:
# accurate: 1542, total: 1906
# fake frames:
# accurate: 3571, total: 18094
# real frames:
# accurate: 1558, total: 1946
# fake frames:
# accurate: 4134, total: 19054
# real frames:
# accurate: 1580, total: 2000
# fake frames:
# accurate: 4698, total: 20000
# real frames:
# accurate: 1687, total: 2132
# fake frames:
# accurate: 5067, total: 20868
# real frames:
# accurate: 1891, total: 2514
# fake frames:
# accurate: 5307, total: 21486
# real frames:
# accurate: 2051, total: 2688
# fake frames:
# accurate: 5346, total: 22312
# real frames:
# accurate: 2098, total: 2736
# fake frames:
# accurate: 5382, total: 23264
# real frames:
# accurate: 2170, total: 2808
# fake frames:
# accurate: 5405, total: 24192
# real frames:
# accurate: 2245, total: 2883
# fake frames:
# accurate: 5426, total: 25117
# real frames:
# accurate: 2292, total: 2931
# fake frames:
# accurate: 5445, total: 26069
# real frames:
# accurate: 2352, total: 2994
# fake frames:
# accurate: 5471, total: 27006
# real frames:
# accurate: 2494, total: 3153
# fake frames:
# accurate: 5535, total: 27847
# real frames:
# accurate: 2750, total: 3547
# fake frames:
# accurate: 5700, total: 28453
# real frames:
# accurate: 2829, total: 3651
# fake frames:
# accurate: 5749, total: 29349
# real frames:
# accurate: 2899, total: 3722
# fake frames:
# accurate: 5756, total: 30278
# real frames:
# accurate: 2966, total: 3789
# fake frames:
# accurate: 5762, total: 31211
# real frames:
# accurate: 3039, total: 3864
# fake frames:
# accurate: 5781, total: 32136
# real frames:
# accurate: 3227, total: 4068
# fake frames:
# accurate: 5838, total: 32932
# real frames:
# accurate: 3437, total: 4361
# fake frames:
# accurate: 6041, total: 33639
# real frames:
# accurate: 3499, total: 4439
# fake frames:
# accurate: 6253, total: 34561
# real frames:
# accurate: 3562, total: 4525
# fake frames:
# accurate: 6471, total: 35475
# real frames:
# accurate: 3748, total: 4736
# fake frames:
# accurate: 6579, total: 36264
# real frames:
# accurate: 3941, total: 4994
# fake frames:
# accurate: 6683, total: 37006
# real frames:
# accurate: 3999, total: 5062
# fake frames:
# accurate: 6889, total: 37938
# real frames:
# accurate: 4101, total: 5182
# fake frames:
# accurate: 7068, total: 38818
# real frames:
# accurate: 4245, total: 5408
# fake frames:
# accurate: 7238, total: 39592
# real frames:
# accurate: 4338, total: 5615
# fake frames:
# accurate: 7680, total: 40385
# real frames:
# accurate: 4379, total: 5667
# fake frames:
# accurate: 7956, total: 41333
# real frames:
# accurate: 4407, total: 5701
# fake frames:
# accurate: 8229, total: 42299
# real frames:
# accurate: 4440, total: 5744
# fake frames:
# accurate: 8521, total: 43256
# real frames:
# accurate: 4485, total: 5804
# fake frames:
# accurate: 8799, total: 44196
# real frames:
# accurate: 4506, total: 5837
# fake frames:
# accurate: 9056, total: 45163
# real frames:
# accurate: 4538, total: 5878
# fake frames:
# accurate: 9333, total: 46122
# real frames:
# accurate: 4633, total: 6051
# fake frames:
# accurate: 9694, total: 46949
# real frames:
# accurate: 4814, total: 6363
# fake frames:
# accurate: 10000, total: 47637
# real frames:
# accurate: 4935, total: 6509
# fake frames:
# accurate: 10133, total: 48491
# real frames:
# accurate: 102, total: 114
# fake frames:
# accurate: 159, total: 886
# real frames:
# accurate: 336, total: 371
# fake frames:
# accurate: 204, total: 1629
# real frames:
# accurate: 596, total: 669
# fake frames:
# accurate: 272, total: 2331
# real frames:
# accurate: 649, total: 725
# fake frames:
# accurate: 351, total: 3275
# real frames:
# accurate: 695, total: 781
# fake frames:
# accurate: 445, total: 4219
# real frames:
# accurate: 753, total: 847
# fake frames:
# accurate: 544, total: 5153
# real frames:
# accurate: 925, total: 1050
# fake frames:
# accurate: 687, total: 5950
# real frames:
# accurate: 1197, total: 1335
# fake frames:
# accurate: 703, total: 6665
# real frames:
# accurate: 1238, total: 1377
# fake frames:
# accurate: 725, total: 7623
# real frames:
# accurate: 1280, total: 1420
# fake frames:
# accurate: 747, total: 8580
# real frames:
# accurate: 1336, total: 1477
# fake frames:
# accurate: 781, total: 9523
# real frames:
# accurate: 1373, total: 1516
# fake frames:
# accurate: 808, total: 10484
# real frames:
# accurate: 1406, total: 1551
# fake frames:
# accurate: 838, total: 11449
# real frames:
# accurate: 1439, total: 1585
# fake frames:
# accurate: 871, total: 12415
# real frames:
# accurate: 1561, total: 1739
# fake frames:
# accurate: 1034, total: 13261
# real frames:
# accurate: 1742, total: 1942
# fake frames:
# accurate: 1134, total: 14058
# real frames:
# accurate: 2016, total: 2287
# fake frames:
# accurate: 1276, total: 14713
# real frames:
# accurate: 2102, total: 2398
# fake frames:
# accurate: 1408, total: 15602
# real frames:
# accurate: 2165, total: 2475
# fake frames:
# accurate: 1579, total: 16525
# real frames:
# accurate: 2261, total: 2575
# fake frames:
# accurate: 1657, total: 17425
# real frames:
# accurate: 2369, total: 2702
# fake frames:
# accurate: 1778, total: 18298
# real frames:
# accurate: 2660, total: 2996
# fake frames:
# accurate: 1805, total: 19004
# real frames:
# accurate: 2840, total: 3184
# fake frames:
# accurate: 1867, total: 19816
# real frames:
# accurate: 2950, total: 3320
# fake frames:
# accurate: 1982, total: 20680
# real frames:
# accurate: 3041, total: 3454
# fake frames:
# accurate: 2266, total: 21546
# real frames:
# accurate: 3140, total: 3589
# fake frames:
# accurate: 2433, total: 22411
# real frames:
# accurate: 3331, total: 3892
# fake frames:
# accurate: 2677, total: 23108
# real frames:
# accurate: 3392, total: 3962
# fake frames:
# accurate: 2782, total: 24038
# real frames:
# accurate: 3515, total: 4085
# fake frames:
# accurate: 2788, total: 24915
# real frames:
# accurate: 3653, total: 4264
# fake frames:
# accurate: 2965, total: 25736
# real frames:
# accurate: 3896, total: 4618
# fake frames:
# accurate: 3157, total: 26382
# real frames:
# accurate: 4020, total: 4750
# fake frames:
# accurate: 3198, total: 27250
# real frames:
# accurate: 4110, total: 4851
# fake frames:
# accurate: 3313, total: 28149
# real frames:
# accurate: 4200, total: 4982
# fake frames:
# accurate: 3633, total: 29018
# real frames:
# accurate: 4350, total: 5160
# fake frames:
# accurate: 3773, total: 29840
# real frames:
# accurate: 4610, total: 5470
# fake frames:
# accurate: 3878, total: 30530
# real frames:
# accurate: 4702, total: 5627
# fake frames:
# accurate: 4038, total: 31373
# real frames:
# accurate: 4764, total: 5693
# fake frames:
# accurate: 4164, total: 32307
# real frames:
# accurate: 4818, total: 5751
# fake frames:
# accurate: 4314, total: 33249
# real frames:
# accurate: 4930, total: 5909
# fake frames:
# accurate: 4660, total: 34091
# real frames:
# accurate: 5076, total: 6105
# fake frames:
# accurate: 4860, total: 34895
# real frames:
# accurate: 5315, total: 6483
# fake frames:
# accurate: 5081, total: 35517
# real frames:
# accurate: 5389, total: 6563
# fake frames:
# accurate: 5167, total: 36437
# real frames:
# accurate: 5459, total: 6643
# fake frames:
# accurate: 5265, total: 37357
# real frames:
# accurate: 5539, total: 6786
# fake frames:
# accurate: 5711, total: 38214
# real frames:
# accurate: 5752, total: 7000
# fake frames:
# accurate: 5719, total: 39000
# real frames:
# accurate: 5981, total: 7301
# fake frames:
# accurate: 5863, total: 39699
# real frames:
# accurate: 6067, total: 7397
# fake frames:
# accurate: 5940, total: 40603
# real frames:
# accurate: 6154, total: 7506
# fake frames:
# accurate: 6113, total: 41494
# real frames:
# accurate: 6226, total: 7607
# fake frames:
# accurate: 6325, total: 42393
# real frames:
# accurate: 6375, total: 7784
# fake frames:
# accurate: 6466, total: 43216
# real frames:
# accurate: 6593, total: 8010
# fake frames:
# accurate: 6494, total: 43990
# real frames:
# accurate: 195, total: 241
# fake frames:
# accurate: 50, total: 759
# real frames:
# accurate: 265, total: 312
# fake frames:
# accurate: 63, total: 1688
# real frames:
# accurate: 363, total: 410
# fake frames:
# accurate: 81, total: 2590
# real frames:
# accurate: 486, total: 566
# fake frames:
# accurate: 206, total: 3434
# real frames:
# accurate: 670, total: 844
# fake frames:
# accurate: 301, total: 4156
# real frames:
# accurate: 793, total: 1013
# fake frames:
# accurate: 427, total: 4987
# real frames:
# accurate: 890, total: 1126
# fake frames:
# accurate: 514, total: 5874
# real frames:
# accurate: 933, total: 1283
# fake frames:
# accurate: 1024, total: 6717
# real frames:
# accurate: 1071, total: 1487
# fake frames:
# accurate: 1262, total: 7513
# real frames:
# accurate: 1333, total: 1840
# fake frames:
# accurate: 1410, total: 8160
# real frames:
# accurate: 1420, total: 2015
# fake frames:
# accurate: 1598, total: 8985
# real frames:
# accurate: 1480, total: 2086
# fake frames:
# accurate: 1749, total: 9914
# real frames:
# accurate: 1615, total: 2221
# fake frames:
# accurate: 1765, total: 10779
# real frames:
# accurate: 1780, total: 2392
# fake frames:
# accurate: 1787, total: 11608
# real frames:
# accurate: 1913, total: 2651
# fake frames:
# accurate: 2174, total: 12349
# real frames:
# accurate: 2091, total: 2877
# fake frames:
# accurate: 2247, total: 13123
# real frames:
# accurate: 2177, total: 2972
# fake frames:
# accurate: 2339, total: 14028
# real frames:
# accurate: 2276, total: 3084
# fake frames:
# accurate: 2413, total: 14916
# real frames:
# accurate: 2332, total: 3187
# fake frames:
# accurate: 2690, total: 15813
# real frames:
# accurate: 2455, total: 3346
# fake frames:
# accurate: 2901, total: 16654
# real frames:
# accurate: 2650, total: 3618
# fake frames:
# accurate: 3048, total: 17382
# real frames:
# accurate: 2809, total: 3814
# fake frames:
# accurate: 3113, total: 18186
# real frames:
# accurate: 2862, total: 3868
# fake frames:
# accurate: 3131, total: 19132
# real frames:
# accurate: 2872, total: 3977
# fake frames:
# accurate: 3838, total: 20023
# real frames:
# accurate: 2975, total: 4163
# fake frames:
# accurate: 4145, total: 20837
# real frames:
# accurate: 3142, total: 4402
# fake frames:
# accurate: 4291, total: 21598
# real frames:
# accurate: 3356, total: 4677
# fake frames:
# accurate: 4391, total: 22323
# real frames:
# accurate: 3474, total: 4798
# fake frames:
# accurate: 4403, total: 23202
# real frames:
# accurate: 3580, total: 4908
# fake frames:
# accurate: 4425, total: 24092
# real frames:
# accurate: 3715, total: 5075
# fake frames:
# accurate: 4513, total: 24925
# real frames:
# accurate: 3908, total: 5294
# fake frames:
# accurate: 4604, total: 25706
# real frames:
# accurate: 4085, total: 5533
# fake frames:
# accurate: 4732, total: 26467
# real frames:
# accurate: 4220, total: 5688
# fake frames:
# accurate: 4780, total: 27312
# real frames:
# accurate: 4309, total: 5780
# fake frames:
# accurate: 4842, total: 28220
# real frames:
# accurate: 4409, total: 5915
# fake frames:
# accurate: 5108, total: 29085
# real frames:
# accurate: 4546, total: 6114
# fake frames:
# accurate: 5345, total: 29886
# real frames:
# accurate: 4701, total: 6443
# fake frames:
# accurate: 5624, total: 30557
# real frames:
# accurate: 4723, total: 6537
# fake frames:
# accurate: 6255, total: 31463
# real frames:
# accurate: 4815, total: 6691
# fake frames:
# accurate: 6545, total: 32309
# real frames:
# accurate: 5066, total: 6975
# fake frames:
# accurate: 6593, total: 33025
# real frames:
# accurate: 5267, total: 7206
# fake frames:
# accurate: 6664, total: 33794
# real frames:
# accurate: 5435, total: 7394
# fake frames:
# accurate: 6692, total: 34606
# real frames:
# accurate: 5487, total: 7447
# fake frames:
# accurate: 6708, total: 35553
# real frames:
# accurate: 5601, total: 7573
# fake frames:
# accurate: 6778, total: 36427
# real frames:
# accurate: 5737, total: 7729
# fake frames:
# accurate: 6923, total: 37271
# real frames:
# accurate: 5983, total: 8005
# fake frames:
# accurate: 7011, total: 37995
# real frames:
# accurate: 6182, total: 8333
# fake frames:
# accurate: 7253, total: 38667
# real frames:
# accurate: 6305, total: 8461
# fake frames:
# accurate: 7296, total: 39539
# real frames:
# accurate: 6403, total: 8580
# fake frames:
# accurate: 7438, total: 40420
# real frames:
# accurate: 6555, total: 8799
# fake frames:
# accurate: 7644, total: 41201
# real frames:
# accurate: 236, total: 347
# fake frames:
# accurate: 184, total: 653
# real frames:
# accurate: 342, total: 486
# fake frames:
# accurate: 336, total: 1514
# real frames:
# accurate: 415, total: 568
# fake frames:
# accurate: 459, total: 2432
# real frames:
# accurate: 571, total: 754
# fake frames:
# accurate: 526, total: 3246
# real frames:
# accurate: 706, total: 952
# fake frames:
# accurate: 697, total: 4048
# real frames:
# accurate: 852, total: 1148
# fake frames:
# accurate: 861, total: 4852
# real frames:
# accurate: 1014, total: 1407
# fake frames:
# accurate: 1029, total: 5593
# real frames:
# accurate: 1191, total: 1607
# fake frames:
# accurate: 1092, total: 6393
# real frames:
# accurate: 1279, total: 1725
# fake frames:
# accurate: 1315, total: 7275
# real frames:
# accurate: 1406, total: 1884
# fake frames:
# accurate: 1451, total: 8116
# real frames:
# accurate: 1613, total: 2108
# fake frames:
# accurate: 1514, total: 8892
# real frames:
# accurate: 1797, total: 2314
# fake frames:
# accurate: 1654, total: 9686
# real frames:
# accurate: 1855, total: 2409
# fake frames:
# accurate: 1896, total: 10591
# real frames:
# accurate: 1929, total: 2541
# fake frames:
# accurate: 2216, total: 11459
# real frames:
# accurate: 2038, total: 2757
# fake frames:
# accurate: 2497, total: 12243
# real frames:
# accurate: 2254, total: 3035
# fake frames:
# accurate: 2678, total: 12965
# real frames:
# accurate: 2336, total: 3181
# fake frames:
# accurate: 3296, total: 13819
# real frames:
# accurate: 2372, total: 3303
# fake frames:
# accurate: 3962, total: 14697
# real frames:
# accurate: 2427, total: 3412
# fake frames:
# accurate: 4442, total: 15588
# real frames:
# accurate: 2520, total: 3550
# fake frames:
# accurate: 4736, total: 16450
# real frames:
# accurate: 2677, total: 3727
# fake frames:
# accurate: 4823, total: 17273
# real frames:
# accurate: 2869, total: 3972
# fake frames:
# accurate: 4930, total: 18028
# real frames:
# accurate: 3007, total: 4135
# fake frames:
# accurate: 5105, total: 18865
# real frames:
# accurate: 3081, total: 4238
# fake frames:
# accurate: 5321, total: 19762
# real frames:
# accurate: 3197, total: 4404
# fake frames:
# accurate: 5511, total: 20596
# real frames:
# accurate: 3320, total: 4567
# fake frames:
# accurate: 5658, total: 21433
# real frames:
# accurate: 3452, total: 4709
# fake frames:
# accurate: 5696, total: 22291
# real frames:
# accurate: 3712, total: 5004
# fake frames:
# accurate: 5786, total: 22996
# real frames:
# accurate: 3790, total: 5092
# fake frames:
# accurate: 5798, total: 23908
# real frames:
# accurate: 3837, total: 5144
# fake frames:
# accurate: 5880, total: 24856
# real frames:
# accurate: 3894, total: 5273
# fake frames:
# accurate: 6173, total: 25727
# real frames:
# accurate: 3947, total: 5554
# fake frames:
# accurate: 6745, total: 26446
# real frames:
# accurate: 4092, total: 5779
# fake frames:
# accurate: 7053, total: 27221
# real frames:
# accurate: 4153, total: 5897
# fake frames:
# accurate: 7442, total: 28103
# real frames:
# accurate: 4234, total: 5984
# fake frames:
# accurate: 7510, total: 29016
# real frames:
# accurate: 4381, total: 6133
# fake frames:
# accurate: 7537, total: 29867
# real frames:
# accurate: 4585, total: 6340
# fake frames:
# accurate: 7551, total: 30660
# real frames:
# accurate: 4906, total: 6685
# fake frames:
# accurate: 7632, total: 31315
# real frames:
# accurate: 4969, total: 6809
# fake frames:
# accurate: 8146, total: 32191
# real frames:
# accurate: 5022, total: 6929
# fake frames:
# accurate: 8658, total: 33071
# real frames:
# accurate: 5161, total: 7109
# fake frames:
# accurate: 8837, total: 33891
# real frames:
# accurate: 5265, total: 7283
# fake frames:
# accurate: 9242, total: 34717
# real frames:
# accurate: 5563, total: 7606
# fake frames:
# accurate: 9275, total: 35394
# real frames:
# accurate: 5737, total: 7797
# fake frames:
# accurate: 9392, total: 36203
# real frames:
# accurate: 5813, total: 7909
# fake frames:
# accurate: 9612, total: 37091
# real frames:
# accurate: 5868, total: 8023
# fake frames:
# accurate: 10028, total: 37977
# real frames:
# accurate: 5962, total: 8121
# fake frames:
# accurate: 10083, total: 38879
# real frames:
# accurate: 6126, total: 8301
# fake frames:
# accurate: 10270, total: 39699
# real frames:
# accurate: 6392, total: 8620
# fake frames:
# accurate: 10352, total: 40380
# real frames:
# accurate: 6505, total: 8761
# fake frames:
# accurate: 10488, total: 41239
# real frames:
# accurate: 6570, total: 8866
# fake frames:
# accurate: 10814, total: 42134
# real frames:
# accurate: 67, total: 131
# fake frames:
# accurate: 380, total: 869
# real frames:
# accurate: 234, total: 363
# fake frames:
# accurate: 589, total: 1637
# real frames:
# accurate: 436, total: 686
# fake frames:
# accurate: 778, total: 2314
# real frames:
# accurate: 543, total: 813
# fake frames:
# accurate: 915, total: 3187
# real frames:
# accurate: 643, total: 927
# fake frames:
# accurate: 1016, total: 4073
# real frames:
# accurate: 720, total: 1004
# fake frames:
# accurate: 1019, total: 4996
# real frames:
# accurate: 899, total: 1211
# fake frames:
# accurate: 1134, total: 5789
# real frames:
# accurate: 1140, total: 1489
# fake frames:
# accurate: 1214, total: 6511
# real frames:
# accurate: 1284, total: 1656
# fake frames:
# accurate: 1265, total: 7344
# real frames:
# accurate: 1381, total: 1758
# fake frames:
# accurate: 1309, total: 8242
# real frames:
# accurate: 1500, total: 1919
# fake frames:
# accurate: 1462, total: 9081
# real frames:
# accurate: 1601, total: 2061
# fake frames:
# accurate: 1732, total: 9939
# real frames:
# accurate: 1687, total: 2196
# fake frames:
# accurate: 2025, total: 10804
# real frames:
# accurate: 1813, total: 2361
# fake frames:
# accurate: 2251, total: 11639
# real frames:
# accurate: 2076, total: 2698
# fake frames:
# accurate: 2392, total: 12302
# real frames:
# accurate: 2202, total: 2863
# fake frames:
# accurate: 2490, total: 13137
# real frames:
# accurate: 2284, total: 2946
# fake frames:
# accurate: 2494, total: 14054
# real frames:
# accurate: 2351, total: 3050
# fake frames:
# accurate: 2823, total: 14950
# real frames:
# accurate: 2405, total: 3163
# fake frames:
# accurate: 3283, total: 15837
# real frames:
# accurate: 2531, total: 3329
# fake frames:
# accurate: 3440, total: 16671
# real frames:
# accurate: 2797, total: 3702
# fake frames:
# accurate: 3570, total: 17298
# real frames:
# accurate: 2889, total: 3821
# fake frames:
# accurate: 3802, total: 18179
# real frames:
# accurate: 2974, total: 3946
# fake frames:
# accurate: 4150, total: 19054
# real frames:
# accurate: 3033, total: 4053
# fake frames:
# accurate: 4640, total: 19947
# real frames:
# accurate: 3167, total: 4199
# fake frames:
# accurate: 4804, total: 20801
# real frames:
# accurate: 3347, total: 4399
# fake frames:
# accurate: 4859, total: 21601
# real frames:
# accurate: 3520, total: 4709
# fake frames:
# accurate: 5080, total: 22291
# real frames:
# accurate: 3639, total: 4871
# fake frames:
# accurate: 5250, total: 23129
# real frames:
# accurate: 3703, total: 4994
# fake frames:
# accurate: 5624, total: 24006
# real frames:
# accurate: 3768, total: 5128
# fake frames:
# accurate: 6061, total: 24872
# real frames:
# accurate: 3910, total: 5375
# fake frames:
# accurate: 6318, total: 25625
# real frames:
# accurate: 4021, total: 5633
# fake frames:
# accurate: 6599, total: 26367
# real frames:
# accurate: 4133, total: 5785
# fake frames:
# accurate: 6785, total: 27215
# real frames:
# accurate: 4241, total: 5906
# fake frames:
# accurate: 6837, total: 28094
# real frames:
# accurate: 4377, total: 6046
# fake frames:
# accurate: 6898, total: 28954
# real frames:
# accurate: 4575, total: 6275
# fake frames:
# accurate: 6981, total: 29725
# real frames:
# accurate: 4788, total: 6513
# fake frames:
# accurate: 7059, total: 30487
# real frames:
# accurate: 4884, total: 6610
# fake frames:
# accurate: 7088, total: 31390
# real frames:
# accurate: 5034, total: 6760
# fake frames:
# accurate: 7097, total: 32240
# real frames:
# accurate: 5146, total: 6872
# fake frames:
# accurate: 7100, total: 33128
# real frames:
# accurate: 5343, total: 7137
# fake frames:
# accurate: 7284, total: 33863
# real frames:
# accurate: 5581, total: 7405
# fake frames:
# accurate: 7403, total: 34595
# real frames:
# accurate: 5698, total: 7544
# fake frames:
# accurate: 7593, total: 35456
# real frames:
# accurate: 5795, total: 7672
# fake frames:
# accurate: 7687, total: 36328
# real frames:
# accurate: 5924, total: 7808
# fake frames:
# accurate: 7738, total: 37192
# real frames:
# accurate: 6050, total: 7996
# fake frames:
# accurate: 8029, total: 38004
# real frames:
# accurate: 6205, total: 8233
# fake frames:
# accurate: 8340, total: 38767
# real frames:
# accurate: 6340, total: 8388
# fake frames:
# accurate: 8392, total: 39612
# real frames:
# accurate: 6465, total: 8528
# fake frames:
# accurate: 8447, total: 40472
# real frames:
# accurate: 6568, total: 8654
# fake frames:
# accurate: 8590, total: 41346
# real frames:
# accurate: 6700, total: 8790
# fake frames:
# accurate: 8643, total: 42210
# real frames:
# accurate: 6857, total: 8949
# fake frames:
# accurate: 8666, total: 43051
# real frames:
# accurate: 7042, total: 9138
# fake frames:
# accurate: 8734, total: 43862
# real frames:
# accurate: 7165, total: 9266
# fake frames:
# accurate: 8843, total: 44734

# %%
print('{}/{} real frames predicted correctly, and {}/{} fake frames predicted correctly'.format(correct_real,
                                                                                                total_real,
                                                                                                correct_fake,
                                                                                                total_fake))
# Out:
# 32182/42036 real frames predicted correctly, and 44337/222156 fake frames predicted correctly

# %%
prediction_df.to_csv('predictions1.csv')
