# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.cloud import storage
from google.oauth2 import service_account
import os

# %%
from google.cloud import storage
try:
    from google.colab import auth
    auth.authenticate_user()
    credentials=None
except ModuleNotFoundError:

    credentials = service_account.Credentials.from_service_account_file( #file location of GCS private key
        '/Users/jeremiahherberg/Downloads/deepfake-research-a6b5e4f02da6.json')

# %%
client = storage.Client(project='deepfake-research', credentials=credentials)
video_frame_bucket_name = 'deepfake-dataset'
#bucket containing test data
video_frame_bucket = client.bucket(video_frame_bucket_name)
model_bucket_name = 'jh-gan-testing'
#bucket containing model
model_bucket = client.bucket(model_bucket_name)

# %%
#download and load model
model_name = 'disc_3.h5'
model_blob = model_bucket.blob(model_name)
model_blob.download_to_filename(model_name)
model = tf.keras.models.load_model(model_name)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
def make_single_prediction(frame,
                          frame_shape=(225, 146, 3),
                          model_input_shape=(192, 128, 3),
                          model=model):
    '''
    function to make a prediction if a single frame in test dataset is real or not
    
    inputs:
        frame - array with a shape of (frame_shape[0] * frame_shape[1] * frame_shape[2],)
        
        frame_shape - tuple that describes the shape of the image, defaults to (225, 146, 3)
        the last dim must be 3 (RGB)
        
        model_input_shape - tuple that describes the shape of the input that will be passed into model
        defaults to (192, 128, 3), the last dim must be 3 (RGB)
        
        model - tensorflow model that will be used to make prediction, defaults to 'model'
    returns:
        prediction - Bool, True if model predicts frame is real, False if prediction is frame is fake
        raw_prediction - float, range of -inf to inf, negative number indicates prediction is that 
        frame is fake and positive indicates the prediction is the frame is real
        the closer to 0 the raw_prediction, the less confident the model is
    ''' 
    assert(frame_shape[2] == model_input_shape[2] == 3), 'the last dim must equal 3 in the model and frame shapes'
    frame_reshaped = frame.reshape(frame_shape)
    #resize frame to be compatable with model
    frame_resized = tf.image.resize_with_pad(frame_reshaped, model_input_shape[0], model_input_shape[1])
    # (H, W, RGB) -> (1, H, W, RGB)
    frame_expanded = tf.expand_dims(frame_resized, 0)
    #convert values to between -1 and 1 (0 to 255 -> -1 to 1) (this is how the model was trained)
    frame_expanded = (tf.cast(frame_expanded, tf.float32) - 127.5) / 127.5
    #we are only making a single prediction
    raw_prediction = model.predict(frame_expanded)[0][0]
    
    if raw_prediction > 0:
        prediction = True
    else:
        prediction = False
    
    return prediction, raw_prediction

# %%
def prediction_batch(idx,
                    bucket=video_frame_bucket,
                    test_ds_file_name='face_arrays',
                    ground_file_name='labels_and_video_names'):
    '''
    function to make a batch of predictions 
    test dataset is split up into 5 files
    
    inputs:
        idx - int with a value between 1 to 5 that represents which test ds file is being used for predictions
        
        bucket - GCS bucket variable that contains files with test data, default is video_frame_bucket
        
        test_ds_file_name - str - beginning of file name of files containing test ds, default is face_arrays
        
        ground_file_name - str - beginning of file name of files containing the ground truth of each frame 
    
    returns:
        correct_real - int - the number of real frames correctly predicted
        
        total_real - int - total number of real frames
        
        correct_fake - int - the number of fake frames correctly predicted
        
        total_fake - int - total number of fake frames
        
        prediction_df - DataFrame  with the following columns:
            raw_prediction - float, range of -inf to inf, negative number indicates prediction
            is frame is fake and postive indicates the prediction is frame is real
            the closer to 0 of the value, the less confident the model is regarding the prediction
            
            accurate - Bool - reflects if the model accurately predicted if the frame is real or fake
            
            ground_truth - Bool - reflects if the frame is real or fake

    '''
    #downlaod files:
    ds_file_name = '{}{}.npz'.format(test_ds_file_name, idx)
    ground_file_name = '{}{}.csv'.format(ground_file_name, idx)
    ds_blob = bucket.blob('aaa_frames/' + ds_file_name)
    ds_blob.download_to_filename(ds_file_name)
    ground_blob = bucket.blob('aaa_frames/' + ground_file_name)
    ground_blob.download_to_filename(ground_file_name)
    
    data_file = np.load(ds_file_name)
    data = [data_file[key] for key in data_file]
    ground = pd.read_csv(ground_file_name)
    ground_list = ground['face_labels'].to_list()
    assert(len(ground_list) == len(data)), 'The len of the DS and ground truth do not match'
    
    total_real, total_fake, correct_real, correct_fake = 0, 0, 0, 0
    predictions = []
    ground_truths = []
    accurate_predictions = []
    
    for frame in range(len(data)):
        prediction, raw_prediction = make_single_prediction(data[frame])
        real = ground_list[frame]
        accurate_prediction = (real == prediction)
        if real:
            total_real +=1
            if accurate_prediction:
                correct_real +=1
        else:
            total_fake +=1
            if accurate_prediction: 
                correct_fake +=1
        predictions.append(raw_prediction)
        ground_truths.append(real)
        accurate_predictions.append(accurate_prediction)
        if frame % 1000 == 999:
          print('real frames:')
          print('accurate: {}, total: {}'.format(correct_real, total_real))
          print('fake frames:')
          print('accurate: {}, total: {} '.format(correct_fake, total_fake))
    
    
    preds_dictionary = {
        'raw_prediction':predictions,
        'accurate': accurate_predictions,
        'ground_truth': ground_truths
    }
    prediction_df = pd.DataFrame(preds_dictionary)
        
    return correct_real, total_real, correct_fake, total_fake, prediction_df

# %%
def make_predictions(start, end):
    '''
    function to make predictions on entire dataset
    
    inputs:
        start - int, starting file number in test dataset
        
        end - int, ending file number in test dataset, must be greater than or equal to start
        
    returns:
    correct_real - int - the number of real frames correctly predicted

    total_real - int - total number of real frames

    correct_fake - int - the number of fake frames correctly predicted

    total_fake - int - total number of fake frames

    prediction_df - DataFrame  with the following columns:
        raw_prediction - float, range of -inf to inf, negative number indicates prediction
        is frame is fake and postive indicates the prediction is frame is real
        the closer to 0 of the value, the less confident the model is regarding the prediction

        accurate - Bool - reflects if the model accurately predicted if the frame is real or fake

        ground_truth - Bool - reflects if the frame is real or fake
    '''
    
    assert(start <= end), 'start must be less than or equal to end'
    
    total_real, total_fake, correct_real, correct_fake = 0, 0, 0, 0
    prediction_dfs = []
    for file in np.arange(start, end+1):
        cor_real_batch, real_batch, cor_fake_batch, fake_batch, df_batch = prediction_batch(file)
        total_real += real_batch
        total_fake += fake_batch
        correct_real +=cor_real_batch
        correct_fake += cor_fake_batch
        prediction_dfs.append(df_batch)
    
    prediction_df = pd.concat(prediction_dfs)
    
    return total_real, total_fake, correct_real, correct_fake, prediction_df

# %%
with tf.device('/device:GPU:0'):
    total_real, total_fake, correct_real, correct_fake, prediction_df = make_predictions(1, 5)
# Out:
# real frames:
# accurate: 52, total: 52
# fake frames:
# accurate: 0, total: 948
# real frames:
# accurate: 127, total: 127
# fake frames:
# accurate: 0, total: 1873
# real frames:
# accurate: 203, total: 206
# fake frames:
# accurate: 27, total: 2794
# real frames:
# accurate: 275, total: 281
# fake frames:
# accurate: 125, total: 3719
# real frames:
# accurate: 324, total: 333
# fake frames:
# accurate: 223, total: 4667
# real frames:
# accurate: 362, total: 373
# fake frames:
# accurate: 319, total: 5627
# real frames:
# accurate: 431, total: 443
# fake frames:
# accurate: 331, total: 6557
# real frames:
# accurate: 501, total: 513
# fake frames:
# accurate: 331, total: 7487
# real frames:
# accurate: 567, total: 579
# fake frames:
# accurate: 332, total: 8421
# real frames:
# accurate: 662, total: 674
# fake frames:
# accurate: 332, total: 9326
# real frames:
# accurate: 934, total: 946
# fake frames:
# accurate: 332, total: 10054
# real frames:
# accurate: 1012, total: 1024
# fake frames:
# accurate: 332, total: 10976
# real frames:
# accurate: 1119, total: 1131
# fake frames:
# accurate: 332, total: 11869
# real frames:
# accurate: 1388, total: 1400
# fake frames:
# accurate: 332, total: 12600
# real frames:
# accurate: 1430, total: 1442
# fake frames:
# accurate: 332, total: 13558
# real frames:
# accurate: 1499, total: 1512
# fake frames:
# accurate: 332, total: 14488
# real frames:
# accurate: 1568, total: 1581
# fake frames:
# accurate: 332, total: 15419
# real frames:
# accurate: 1748, total: 1761
# fake frames:
# accurate: 332, total: 16239
# real frames:
# accurate: 1825, total: 1842
# fake frames:
# accurate: 407, total: 17158
# real frames:
# accurate: 1877, total: 1906
# fake frames:
# accurate: 494, total: 18094
# real frames:
# accurate: 1912, total: 1946
# fake frames:
# accurate: 592, total: 19054
# real frames:
# accurate: 1952, total: 2000
# fake frames:
# accurate: 685, total: 20000
# real frames:
# accurate: 2073, total: 2132
# fake frames:
# accurate: 745, total: 20868
# real frames:
# accurate: 2395, total: 2514
# fake frames:
# accurate: 843, total: 21486
# real frames:
# accurate: 2568, total: 2688
# fake frames:
# accurate: 843, total: 22312
# real frames:
# accurate: 2616, total: 2736
# fake frames:
# accurate: 843, total: 23264
# real frames:
# accurate: 2688, total: 2808
# fake frames:
# accurate: 843, total: 24192
# real frames:
# accurate: 2763, total: 2883
# fake frames:
# accurate: 843, total: 25117
# real frames:
# accurate: 2811, total: 2931
# fake frames:
# accurate: 844, total: 26069
# real frames:
# accurate: 2874, total: 2994
# fake frames:
# accurate: 844, total: 27006
# real frames:
# accurate: 3031, total: 3153
# fake frames:
# accurate: 845, total: 27847
# real frames:
# accurate: 3411, total: 3547
# fake frames:
# accurate: 863, total: 28453
# real frames:
# accurate: 3515, total: 3651
# fake frames:
# accurate: 867, total: 29349
# real frames:
# accurate: 3586, total: 3722
# fake frames:
# accurate: 867, total: 30278
# real frames:
# accurate: 3653, total: 3789
# fake frames:
# accurate: 867, total: 31211
# real frames:
# accurate: 3728, total: 3864
# fake frames:
# accurate: 867, total: 32136
# real frames:
# accurate: 3932, total: 4068
# fake frames:
# accurate: 869, total: 32932
# real frames:
# accurate: 4208, total: 4361
# fake frames:
# accurate: 893, total: 33639
# real frames:
# accurate: 4285, total: 4439
# fake frames:
# accurate: 913, total: 34561
# real frames:
# accurate: 4366, total: 4525
# fake frames:
# accurate: 928, total: 35475
# real frames:
# accurate: 4574, total: 4736
# fake frames:
# accurate: 957, total: 36264
# real frames:
# accurate: 4829, total: 4994
# fake frames:
# accurate: 964, total: 37006
# real frames:
# accurate: 4897, total: 5062
# fake frames:
# accurate: 964, total: 37938
# real frames:
# accurate: 5017, total: 5182
# fake frames:
# accurate: 966, total: 38818
# real frames:
# accurate: 5241, total: 5408
# fake frames:
# accurate: 974, total: 39592
# real frames:
# accurate: 5429, total: 5615
# fake frames:
# accurate: 1026, total: 40385
# real frames:
# accurate: 5481, total: 5667
# fake frames:
# accurate: 1073, total: 41333
# real frames:
# accurate: 5515, total: 5701
# fake frames:
# accurate: 1125, total: 42299
# real frames:
# accurate: 5558, total: 5744
# fake frames:
# accurate: 1175, total: 43256
# real frames:
# accurate: 5617, total: 5804
# fake frames:
# accurate: 1218, total: 44196
# real frames:
# accurate: 5649, total: 5837
# fake frames:
# accurate: 1258, total: 45163
# real frames:
# accurate: 5687, total: 5878
# fake frames:
# accurate: 1314, total: 46122
# real frames:
# accurate: 5849, total: 6051
# fake frames:
# accurate: 1378, total: 46949
# real frames:
# accurate: 6148, total: 6363
# fake frames:
# accurate: 1426, total: 47637
# real frames:
# accurate: 6292, total: 6509
# fake frames:
# accurate: 1445, total: 48491
# real frames:
# accurate: 112, total: 114
# fake frames:
# accurate: 19, total: 886
# real frames:
# accurate: 369, total: 371
# fake frames:
# accurate: 19, total: 1629
# real frames:
# accurate: 667, total: 669
# fake frames:
# accurate: 19, total: 2331
# real frames:
# accurate: 723, total: 725
# fake frames:
# accurate: 30, total: 3275
# real frames:
# accurate: 776, total: 781
# fake frames:
# accurate: 34, total: 4219
# real frames:
# accurate: 840, total: 847
# fake frames:
# accurate: 48, total: 5153
# real frames:
# accurate: 1043, total: 1050
# fake frames:
# accurate: 77, total: 5950
# real frames:
# accurate: 1328, total: 1335
# fake frames:
# accurate: 78, total: 6665
# real frames:
# accurate: 1370, total: 1377
# fake frames:
# accurate: 79, total: 7623
# real frames:
# accurate: 1413, total: 1420
# fake frames:
# accurate: 80, total: 8580
# real frames:
# accurate: 1470, total: 1477
# fake frames:
# accurate: 82, total: 9523
# real frames:
# accurate: 1509, total: 1516
# fake frames:
# accurate: 82, total: 10484
# real frames:
# accurate: 1544, total: 1551
# fake frames:
# accurate: 82, total: 11449
# real frames:
# accurate: 1578, total: 1585
# fake frames:
# accurate: 83, total: 12415
# real frames:
# accurate: 1732, total: 1739
# fake frames:
# accurate: 96, total: 13261
# real frames:
# accurate: 1929, total: 1942
# fake frames:
# accurate: 134, total: 14058
# real frames:
# accurate: 2272, total: 2287
# fake frames:
# accurate: 141, total: 14713
# real frames:
# accurate: 2379, total: 2398
# fake frames:
# accurate: 168, total: 15602
# real frames:
# accurate: 2454, total: 2475
# fake frames:
# accurate: 200, total: 16525
# real frames:
# accurate: 2554, total: 2575
# fake frames:
# accurate: 220, total: 17425
# real frames:
# accurate: 2680, total: 2702
# fake frames:
# accurate: 222, total: 18298
# real frames:
# accurate: 2974, total: 2996
# fake frames:
# accurate: 223, total: 19004
# real frames:
# accurate: 3162, total: 3184
# fake frames:
# accurate: 230, total: 19816
# real frames:
# accurate: 3284, total: 3320
# fake frames:
# accurate: 276, total: 20680
# real frames:
# accurate: 3404, total: 3454
# fake frames:
# accurate: 445, total: 21546
# real frames:
# accurate: 3531, total: 3589
# fake frames:
# accurate: 516, total: 22411
# real frames:
# accurate: 3826, total: 3892
# fake frames:
# accurate: 544, total: 23108
# real frames:
# accurate: 3896, total: 3962
# fake frames:
# accurate: 544, total: 24038
# real frames:
# accurate: 4019, total: 4085
# fake frames:
# accurate: 544, total: 24915
# real frames:
# accurate: 4196, total: 4264
# fake frames:
# accurate: 564, total: 25736
# real frames:
# accurate: 4527, total: 4618
# fake frames:
# accurate: 624, total: 26382
# real frames:
# accurate: 4659, total: 4750
# fake frames:
# accurate: 624, total: 27250
# real frames:
# accurate: 4760, total: 4851
# fake frames:
# accurate: 625, total: 28149
# real frames:
# accurate: 4891, total: 4982
# fake frames:
# accurate: 625, total: 29018
# real frames:
# accurate: 5068, total: 5160
# fake frames:
# accurate: 626, total: 29840
# real frames:
# accurate: 5378, total: 5470
# fake frames:
# accurate: 628, total: 30530
# real frames:
# accurate: 5500, total: 5627
# fake frames:
# accurate: 632, total: 31373
# real frames:
# accurate: 5566, total: 5693
# fake frames:
# accurate: 633, total: 32307
# real frames:
# accurate: 5624, total: 5751
# fake frames:
# accurate: 633, total: 33249
# real frames:
# accurate: 5780, total: 5909
# fake frames:
# accurate: 675, total: 34091
# real frames:
# accurate: 5970, total: 6105
# fake frames:
# accurate: 694, total: 34895
# real frames:
# accurate: 6328, total: 6483
# fake frames:
# accurate: 756, total: 35517
# real frames:
# accurate: 6408, total: 6563
# fake frames:
# accurate: 756, total: 36437
# real frames:
# accurate: 6486, total: 6643
# fake frames:
# accurate: 771, total: 37357
# real frames:
# accurate: 6609, total: 6786
# fake frames:
# accurate: 942, total: 38214
# real frames:
# accurate: 6823, total: 7000
# fake frames:
# accurate: 942, total: 39000
# real frames:
# accurate: 7107, total: 7301
# fake frames:
# accurate: 976, total: 39699
# real frames:
# accurate: 7201, total: 7397
# fake frames:
# accurate: 982, total: 40603
# real frames:
# accurate: 7309, total: 7506
# fake frames:
# accurate: 995, total: 41494
# real frames:
# accurate: 7404, total: 7607
# fake frames:
# accurate: 1038, total: 42393
# real frames:
# accurate: 7567, total: 7784
# fake frames:
# accurate: 1120, total: 43216
# real frames:
# accurate: 7793, total: 8010
# fake frames:
# accurate: 1120, total: 43990
# real frames:
# accurate: 241, total: 241
# fake frames:
# accurate: 0, total: 759
# real frames:
# accurate: 312, total: 312
# fake frames:
# accurate: 2, total: 1688
# real frames:
# accurate: 409, total: 410
# fake frames:
# accurate: 2, total: 2590
# real frames:
# accurate: 565, total: 566
# fake frames:
# accurate: 28, total: 3434
# real frames:
# accurate: 840, total: 844
# fake frames:
# accurate: 35, total: 4156
# real frames:
# accurate: 1003, total: 1013
# fake frames:
# accurate: 37, total: 4987
# real frames:
# accurate: 1116, total: 1126
# fake frames:
# accurate: 38, total: 5874
# real frames:
# accurate: 1252, total: 1283
# fake frames:
# accurate: 118, total: 6717
# real frames:
# accurate: 1446, total: 1487
# fake frames:
# accurate: 179, total: 7513
# real frames:
# accurate: 1784, total: 1840
# fake frames:
# accurate: 218, total: 8160
# real frames:
# accurate: 1941, total: 2015
# fake frames:
# accurate: 237, total: 8985
# real frames:
# accurate: 2012, total: 2086
# fake frames:
# accurate: 238, total: 9914
# real frames:
# accurate: 2147, total: 2221
# fake frames:
# accurate: 238, total: 10779
# real frames:
# accurate: 2318, total: 2392
# fake frames:
# accurate: 238, total: 11608
# real frames:
# accurate: 2556, total: 2651
# fake frames:
# accurate: 270, total: 12349
# real frames:
# accurate: 2782, total: 2877
# fake frames:
# accurate: 270, total: 13123
# real frames:
# accurate: 2877, total: 2972
# fake frames:
# accurate: 270, total: 14028
# real frames:
# accurate: 2989, total: 3084
# fake frames:
# accurate: 270, total: 14916
# real frames:
# accurate: 3089, total: 3187
# fake frames:
# accurate: 324, total: 15813
# real frames:
# accurate: 3232, total: 3346
# fake frames:
# accurate: 394, total: 16654
# real frames:
# accurate: 3484, total: 3618
# fake frames:
# accurate: 464, total: 17382
# real frames:
# accurate: 3674, total: 3814
# fake frames:
# accurate: 479, total: 18186
# real frames:
# accurate: 3728, total: 3868
# fake frames:
# accurate: 479, total: 19132
# real frames:
# accurate: 3799, total: 3977
# fake frames:
# accurate: 626, total: 20023
# real frames:
# accurate: 3978, total: 4163
# fake frames:
# accurate: 668, total: 20837
# real frames:
# accurate: 4214, total: 4402
# fake frames:
# accurate: 674, total: 21598
# real frames:
# accurate: 4470, total: 4677
# fake frames:
# accurate: 703, total: 22323
# real frames:
# accurate: 4591, total: 4798
# fake frames:
# accurate: 705, total: 23202
# real frames:
# accurate: 4701, total: 4908
# fake frames:
# accurate: 713, total: 24092
# real frames:
# accurate: 4868, total: 5075
# fake frames:
# accurate: 715, total: 24925
# real frames:
# accurate: 5087, total: 5294
# fake frames:
# accurate: 715, total: 25706
# real frames:
# accurate: 5320, total: 5533
# fake frames:
# accurate: 726, total: 26467
# real frames:
# accurate: 5474, total: 5688
# fake frames:
# accurate: 726, total: 27312
# real frames:
# accurate: 5566, total: 5780
# fake frames:
# accurate: 726, total: 28220
# real frames:
# accurate: 5701, total: 5915
# fake frames:
# accurate: 727, total: 29085
# real frames:
# accurate: 5900, total: 6114
# fake frames:
# accurate: 736, total: 29886
# real frames:
# accurate: 6146, total: 6443
# fake frames:
# accurate: 806, total: 30557
# real frames:
# accurate: 6240, total: 6537
# fake frames:
# accurate: 900, total: 31463
# real frames:
# accurate: 6391, total: 6691
# fake frames:
# accurate: 918, total: 32309
# real frames:
# accurate: 6675, total: 6975
# fake frames:
# accurate: 918, total: 33025
# real frames:
# accurate: 6906, total: 7206
# fake frames:
# accurate: 918, total: 33794
# real frames:
# accurate: 7094, total: 7394
# fake frames:
# accurate: 918, total: 34606
# real frames:
# accurate: 7146, total: 7447
# fake frames:
# accurate: 918, total: 35553
# real frames:
# accurate: 7272, total: 7573
# fake frames:
# accurate: 918, total: 36427
# real frames:
# accurate: 7428, total: 7729
# fake frames:
# accurate: 918, total: 37271
# real frames:
# accurate: 7703, total: 8005
# fake frames:
# accurate: 922, total: 37995
# real frames:
# accurate: 8018, total: 8333
# fake frames:
# accurate: 944, total: 38667
# real frames:
# accurate: 8146, total: 8461
# fake frames:
# accurate: 944, total: 39539
# real frames:
# accurate: 8265, total: 8580
# fake frames:
# accurate: 944, total: 40420
# real frames:
# accurate: 8483, total: 8799
# fake frames:
# accurate: 949, total: 41201
# real frames:
# accurate: 329, total: 347
# fake frames:
# accurate: 37, total: 653
# real frames:
# accurate: 460, total: 486
# fake frames:
# accurate: 41, total: 1514
# real frames:
# accurate: 542, total: 568
# fake frames:
# accurate: 42, total: 2432
# real frames:
# accurate: 728, total: 754
# fake frames:
# accurate: 42, total: 3246
# real frames:
# accurate: 925, total: 952
# fake frames:
# accurate: 46, total: 4048
# real frames:
# accurate: 1116, total: 1148
# fake frames:
# accurate: 58, total: 4852
# real frames:
# accurate: 1358, total: 1407
# fake frames:
# accurate: 91, total: 5593
# real frames:
# accurate: 1558, total: 1607
# fake frames:
# accurate: 91, total: 6393
# real frames:
# accurate: 1676, total: 1725
# fake frames:
# accurate: 92, total: 7275
# real frames:
# accurate: 1834, total: 1884
# fake frames:
# accurate: 92, total: 8116
# real frames:
# accurate: 2058, total: 2108
# fake frames:
# accurate: 92, total: 8892
# real frames:
# accurate: 2248, total: 2314
# fake frames:
# accurate: 117, total: 9686
# real frames:
# accurate: 2341, total: 2409
# fake frames:
# accurate: 168, total: 10591
# real frames:
# accurate: 2473, total: 2541
# fake frames:
# accurate: 244, total: 11459
# real frames:
# accurate: 2687, total: 2757
# fake frames:
# accurate: 269, total: 12243
# real frames:
# accurate: 2955, total: 3035
# fake frames:
# accurate: 286, total: 12965
# real frames:
# accurate: 3086, total: 3181
# fake frames:
# accurate: 474, total: 13819
# real frames:
# accurate: 3181, total: 3303
# fake frames:
# accurate: 797, total: 14697
# real frames:
# accurate: 3268, total: 3412
# fake frames:
# accurate: 945, total: 15588
# real frames:
# accurate: 3402, total: 3550
# fake frames:
# accurate: 986, total: 16450
# real frames:
# accurate: 3579, total: 3727
# fake frames:
# accurate: 986, total: 17273
# real frames:
# accurate: 3823, total: 3972
# fake frames:
# accurate: 986, total: 18028
# real frames:
# accurate: 3980, total: 4135
# fake frames:
# accurate: 1054, total: 18865
# real frames:
# accurate: 4082, total: 4238
# fake frames:
# accurate: 1117, total: 19762
# real frames:
# accurate: 4248, total: 4404
# fake frames:
# accurate: 1117, total: 20596
# real frames:
# accurate: 4405, total: 4567
# fake frames:
# accurate: 1133, total: 21433
# real frames:
# accurate: 4547, total: 4709
# fake frames:
# accurate: 1134, total: 22291
# real frames:
# accurate: 4834, total: 5004
# fake frames:
# accurate: 1146, total: 22996
# real frames:
# accurate: 4922, total: 5092
# fake frames:
# accurate: 1146, total: 23908
# real frames:
# accurate: 4974, total: 5144
# fake frames:
# accurate: 1147, total: 24856
# real frames:
# accurate: 5081, total: 5273
# fake frames:
# accurate: 1245, total: 25727
# real frames:
# accurate: 5259, total: 5554
# fake frames:
# accurate: 1462, total: 26446
# real frames:
# accurate: 5468, total: 5779
# fake frames:
# accurate: 1558, total: 27221
# real frames:
# accurate: 5575, total: 5897
# fake frames:
# accurate: 1636, total: 28103
# real frames:
# accurate: 5662, total: 5984
# fake frames:
# accurate: 1636, total: 29016
# real frames:
# accurate: 5811, total: 6133
# fake frames:
# accurate: 1636, total: 29867
# real frames:
# accurate: 6018, total: 6340
# fake frames:
# accurate: 1636, total: 30660
# real frames:
# accurate: 6363, total: 6685
# fake frames:
# accurate: 1636, total: 31315
# real frames:
# accurate: 6486, total: 6809
# fake frames:
# accurate: 1722, total: 32191
# real frames:
# accurate: 6597, total: 6929
# fake frames:
# accurate: 1806, total: 33071
# real frames:
# accurate: 6762, total: 7109
# fake frames:
# accurate: 1863, total: 33891
# real frames:
# accurate: 6924, total: 7283
# fake frames:
# accurate: 1909, total: 34717
# real frames:
# accurate: 7247, total: 7606
# fake frames:
# accurate: 1909, total: 35394
# real frames:
# accurate: 7438, total: 7797
# fake frames:
# accurate: 1917, total: 36203
# real frames:
# accurate: 7549, total: 7909
# fake frames:
# accurate: 1933, total: 37091
# real frames:
# accurate: 7655, total: 8023
# fake frames:
# accurate: 2037, total: 37977
# real frames:
# accurate: 7753, total: 8121
# fake frames:
# accurate: 2051, total: 38879
# real frames:
# accurate: 7933, total: 8301
# fake frames:
# accurate: 2052, total: 39699
# real frames:
# accurate: 8251, total: 8620
# fake frames:
# accurate: 2053, total: 40380
# real frames:
# accurate: 8391, total: 8761
# fake frames:
# accurate: 2063, total: 41239
# real frames:
# accurate: 8484, total: 8866
# fake frames:
# accurate: 2153, total: 42134
# real frames:
# accurate: 123, total: 131
# fake frames:
# accurate: 42, total: 869
# real frames:
# accurate: 338, total: 363
# fake frames:
# accurate: 117, total: 1637
# real frames:
# accurate: 655, total: 686
# fake frames:
# accurate: 125, total: 2314
# real frames:
# accurate: 782, total: 813
# fake frames:
# accurate: 129, total: 3187
# real frames:
# accurate: 895, total: 927
# fake frames:
# accurate: 135, total: 4073
# real frames:
# accurate: 972, total: 1004
# fake frames:
# accurate: 135, total: 4996
# real frames:
# accurate: 1179, total: 1211
# fake frames:
# accurate: 135, total: 5789
# real frames:
# accurate: 1448, total: 1489
# fake frames:
# accurate: 147, total: 6511
# real frames:
# accurate: 1613, total: 1656
# fake frames:
# accurate: 168, total: 7344
# real frames:
# accurate: 1715, total: 1758
# fake frames:
# accurate: 168, total: 8242
# real frames:
# accurate: 1874, total: 1919
# fake frames:
# accurate: 168, total: 9081
# real frames:
# accurate: 2014, total: 2061
# fake frames:
# accurate: 171, total: 9939
# real frames:
# accurate: 2148, total: 2196
# fake frames:
# accurate: 188, total: 10804
# real frames:
# accurate: 2311, total: 2361
# fake frames:
# accurate: 195, total: 11639
# real frames:
# accurate: 2646, total: 2698
# fake frames:
# accurate: 198, total: 12302
# real frames:
# accurate: 2811, total: 2863
# fake frames:
# accurate: 201, total: 13137
# real frames:
# accurate: 2894, total: 2946
# fake frames:
# accurate: 201, total: 14054
# real frames:
# accurate: 2998, total: 3050
# fake frames:
# accurate: 208, total: 14950
# real frames:
# accurate: 3109, total: 3163
# fake frames:
# accurate: 217, total: 15837
# real frames:
# accurate: 3275, total: 3329
# fake frames:
# accurate: 217, total: 16671
# real frames:
# accurate: 3642, total: 3702
# fake frames:
# accurate: 222, total: 17298
# real frames:
# accurate: 3757, total: 3821
# fake frames:
# accurate: 357, total: 18179
# real frames:
# accurate: 3866, total: 3946
# fake frames:
# accurate: 545, total: 19054
# real frames:
# accurate: 3949, total: 4053
# fake frames:
# accurate: 799, total: 19947
# real frames:
# accurate: 4095, total: 4199
# fake frames:
# accurate: 818, total: 20801
# real frames:
# accurate: 4295, total: 4399
# fake frames:
# accurate: 819, total: 21601
# real frames:
# accurate: 4604, total: 4709
# fake frames:
# accurate: 840, total: 22291
# real frames:
# accurate: 4763, total: 4871
# fake frames:
# accurate: 848, total: 23129
# real frames:
# accurate: 4877, total: 4994
# fake frames:
# accurate: 946, total: 24006
# real frames:
# accurate: 4985, total: 5128
# fake frames:
# accurate: 1112, total: 24872
# real frames:
# accurate: 5216, total: 5375
# fake frames:
# accurate: 1187, total: 25625
# real frames:
# accurate: 5455, total: 5633
# fake frames:
# accurate: 1220, total: 26367
# real frames:
# accurate: 5601, total: 5785
# fake frames:
# accurate: 1238, total: 27215
# real frames:
# accurate: 5720, total: 5906
# fake frames:
# accurate: 1241, total: 28094
# real frames:
# accurate: 5860, total: 6046
# fake frames:
# accurate: 1241, total: 28954
# real frames:
# accurate: 6089, total: 6275
# fake frames:
# accurate: 1241, total: 29725
# real frames:
# accurate: 6326, total: 6513
# fake frames:
# accurate: 1244, total: 30487
# real frames:
# accurate: 6423, total: 6610
# fake frames:
# accurate: 1244, total: 31390
# real frames:
# accurate: 6573, total: 6760
# fake frames:
# accurate: 1244, total: 32240
# real frames:
# accurate: 6685, total: 6872
# fake frames:
# accurate: 1244, total: 33128
# real frames:
# accurate: 6948, total: 7137
# fake frames:
# accurate: 1246, total: 33863
# real frames:
# accurate: 7207, total: 7405
# fake frames:
# accurate: 1266, total: 34595
# real frames:
# accurate: 7344, total: 7544
# fake frames:
# accurate: 1280, total: 35456
# real frames:
# accurate: 7472, total: 7672
# fake frames:
# accurate: 1280, total: 36328
# real frames:
# accurate: 7607, total: 7808
# fake frames:
# accurate: 1284, total: 37192
# real frames:
# accurate: 7792, total: 7996
# fake frames:
# accurate: 1299, total: 38004
# real frames:
# accurate: 7993, total: 8233
# fake frames:
# accurate: 1458, total: 38767
# real frames:
# accurate: 8146, total: 8388
# fake frames:
# accurate: 1464, total: 39612
# real frames:
# accurate: 8286, total: 8528
# fake frames:
# accurate: 1469, total: 40472
# real frames:
# accurate: 8411, total: 8654
# fake frames:
# accurate: 1471, total: 41346
# real frames:
# accurate: 8546, total: 8790
# fake frames:
# accurate: 1472, total: 42210
# real frames:
# accurate: 8705, total: 8949
# fake frames:
# accurate: 1472, total: 43051
# real frames:
# accurate: 8893, total: 9138
# fake frames:
# accurate: 1472, total: 43862
# real frames:
# accurate: 9021, total: 9266
# fake frames:
# accurate: 1479, total: 44734

# %%
print('{}/{} real frames predicted correctly, and {}/{} fake frames predicted correctly'.format(correct_real,
                                                                                                total_real,
                                                                                                correct_fake,
                                                                                                total_fake))
# Out:
# 40629/42036 real frames predicted correctly, and 7209/222156 fake frames predicted correctly

# %%
prediction_df.to_csv('predictions1.csv')
