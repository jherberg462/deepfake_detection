# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.cloud import storage
from google.oauth2 import service_account
import os

# %%
from google.cloud import storage
try:
    from google.colab import auth
    auth.authenticate_user()
    credentials=None
except ModuleNotFoundError:

    credentials = service_account.Credentials.from_service_account_file( #file location of GCS private key
        '/Users/jeremiahherberg/Downloads/deepfake-research-a6b5e4f02da6.json')

# %%
client = storage.Client(project='deepfake-research', credentials=credentials)
video_frame_bucket_name = 'deepfake-dataset'
#bucket containing test data
video_frame_bucket = client.bucket(video_frame_bucket_name)
model_bucket_name = 'jh-gan-testing'
#bucket containing model
model_bucket = client.bucket(model_bucket_name)

# %%
#download and load model
model_name = 'disc4_epoch200.h5'
model_blob = model_bucket.blob(model_name)
model_blob.download_to_filename(model_name)
model = tf.keras.models.load_model(model_name)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
def make_single_prediction(frame,
                          frame_shape=(225, 146, 3),
                          model_input_shape=(192, 128, 3),
                          model=model):
    '''
    function to make a prediction if a single frame in test dataset is real or not
    
    inputs:
        frame - array with a shape of (frame_shape[0] * frame_shape[1] * frame_shape[2],)
        
        frame_shape - tuple that describes the shape of the image, defaults to (225, 146, 3)
        the last dim must be 3 (RGB)
        
        model_input_shape - tuple that describes the shape of the input that will be passed into model
        defaults to (192, 128, 3), the last dim must be 3 (RGB)
        
        model - tensorflow model that will be used to make prediction, defaults to 'model'
    returns:
        prediction - Bool, True if model predicts frame is real, False if prediction is frame is fake
        raw_prediction - float, range of -inf to inf, negative number indicates prediction is that 
        frame is fake and positive indicates the prediction is the frame is real
        the closer to 0 the raw_prediction, the less confident the model is
    ''' 
    assert(frame_shape[2] == model_input_shape[2] == 3), 'the last dim must equal 3 in the model and frame shapes'
    frame_reshaped = frame.reshape(frame_shape)
    #resize frame to be compatable with model
    frame_resized = tf.image.resize_with_pad(frame_reshaped, model_input_shape[0], model_input_shape[1])
    # (H, W, RGB) -> (1, H, W, RGB)
    frame_expanded = tf.expand_dims(frame_resized, 0)
    #convert values to between -1 and 1 (0 to 255 -> -1 to 1) (this is how the model was trained)
    frame_expanded = (tf.cast(frame_expanded, tf.float32) - 127.5) / 127.5
    #we are only making a single prediction
    raw_prediction = model.predict(frame_expanded)[0][0]
    
    if raw_prediction > 0:
        prediction = True
    else:
        prediction = False
    
    return prediction, raw_prediction

# %%
def prediction_batch(idx,
                    bucket=video_frame_bucket,
                    test_ds_file_name='face_arrays',
                    ground_file_name='labels_and_video_names'):
    '''
    function to make a batch of predictions 
    test dataset is split up into 5 files
    
    inputs:
        idx - int with a value between 1 to 5 that represents which test ds file is being used for predictions
        
        bucket - GCS bucket variable that contains files with test data, default is video_frame_bucket
        
        test_ds_file_name - str - beginning of file name of files containing test ds, default is face_arrays
        
        ground_file_name - str - beginning of file name of files containing the ground truth of each frame 
    
    returns:
        correct_real - int - the number of real frames correctly predicted
        
        total_real - int - total number of real frames
        
        correct_fake - int - the number of fake frames correctly predicted
        
        total_fake - int - total number of fake frames
        
        prediction_df - DataFrame  with the following columns:
            raw_prediction - float, range of -inf to inf, negative number indicates prediction
            is frame is fake and postive indicates the prediction is frame is real
            the closer to 0 of the value, the less confident the model is regarding the prediction
            
            accurate - Bool - reflects if the model accurately predicted if the frame is real or fake
            
            ground_truth - Bool - reflects if the frame is real or fake

    '''
    #downlaod files:
    ds_file_name = '{}{}.npz'.format(test_ds_file_name, idx)
    ground_file_name = '{}{}.csv'.format(ground_file_name, idx)
    ds_blob = bucket.blob('aaa_frames/' + ds_file_name)
    ds_blob.download_to_filename(ds_file_name)
    ground_blob = bucket.blob('aaa_frames/' + ground_file_name)
    ground_blob.download_to_filename(ground_file_name)
    
    data_file = np.load(ds_file_name)
    data = [data_file[key] for key in data_file]
    ground = pd.read_csv(ground_file_name)
    ground_list = ground['face_labels'].to_list()
    assert(len(ground_list) == len(data)), 'The len of the DS and ground truth do not match'
    
    total_real, total_fake, correct_real, correct_fake = 0, 0, 0, 0
    predictions = []
    ground_truths = []
    accurate_predictions = []
    
    for frame in range(len(data)):
        prediction, raw_prediction = make_single_prediction(data[frame])
        real = ground_list[frame]
        accurate_prediction = (real == prediction)
        if real:
            total_real +=1
            if accurate_prediction:
                correct_real +=1
        else:
            total_fake +=1
            if accurate_prediction: 
                correct_fake +=1
        predictions.append(raw_prediction)
        ground_truths.append(real)
        accurate_predictions.append(accurate_prediction)
        if frame % 1000 == 999:
          print('real frames:')
          print('accurate: {}, total: {}'.format(correct_real, total_real))
          print('fake frames:')
          print('accurate: {}, total: {} '.format(correct_fake, total_fake))
    
    
    preds_dictionary = {
        'raw_prediction':predictions,
        'accurate': accurate_predictions,
        'ground_truth': ground_truths
    }
    prediction_df = pd.DataFrame(preds_dictionary)
        
    return correct_real, total_real, correct_fake, total_fake, prediction_df

# %%
def make_predictions(start, end):
    '''
    function to make predictions on entire dataset
    
    inputs:
        start - int, starting file number in test dataset
        
        end - int, ending file number in test dataset, must be greater than or equal to start
        
    returns:
    correct_real - int - the number of real frames correctly predicted

    total_real - int - total number of real frames

    correct_fake - int - the number of fake frames correctly predicted

    total_fake - int - total number of fake frames

    prediction_df - DataFrame  with the following columns:
        raw_prediction - float, range of -inf to inf, negative number indicates prediction
        is frame is fake and postive indicates the prediction is frame is real
        the closer to 0 of the value, the less confident the model is regarding the prediction

        accurate - Bool - reflects if the model accurately predicted if the frame is real or fake

        ground_truth - Bool - reflects if the frame is real or fake
    '''
    
    assert(start <= end), 'start must be less than or equal to end'
    
    total_real, total_fake, correct_real, correct_fake = 0, 0, 0, 0
    prediction_dfs = []
    for file in np.arange(start, end+1):
        cor_real_batch, real_batch, cor_fake_batch, fake_batch, df_batch = prediction_batch(file)
        total_real += real_batch
        total_fake += fake_batch
        correct_real +=cor_real_batch
        correct_fake += cor_fake_batch
        prediction_dfs.append(df_batch)
    
    prediction_df = pd.concat(prediction_dfs)
    
    return total_real, total_fake, correct_real, correct_fake, prediction_df

# %%
with tf.device('/device:GPU:0'):
    total_real, total_fake, correct_real, correct_fake, prediction_df = make_predictions(1, 5)
# Out:
# real frames:
# accurate: 45, total: 52
# fake frames:
# accurate: 181, total: 948
# real frames:
# accurate: 107, total: 127
# fake frames:
# accurate: 354, total: 1873
# real frames:
# accurate: 169, total: 206
# fake frames:
# accurate: 618, total: 2794
# real frames:
# accurate: 228, total: 281
# fake frames:
# accurate: 955, total: 3719
# real frames:
# accurate: 267, total: 333
# fake frames:
# accurate: 1310, total: 4667
# real frames:
# accurate: 297, total: 373
# fake frames:
# accurate: 1693, total: 5627
# real frames:
# accurate: 348, total: 443
# fake frames:
# accurate: 1897, total: 6557
# real frames:
# accurate: 397, total: 513
# fake frames:
# accurate: 2088, total: 7487
# real frames:
# accurate: 439, total: 579
# fake frames:
# accurate: 2258, total: 8421
# real frames:
# accurate: 503, total: 674
# fake frames:
# accurate: 2462, total: 9326
# real frames:
# accurate: 718, total: 946
# fake frames:
# accurate: 2572, total: 10054
# real frames:
# accurate: 794, total: 1024
# fake frames:
# accurate: 2630, total: 10976
# real frames:
# accurate: 895, total: 1131
# fake frames:
# accurate: 2652, total: 11869
# real frames:
# accurate: 1104, total: 1400
# fake frames:
# accurate: 2768, total: 12600
# real frames:
# accurate: 1141, total: 1442
# fake frames:
# accurate: 2992, total: 13558
# real frames:
# accurate: 1193, total: 1512
# fake frames:
# accurate: 3203, total: 14488
# real frames:
# accurate: 1242, total: 1581
# fake frames:
# accurate: 3396, total: 15419
# real frames:
# accurate: 1389, total: 1761
# fake frames:
# accurate: 3456, total: 16239
# real frames:
# accurate: 1419, total: 1842
# fake frames:
# accurate: 4158, total: 17158
# real frames:
# accurate: 1429, total: 1906
# fake frames:
# accurate: 4938, total: 18094
# real frames:
# accurate: 1435, total: 1946
# fake frames:
# accurate: 5722, total: 19054
# real frames:
# accurate: 1441, total: 2000
# fake frames:
# accurate: 6505, total: 20000
# real frames:
# accurate: 1531, total: 2132
# fake frames:
# accurate: 7040, total: 20868
# real frames:
# accurate: 1740, total: 2514
# fake frames:
# accurate: 7280, total: 21486
# real frames:
# accurate: 1900, total: 2688
# fake frames:
# accurate: 7333, total: 22312
# real frames:
# accurate: 1947, total: 2736
# fake frames:
# accurate: 7372, total: 23264
# real frames:
# accurate: 2018, total: 2808
# fake frames:
# accurate: 7407, total: 24192
# real frames:
# accurate: 2092, total: 2883
# fake frames:
# accurate: 7445, total: 25117
# real frames:
# accurate: 2140, total: 2931
# fake frames:
# accurate: 7482, total: 26069
# real frames:
# accurate: 2203, total: 2994
# fake frames:
# accurate: 7511, total: 27006
# real frames:
# accurate: 2343, total: 3153
# fake frames:
# accurate: 7553, total: 27847
# real frames:
# accurate: 2569, total: 3547
# fake frames:
# accurate: 7734, total: 28453
# real frames:
# accurate: 2636, total: 3651
# fake frames:
# accurate: 7840, total: 29349
# real frames:
# accurate: 2704, total: 3722
# fake frames:
# accurate: 7877, total: 30278
# real frames:
# accurate: 2767, total: 3789
# fake frames:
# accurate: 7902, total: 31211
# real frames:
# accurate: 2839, total: 3864
# fake frames:
# accurate: 7944, total: 32136
# real frames:
# accurate: 3035, total: 4068
# fake frames:
# accurate: 7966, total: 32932
# real frames:
# accurate: 3218, total: 4361
# fake frames:
# accurate: 8258, total: 33639
# real frames:
# accurate: 3264, total: 4439
# fake frames:
# accurate: 8557, total: 34561
# real frames:
# accurate: 3311, total: 4525
# fake frames:
# accurate: 8907, total: 35475
# real frames:
# accurate: 3479, total: 4736
# fake frames:
# accurate: 9112, total: 36264
# real frames:
# accurate: 3654, total: 4994
# fake frames:
# accurate: 9225, total: 37006
# real frames:
# accurate: 3714, total: 5062
# fake frames:
# accurate: 9404, total: 37938
# real frames:
# accurate: 3815, total: 5182
# fake frames:
# accurate: 9562, total: 38818
# real frames:
# accurate: 3890, total: 5408
# fake frames:
# accurate: 9887, total: 39592
# real frames:
# accurate: 3972, total: 5615
# fake frames:
# accurate: 10337, total: 40385
# real frames:
# accurate: 4003, total: 5667
# fake frames:
# accurate: 10789, total: 41333
# real frames:
# accurate: 4030, total: 5701
# fake frames:
# accurate: 11261, total: 42299
# real frames:
# accurate: 4053, total: 5744
# fake frames:
# accurate: 11752, total: 43256
# real frames:
# accurate: 4094, total: 5804
# fake frames:
# accurate: 12211, total: 44196
# real frames:
# accurate: 4103, total: 5837
# fake frames:
# accurate: 12673, total: 45163
# real frames:
# accurate: 4120, total: 5878
# fake frames:
# accurate: 13124, total: 46122
# real frames:
# accurate: 4216, total: 6051
# fake frames:
# accurate: 13451, total: 46949
# real frames:
# accurate: 4379, total: 6363
# fake frames:
# accurate: 13807, total: 47637
# real frames:
# accurate: 4455, total: 6509
# fake frames:
# accurate: 13947, total: 48491
# real frames:
# accurate: 58, total: 114
# fake frames:
# accurate: 216, total: 886
# real frames:
# accurate: 263, total: 371
# fake frames:
# accurate: 335, total: 1629
# real frames:
# accurate: 473, total: 669
# fake frames:
# accurate: 491, total: 2331
# real frames:
# accurate: 525, total: 725
# fake frames:
# accurate: 570, total: 3275
# real frames:
# accurate: 569, total: 781
# fake frames:
# accurate: 664, total: 4219
# real frames:
# accurate: 628, total: 847
# fake frames:
# accurate: 770, total: 5153
# real frames:
# accurate: 794, total: 1050
# fake frames:
# accurate: 959, total: 5950
# real frames:
# accurate: 1033, total: 1335
# fake frames:
# accurate: 1084, total: 6665
# real frames:
# accurate: 1070, total: 1377
# fake frames:
# accurate: 1171, total: 7623
# real frames:
# accurate: 1110, total: 1420
# fake frames:
# accurate: 1253, total: 8580
# real frames:
# accurate: 1161, total: 1477
# fake frames:
# accurate: 1343, total: 9523
# real frames:
# accurate: 1193, total: 1516
# fake frames:
# accurate: 1416, total: 10484
# real frames:
# accurate: 1224, total: 1551
# fake frames:
# accurate: 1482, total: 11449
# real frames:
# accurate: 1254, total: 1585
# fake frames:
# accurate: 1568, total: 12415
# real frames:
# accurate: 1383, total: 1739
# fake frames:
# accurate: 1800, total: 13261
# real frames:
# accurate: 1552, total: 1942
# fake frames:
# accurate: 1937, total: 14058
# real frames:
# accurate: 1799, total: 2287
# fake frames:
# accurate: 2148, total: 14713
# real frames:
# accurate: 1878, total: 2398
# fake frames:
# accurate: 2313, total: 15602
# real frames:
# accurate: 1945, total: 2475
# fake frames:
# accurate: 2503, total: 16525
# real frames:
# accurate: 2035, total: 2575
# fake frames:
# accurate: 2594, total: 17425
# real frames:
# accurate: 2145, total: 2702
# fake frames:
# accurate: 2653, total: 18298
# real frames:
# accurate: 2389, total: 2996
# fake frames:
# accurate: 2735, total: 19004
# real frames:
# accurate: 2558, total: 3184
# fake frames:
# accurate: 2819, total: 19816
# real frames:
# accurate: 2675, total: 3320
# fake frames:
# accurate: 2940, total: 20680
# real frames:
# accurate: 2772, total: 3454
# fake frames:
# accurate: 3213, total: 21546
# real frames:
# accurate: 2872, total: 3589
# fake frames:
# accurate: 3398, total: 22411
# real frames:
# accurate: 3078, total: 3892
# fake frames:
# accurate: 3644, total: 23108
# real frames:
# accurate: 3132, total: 3962
# fake frames:
# accurate: 3829, total: 24038
# real frames:
# accurate: 3250, total: 4085
# fake frames:
# accurate: 3861, total: 24915
# real frames:
# accurate: 3377, total: 4264
# fake frames:
# accurate: 4051, total: 25736
# real frames:
# accurate: 3607, total: 4618
# fake frames:
# accurate: 4266, total: 26382
# real frames:
# accurate: 3726, total: 4750
# fake frames:
# accurate: 4337, total: 27250
# real frames:
# accurate: 3813, total: 4851
# fake frames:
# accurate: 4445, total: 28149
# real frames:
# accurate: 3904, total: 4982
# fake frames:
# accurate: 4750, total: 29018
# real frames:
# accurate: 4037, total: 5160
# fake frames:
# accurate: 4932, total: 29840
# real frames:
# accurate: 4274, total: 5470
# fake frames:
# accurate: 5102, total: 30530
# real frames:
# accurate: 4376, total: 5627
# fake frames:
# accurate: 5197, total: 31373
# real frames:
# accurate: 4439, total: 5693
# fake frames:
# accurate: 5295, total: 32307
# real frames:
# accurate: 4493, total: 5751
# fake frames:
# accurate: 5384, total: 33249
# real frames:
# accurate: 4602, total: 5909
# fake frames:
# accurate: 5665, total: 34091
# real frames:
# accurate: 4730, total: 6105
# fake frames:
# accurate: 5890, total: 34895
# real frames:
# accurate: 4974, total: 6483
# fake frames:
# accurate: 6131, total: 35517
# real frames:
# accurate: 5042, total: 6563
# fake frames:
# accurate: 6316, total: 36437
# real frames:
# accurate: 5100, total: 6643
# fake frames:
# accurate: 6486, total: 37357
# real frames:
# accurate: 5168, total: 6786
# fake frames:
# accurate: 6977, total: 38214
# real frames:
# accurate: 5381, total: 7000
# fake frames:
# accurate: 6980, total: 39000
# real frames:
# accurate: 5581, total: 7301
# fake frames:
# accurate: 7156, total: 39699
# real frames:
# accurate: 5662, total: 7397
# fake frames:
# accurate: 7292, total: 40603
# real frames:
# accurate: 5744, total: 7506
# fake frames:
# accurate: 7431, total: 41494
# real frames:
# accurate: 5822, total: 7607
# fake frames:
# accurate: 7613, total: 42393
# real frames:
# accurate: 5958, total: 7784
# fake frames:
# accurate: 7779, total: 43216
# real frames:
# accurate: 6153, total: 8010
# fake frames:
# accurate: 7839, total: 43990
# real frames:
# accurate: 158, total: 241
# fake frames:
# accurate: 117, total: 759
# real frames:
# accurate: 226, total: 312
# fake frames:
# accurate: 188, total: 1688
# real frames:
# accurate: 322, total: 410
# fake frames:
# accurate: 236, total: 2590
# real frames:
# accurate: 439, total: 566
# fake frames:
# accurate: 388, total: 3434
# real frames:
# accurate: 624, total: 844
# fake frames:
# accurate: 509, total: 4156
# real frames:
# accurate: 720, total: 1013
# fake frames:
# accurate: 641, total: 4987
# real frames:
# accurate: 817, total: 1126
# fake frames:
# accurate: 692, total: 5874
# real frames:
# accurate: 854, total: 1283
# fake frames:
# accurate: 1284, total: 6717
# real frames:
# accurate: 986, total: 1487
# fake frames:
# accurate: 1599, total: 7513
# real frames:
# accurate: 1231, total: 1840
# fake frames:
# accurate: 1766, total: 8160
# real frames:
# accurate: 1319, total: 2015
# fake frames:
# accurate: 1892, total: 8985
# real frames:
# accurate: 1383, total: 2086
# fake frames:
# accurate: 1961, total: 9914
# real frames:
# accurate: 1517, total: 2221
# fake frames:
# accurate: 1995, total: 10779
# real frames:
# accurate: 1676, total: 2392
# fake frames:
# accurate: 2035, total: 11608
# real frames:
# accurate: 1815, total: 2651
# fake frames:
# accurate: 2417, total: 12349
# real frames:
# accurate: 1972, total: 2877
# fake frames:
# accurate: 2517, total: 13123
# real frames:
# accurate: 2030, total: 2972
# fake frames:
# accurate: 2709, total: 14028
# real frames:
# accurate: 2103, total: 3084
# fake frames:
# accurate: 2904, total: 14916
# real frames:
# accurate: 2160, total: 3187
# fake frames:
# accurate: 3267, total: 15813
# real frames:
# accurate: 2266, total: 3346
# fake frames:
# accurate: 3520, total: 16654
# real frames:
# accurate: 2397, total: 3618
# fake frames:
# accurate: 3831, total: 17382
# real frames:
# accurate: 2553, total: 3814
# fake frames:
# accurate: 3913, total: 18186
# real frames:
# accurate: 2607, total: 3868
# fake frames:
# accurate: 3934, total: 19132
# real frames:
# accurate: 2618, total: 3977
# fake frames:
# accurate: 4647, total: 20023
# real frames:
# accurate: 2677, total: 4163
# fake frames:
# accurate: 5203, total: 20837
# real frames:
# accurate: 2849, total: 4402
# fake frames:
# accurate: 5372, total: 21598
# real frames:
# accurate: 3057, total: 4677
# fake frames:
# accurate: 5482, total: 22323
# real frames:
# accurate: 3169, total: 4798
# fake frames:
# accurate: 5537, total: 23202
# real frames:
# accurate: 3265, total: 4908
# fake frames:
# accurate: 5648, total: 24092
# real frames:
# accurate: 3337, total: 5075
# fake frames:
# accurate: 5920, total: 24925
# real frames:
# accurate: 3470, total: 5294
# fake frames:
# accurate: 6069, total: 25706
# real frames:
# accurate: 3607, total: 5533
# fake frames:
# accurate: 6305, total: 26467
# real frames:
# accurate: 3747, total: 5688
# fake frames:
# accurate: 6357, total: 27312
# real frames:
# accurate: 3830, total: 5780
# fake frames:
# accurate: 6405, total: 28220
# real frames:
# accurate: 3943, total: 5915
# fake frames:
# accurate: 6567, total: 29085
# real frames:
# accurate: 4108, total: 6114
# fake frames:
# accurate: 6694, total: 29886
# real frames:
# accurate: 4224, total: 6443
# fake frames:
# accurate: 7019, total: 30557
# real frames:
# accurate: 4242, total: 6537
# fake frames:
# accurate: 7715, total: 31463
# real frames:
# accurate: 4317, total: 6691
# fake frames:
# accurate: 8089, total: 32309
# real frames:
# accurate: 4482, total: 6975
# fake frames:
# accurate: 8237, total: 33025
# real frames:
# accurate: 4678, total: 7206
# fake frames:
# accurate: 8331, total: 33794
# real frames:
# accurate: 4824, total: 7394
# fake frames:
# accurate: 8402, total: 34606
# real frames:
# accurate: 4875, total: 7447
# fake frames:
# accurate: 8413, total: 35553
# real frames:
# accurate: 4988, total: 7573
# fake frames:
# accurate: 8464, total: 36427
# real frames:
# accurate: 5128, total: 7729
# fake frames:
# accurate: 8560, total: 37271
# real frames:
# accurate: 5367, total: 8005
# fake frames:
# accurate: 8657, total: 37995
# real frames:
# accurate: 5572, total: 8333
# fake frames:
# accurate: 8920, total: 38667
# real frames:
# accurate: 5693, total: 8461
# fake frames:
# accurate: 8969, total: 39539
# real frames:
# accurate: 5800, total: 8580
# fake frames:
# accurate: 9050, total: 40420
# real frames:
# accurate: 5966, total: 8799
# fake frames:
# accurate: 9200, total: 41201
# real frames:
# accurate: 209, total: 347
# fake frames:
# accurate: 231, total: 653
# real frames:
# accurate: 303, total: 486
# fake frames:
# accurate: 440, total: 1514
# real frames:
# accurate: 358, total: 568
# fake frames:
# accurate: 634, total: 2432
# real frames:
# accurate: 508, total: 754
# fake frames:
# accurate: 718, total: 3246
# real frames:
# accurate: 620, total: 952
# fake frames:
# accurate: 950, total: 4048
# real frames:
# accurate: 756, total: 1148
# fake frames:
# accurate: 1157, total: 4852
# real frames:
# accurate: 903, total: 1407
# fake frames:
# accurate: 1416, total: 5593
# real frames:
# accurate: 1037, total: 1607
# fake frames:
# accurate: 1587, total: 6393
# real frames:
# accurate: 1121, total: 1725
# fake frames:
# accurate: 1840, total: 7275
# real frames:
# accurate: 1233, total: 1884
# fake frames:
# accurate: 2032, total: 8116
# real frames:
# accurate: 1433, total: 2108
# fake frames:
# accurate: 2104, total: 8892
# real frames:
# accurate: 1587, total: 2314
# fake frames:
# accurate: 2254, total: 9686
# real frames:
# accurate: 1643, total: 2409
# fake frames:
# accurate: 2540, total: 10591
# real frames:
# accurate: 1713, total: 2541
# fake frames:
# accurate: 2896, total: 11459
# real frames:
# accurate: 1846, total: 2757
# fake frames:
# accurate: 3156, total: 12243
# real frames:
# accurate: 2072, total: 3035
# fake frames:
# accurate: 3308, total: 12965
# real frames:
# accurate: 2149, total: 3181
# fake frames:
# accurate: 3860, total: 13819
# real frames:
# accurate: 2186, total: 3303
# fake frames:
# accurate: 4522, total: 14697
# real frames:
# accurate: 2233, total: 3412
# fake frames:
# accurate: 5006, total: 15588
# real frames:
# accurate: 2326, total: 3550
# fake frames:
# accurate: 5295, total: 16450
# real frames:
# accurate: 2478, total: 3727
# fake frames:
# accurate: 5415, total: 17273
# real frames:
# accurate: 2640, total: 3972
# fake frames:
# accurate: 5570, total: 18028
# real frames:
# accurate: 2757, total: 4135
# fake frames:
# accurate: 5814, total: 18865
# real frames:
# accurate: 2837, total: 4238
# fake frames:
# accurate: 6051, total: 19762
# real frames:
# accurate: 2961, total: 4404
# fake frames:
# accurate: 6186, total: 20596
# real frames:
# accurate: 3071, total: 4567
# fake frames:
# accurate: 6401, total: 21433
# real frames:
# accurate: 3206, total: 4709
# fake frames:
# accurate: 6454, total: 22291
# real frames:
# accurate: 3438, total: 5004
# fake frames:
# accurate: 6582, total: 22996
# real frames:
# accurate: 3509, total: 5092
# fake frames:
# accurate: 6656, total: 23908
# real frames:
# accurate: 3554, total: 5144
# fake frames:
# accurate: 6842, total: 24856
# real frames:
# accurate: 3630, total: 5273
# fake frames:
# accurate: 7140, total: 25727
# real frames:
# accurate: 3693, total: 5554
# fake frames:
# accurate: 7696, total: 26446
# real frames:
# accurate: 3836, total: 5779
# fake frames:
# accurate: 8025, total: 27221
# real frames:
# accurate: 3889, total: 5897
# fake frames:
# accurate: 8444, total: 28103
# real frames:
# accurate: 3947, total: 5984
# fake frames:
# accurate: 8594, total: 29016
# real frames:
# accurate: 4087, total: 6133
# fake frames:
# accurate: 8658, total: 29867
# real frames:
# accurate: 4276, total: 6340
# fake frames:
# accurate: 8723, total: 30660
# real frames:
# accurate: 4585, total: 6685
# fake frames:
# accurate: 8833, total: 31315
# real frames:
# accurate: 4625, total: 6809
# fake frames:
# accurate: 9414, total: 32191
# real frames:
# accurate: 4672, total: 6929
# fake frames:
# accurate: 9967, total: 33071
# real frames:
# accurate: 4819, total: 7109
# fake frames:
# accurate: 10130, total: 33891
# real frames:
# accurate: 4913, total: 7283
# fake frames:
# accurate: 10464, total: 34717
# real frames:
# accurate: 5211, total: 7606
# fake frames:
# accurate: 10520, total: 35394
# real frames:
# accurate: 5359, total: 7797
# fake frames:
# accurate: 10749, total: 36203
# real frames:
# accurate: 5416, total: 7909
# fake frames:
# accurate: 11077, total: 37091
# real frames:
# accurate: 5463, total: 8023
# fake frames:
# accurate: 11499, total: 37977
# real frames:
# accurate: 5553, total: 8121
# fake frames:
# accurate: 11564, total: 38879
# real frames:
# accurate: 5716, total: 8301
# fake frames:
# accurate: 11765, total: 39699
# real frames:
# accurate: 5966, total: 8620
# fake frames:
# accurate: 11874, total: 40380
# real frames:
# accurate: 6080, total: 8761
# fake frames:
# accurate: 12032, total: 41239
# real frames:
# accurate: 6139, total: 8866
# fake frames:
# accurate: 12316, total: 42134
# real frames:
# accurate: 44, total: 131
# fake frames:
# accurate: 511, total: 869
# real frames:
# accurate: 181, total: 363
# fake frames:
# accurate: 790, total: 1637
# real frames:
# accurate: 362, total: 686
# fake frames:
# accurate: 998, total: 2314
# real frames:
# accurate: 440, total: 813
# fake frames:
# accurate: 1314, total: 3187
# real frames:
# accurate: 520, total: 927
# fake frames:
# accurate: 1603, total: 4073
# real frames:
# accurate: 581, total: 1004
# fake frames:
# accurate: 1751, total: 4996
# real frames:
# accurate: 752, total: 1211
# fake frames:
# accurate: 1866, total: 5789
# real frames:
# accurate: 960, total: 1489
# fake frames:
# accurate: 2027, total: 6511
# real frames:
# accurate: 1101, total: 1656
# fake frames:
# accurate: 2189, total: 7344
# real frames:
# accurate: 1173, total: 1758
# fake frames:
# accurate: 2353, total: 8242
# real frames:
# accurate: 1273, total: 1919
# fake frames:
# accurate: 2613, total: 9081
# real frames:
# accurate: 1351, total: 2061
# fake frames:
# accurate: 2992, total: 9939
# real frames:
# accurate: 1433, total: 2196
# fake frames:
# accurate: 3389, total: 10804
# real frames:
# accurate: 1540, total: 2361
# fake frames:
# accurate: 3715, total: 11639
# real frames:
# accurate: 1809, total: 2698
# fake frames:
# accurate: 3856, total: 12302
# real frames:
# accurate: 1956, total: 2863
# fake frames:
# accurate: 3884, total: 13137
# real frames:
# accurate: 2039, total: 2946
# fake frames:
# accurate: 3888, total: 14054
# real frames:
# accurate: 2104, total: 3050
# fake frames:
# accurate: 4248, total: 14950
# real frames:
# accurate: 2152, total: 3163
# fake frames:
# accurate: 4771, total: 15837
# real frames:
# accurate: 2262, total: 3329
# fake frames:
# accurate: 5024, total: 16671
# real frames:
# accurate: 2519, total: 3702
# fake frames:
# accurate: 5187, total: 17298
# real frames:
# accurate: 2610, total: 3821
# fake frames:
# accurate: 5453, total: 18179
# real frames:
# accurate: 2684, total: 3946
# fake frames:
# accurate: 5866, total: 19054
# real frames:
# accurate: 2725, total: 4053
# fake frames:
# accurate: 6482, total: 19947
# real frames:
# accurate: 2851, total: 4199
# fake frames:
# accurate: 6637, total: 20801
# real frames:
# accurate: 3007, total: 4399
# fake frames:
# accurate: 6753, total: 21601
# real frames:
# accurate: 3151, total: 4709
# fake frames:
# accurate: 7035, total: 22291
# real frames:
# accurate: 3243, total: 4871
# fake frames:
# accurate: 7244, total: 23129
# real frames:
# accurate: 3288, total: 4994
# fake frames:
# accurate: 7646, total: 24006
# real frames:
# accurate: 3353, total: 5128
# fake frames:
# accurate: 8086, total: 24872
# real frames:
# accurate: 3507, total: 5375
# fake frames:
# accurate: 8295, total: 25625
# real frames:
# accurate: 3609, total: 5633
# fake frames:
# accurate: 8568, total: 26367
# real frames:
# accurate: 3723, total: 5785
# fake frames:
# accurate: 8708, total: 27215
# real frames:
# accurate: 3822, total: 5906
# fake frames:
# accurate: 8816, total: 28094
# real frames:
# accurate: 3947, total: 6046
# fake frames:
# accurate: 8936, total: 28954
# real frames:
# accurate: 4115, total: 6275
# fake frames:
# accurate: 9084, total: 29725
# real frames:
# accurate: 4315, total: 6513
# fake frames:
# accurate: 9189, total: 30487
# real frames:
# accurate: 4403, total: 6610
# fake frames:
# accurate: 9236, total: 31390
# real frames:
# accurate: 4553, total: 6760
# fake frames:
# accurate: 9236, total: 32240
# real frames:
# accurate: 4664, total: 6872
# fake frames:
# accurate: 9248, total: 33128
# real frames:
# accurate: 4859, total: 7137
# fake frames:
# accurate: 9451, total: 33863
# real frames:
# accurate: 5065, total: 7405
# fake frames:
# accurate: 9617, total: 34595
# real frames:
# accurate: 5157, total: 7544
# fake frames:
# accurate: 9913, total: 35456
# real frames:
# accurate: 5215, total: 7672
# fake frames:
# accurate: 10342, total: 36328
# real frames:
# accurate: 5335, total: 7808
# fake frames:
# accurate: 10436, total: 37192
# real frames:
# accurate: 5452, total: 7996
# fake frames:
# accurate: 10725, total: 38004
# real frames:
# accurate: 5579, total: 8233
# fake frames:
# accurate: 11100, total: 38767
# real frames:
# accurate: 5699, total: 8388
# fake frames:
# accurate: 11225, total: 39612
# real frames:
# accurate: 5815, total: 8528
# fake frames:
# accurate: 11346, total: 40472
# real frames:
# accurate: 5912, total: 8654
# fake frames:
# accurate: 11551, total: 41346
# real frames:
# accurate: 6041, total: 8790
# fake frames:
# accurate: 11626, total: 42210
# real frames:
# accurate: 6190, total: 8949
# fake frames:
# accurate: 11702, total: 43051
# real frames:
# accurate: 6364, total: 9138
# fake frames:
# accurate: 11833, total: 43862
# real frames:
# accurate: 6480, total: 9266
# fake frames:
# accurate: 12028, total: 44734

# %%
print('{}/{} real frames predicted correctly, and {}/{} fake frames predicted correctly'.format(correct_real,
                                                                                                total_real,
                                                                                                correct_fake,
                                                                                                total_fake))
# Out:
# 29519/42036 real frames predicted correctly, and 55703/222156 fake frames predicted correctly

# %%
prediction_df.to_csv('predictions1.csv')
