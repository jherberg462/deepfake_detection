# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.cloud import storage
from google.oauth2 import service_account
import os

# %%
from google.cloud import storage
try:
    from google.colab import auth
    auth.authenticate_user()
    credentials=None
except ModuleNotFoundError:

    credentials = service_account.Credentials.from_service_account_file( #file location of GCS private key
        '/Users/jeremiahherberg/Downloads/deepfake-research-a6b5e4f02da6.json')

# %%
client = storage.Client(project='deepfake-research', credentials=credentials)
video_frame_bucket_name = 'deepfake-dataset'
#bucket containing test data
video_frame_bucket = client.bucket(video_frame_bucket_name)
model_bucket_name = 'jh-gan-testing'
#bucket containing model
model_bucket = client.bucket(model_bucket_name)

# %%
#download and load model
model_name =  'disc5_epoch200.h5' #'disc5_epoch230.h5' #  200
model_blob = model_bucket.blob(model_name)
model_blob.download_to_filename(model_name)
model = tf.keras.models.load_model(model_name)

""" 
200:
real frames:
accurate: 314, total: 373
fake frames:
accurate: 1941, total: 5627 
"""
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# ' \n200:\nreal frames:\naccurate: 314, total: 373\nfake frames:\naccurate: 1941, total: 5627 \n'

# %%
def make_single_prediction(frame,
                          frame_shape=(225, 146, 3),
                          model_input_shape=(192, 128, 3),
                          model=model):
    '''
    function to make a prediction if a single frame in test dataset is real or not
    
    inputs:
        frame - array with a shape of (frame_shape[0] * frame_shape[1] * frame_shape[2],)
        
        frame_shape - tuple that describes the shape of the image, defaults to (225, 146, 3)
        the last dim must be 3 (RGB)
        
        model_input_shape - tuple that describes the shape of the input that will be passed into model
        defaults to (192, 128, 3), the last dim must be 3 (RGB)
        
        model - tensorflow model that will be used to make prediction, defaults to 'model'
    returns:
        prediction - Bool, True if model predicts frame is real, False if prediction is frame is fake
        raw_prediction - float, range of -inf to inf, negative number indicates prediction is that 
        frame is fake and positive indicates the prediction is the frame is real
        the closer to 0 the raw_prediction, the less confident the model is
    ''' 
    assert(frame_shape[2] == model_input_shape[2] == 3), 'the last dim must equal 3 in the model and frame shapes'
    frame_reshaped = frame.reshape(frame_shape)
    #resize frame to be compatable with model
    frame_resized = tf.image.resize_with_pad(frame_reshaped, model_input_shape[0], model_input_shape[1])
    # (H, W, RGB) -> (1, H, W, RGB)
    frame_expanded = tf.expand_dims(frame_resized, 0)
    #convert values to between -1 and 1 (0 to 255 -> -1 to 1) (this is how the model was trained)
    frame_expanded = (tf.cast(frame_expanded, tf.float32) - 127.5) / 127.5
    #we are only making a single prediction
    raw_prediction = model.predict(frame_expanded)[0][0]
    
    if raw_prediction > 0:
        prediction = True
    else:
        prediction = False
    
    return prediction, raw_prediction

# %%
def prediction_batch(idx,
                    bucket=video_frame_bucket,
                    test_ds_file_name='face_arrays',
                    ground_file_name='labels_and_video_names'):
    '''
    function to make a batch of predictions 
    test dataset is split up into 5 files
    
    inputs:
        idx - int with a value between 1 to 5 that represents which test ds file is being used for predictions
        
        bucket - GCS bucket variable that contains files with test data, default is video_frame_bucket
        
        test_ds_file_name - str - beginning of file name of files containing test ds, default is face_arrays
        
        ground_file_name - str - beginning of file name of files containing the ground truth of each frame 
    
    returns:
        correct_real - int - the number of real frames correctly predicted
        
        total_real - int - total number of real frames
        
        correct_fake - int - the number of fake frames correctly predicted
        
        total_fake - int - total number of fake frames
        
        prediction_df - DataFrame  with the following columns:
            raw_prediction - float, range of -inf to inf, negative number indicates prediction
            is frame is fake and postive indicates the prediction is frame is real
            the closer to 0 of the value, the less confident the model is regarding the prediction
            
            accurate - Bool - reflects if the model accurately predicted if the frame is real or fake
            
            ground_truth - Bool - reflects if the frame is real or fake

    '''
    #downlaod files:
    ds_file_name = '{}{}.npz'.format(test_ds_file_name, idx)
    ground_file_name = '{}{}.csv'.format(ground_file_name, idx)
    ds_blob = bucket.blob('aaa_frames/' + ds_file_name)
    ds_blob.download_to_filename(ds_file_name)
    ground_blob = bucket.blob('aaa_frames/' + ground_file_name)
    ground_blob.download_to_filename(ground_file_name)
    
    data_file = np.load(ds_file_name)
    data = [data_file[key] for key in data_file]
    ground = pd.read_csv(ground_file_name)
    ground_list = ground['face_labels'].to_list()
    assert(len(ground_list) == len(data)), 'The len of the DS and ground truth do not match'
    
    total_real, total_fake, correct_real, correct_fake = 0, 0, 0, 0
    predictions = []
    ground_truths = []
    accurate_predictions = []
    
    for frame in range(len(data)):
        prediction, raw_prediction = make_single_prediction(data[frame])
        real = ground_list[frame]
        accurate_prediction = (real == prediction)
        if real:
            total_real +=1
            if accurate_prediction:
                correct_real +=1
        else:
            total_fake +=1
            if accurate_prediction: 
                correct_fake +=1
        predictions.append(raw_prediction)
        ground_truths.append(real)
        accurate_predictions.append(accurate_prediction)
        if frame % 1000 == 999:
          print('real frames:')
          print('accurate: {}, total: {}'.format(correct_real, total_real))
          print('fake frames:')
          print('accurate: {}, total: {} '.format(correct_fake, total_fake))
    
    
    preds_dictionary = {
        'raw_prediction':predictions,
        'accurate': accurate_predictions,
        'ground_truth': ground_truths
    }
    prediction_df = pd.DataFrame(preds_dictionary)
        
    return correct_real, total_real, correct_fake, total_fake, prediction_df

# %%
def make_predictions(start, end):
    '''
    function to make predictions on entire dataset
    
    inputs:
        start - int, starting file number in test dataset
        
        end - int, ending file number in test dataset, must be greater than or equal to start
        
    returns:
    correct_real - int - the number of real frames correctly predicted

    total_real - int - total number of real frames

    correct_fake - int - the number of fake frames correctly predicted

    total_fake - int - total number of fake frames

    prediction_df - DataFrame  with the following columns:
        raw_prediction - float, range of -inf to inf, negative number indicates prediction
        is frame is fake and postive indicates the prediction is frame is real
        the closer to 0 of the value, the less confident the model is regarding the prediction

        accurate - Bool - reflects if the model accurately predicted if the frame is real or fake

        ground_truth - Bool - reflects if the frame is real or fake
    '''
    
    assert(start <= end), 'start must be less than or equal to end'
    
    total_real, total_fake, correct_real, correct_fake = 0, 0, 0, 0
    prediction_dfs = []
    for file in np.arange(start, end+1):
        cor_real_batch, real_batch, cor_fake_batch, fake_batch, df_batch = prediction_batch(file)
        total_real += real_batch
        total_fake += fake_batch
        correct_real +=cor_real_batch
        correct_fake += cor_fake_batch
        prediction_dfs.append(df_batch)
    
    prediction_df = pd.concat(prediction_dfs)
    
    return total_real, total_fake, correct_real, correct_fake, prediction_df

# %%
with tf.device('/device:GPU:0'):
    total_real, total_fake, correct_real, correct_fake, prediction_df = make_predictions(1, 5)
# Out:
# real frames:
# accurate: 41, total: 52
# fake frames:
# accurate: 233, total: 948
# real frames:
# accurate: 108, total: 127
# fake frames:
# accurate: 453, total: 1873
# real frames:
# accurate: 179, total: 206
# fake frames:
# accurate: 717, total: 2794
# real frames:
# accurate: 238, total: 281
# fake frames:
# accurate: 1094, total: 3719
# real frames:
# accurate: 280, total: 333
# fake frames:
# accurate: 1507, total: 4667
# real frames:
# accurate: 314, total: 373
# fake frames:
# accurate: 1941, total: 5627
# real frames:
# accurate: 370, total: 443
# fake frames:
# accurate: 2309, total: 6557
# real frames:
# accurate: 419, total: 513
# fake frames:
# accurate: 2696, total: 7487
# real frames:
# accurate: 458, total: 579
# fake frames:
# accurate: 3069, total: 8421
# real frames:
# accurate: 529, total: 674
# fake frames:
# accurate: 3426, total: 9326
# real frames:
# accurate: 784, total: 946
# fake frames:
# accurate: 3495, total: 10054
# real frames:
# accurate: 851, total: 1024
# fake frames:
# accurate: 3607, total: 10976
# real frames:
# accurate: 950, total: 1131
# fake frames:
# accurate: 3683, total: 11869
# real frames:
# accurate: 1183, total: 1400
# fake frames:
# accurate: 3759, total: 12600
# real frames:
# accurate: 1221, total: 1442
# fake frames:
# accurate: 3905, total: 13558
# real frames:
# accurate: 1283, total: 1512
# fake frames:
# accurate: 4049, total: 14488
# real frames:
# accurate: 1351, total: 1581
# fake frames:
# accurate: 4177, total: 15419
# real frames:
# accurate: 1510, total: 1761
# fake frames:
# accurate: 4221, total: 16239
# real frames:
# accurate: 1558, total: 1842
# fake frames:
# accurate: 4514, total: 17158
# real frames:
# accurate: 1594, total: 1906
# fake frames:
# accurate: 4856, total: 18094
# real frames:
# accurate: 1620, total: 1946
# fake frames:
# accurate: 5242, total: 19054
# real frames:
# accurate: 1658, total: 2000
# fake frames:
# accurate: 5591, total: 20000
# real frames:
# accurate: 1775, total: 2132
# fake frames:
# accurate: 5846, total: 20868
# real frames:
# accurate: 2020, total: 2514
# fake frames:
# accurate: 6038, total: 21486
# real frames:
# accurate: 2163, total: 2688
# fake frames:
# accurate: 6143, total: 22312
# real frames:
# accurate: 2210, total: 2736
# fake frames:
# accurate: 6181, total: 23264
# real frames:
# accurate: 2280, total: 2808
# fake frames:
# accurate: 6226, total: 24192
# real frames:
# accurate: 2354, total: 2883
# fake frames:
# accurate: 6271, total: 25117
# real frames:
# accurate: 2402, total: 2931
# fake frames:
# accurate: 6306, total: 26069
# real frames:
# accurate: 2462, total: 2994
# fake frames:
# accurate: 6357, total: 27006
# real frames:
# accurate: 2605, total: 3153
# fake frames:
# accurate: 6411, total: 27847
# real frames:
# accurate: 2870, total: 3547
# fake frames:
# accurate: 6634, total: 28453
# real frames:
# accurate: 2962, total: 3651
# fake frames:
# accurate: 6679, total: 29349
# real frames:
# accurate: 3033, total: 3722
# fake frames:
# accurate: 6712, total: 30278
# real frames:
# accurate: 3100, total: 3789
# fake frames:
# accurate: 6749, total: 31211
# real frames:
# accurate: 3175, total: 3864
# fake frames:
# accurate: 6783, total: 32136
# real frames:
# accurate: 3372, total: 4068
# fake frames:
# accurate: 6838, total: 32932
# real frames:
# accurate: 3633, total: 4361
# fake frames:
# accurate: 6951, total: 33639
# real frames:
# accurate: 3710, total: 4439
# fake frames:
# accurate: 7003, total: 34561
# real frames:
# accurate: 3785, total: 4525
# fake frames:
# accurate: 7071, total: 35475
# real frames:
# accurate: 3964, total: 4736
# fake frames:
# accurate: 7234, total: 36264
# real frames:
# accurate: 4202, total: 4994
# fake frames:
# accurate: 7396, total: 37006
# real frames:
# accurate: 4262, total: 5062
# fake frames:
# accurate: 7519, total: 37938
# real frames:
# accurate: 4371, total: 5182
# fake frames:
# accurate: 7627, total: 38818
# real frames:
# accurate: 4545, total: 5408
# fake frames:
# accurate: 7858, total: 39592
# real frames:
# accurate: 4678, total: 5615
# fake frames:
# accurate: 8201, total: 40385
# real frames:
# accurate: 4719, total: 5667
# fake frames:
# accurate: 8517, total: 41333
# real frames:
# accurate: 4748, total: 5701
# fake frames:
# accurate: 8796, total: 42299
# real frames:
# accurate: 4784, total: 5744
# fake frames:
# accurate: 9106, total: 43256
# real frames:
# accurate: 4829, total: 5804
# fake frames:
# accurate: 9415, total: 44196
# real frames:
# accurate: 4855, total: 5837
# fake frames:
# accurate: 9686, total: 45163
# real frames:
# accurate: 4889, total: 5878
# fake frames:
# accurate: 10010, total: 46122
# real frames:
# accurate: 4970, total: 6051
# fake frames:
# accurate: 10454, total: 46949
# real frames:
# accurate: 5185, total: 6363
# fake frames:
# accurate: 10660, total: 47637
# real frames:
# accurate: 5313, total: 6509
# fake frames:
# accurate: 10828, total: 48491
# real frames:
# accurate: 106, total: 114
# fake frames:
# accurate: 125, total: 886
# real frames:
# accurate: 356, total: 371
# fake frames:
# accurate: 137, total: 1629
# real frames:
# accurate: 633, total: 669
# fake frames:
# accurate: 202, total: 2331
# real frames:
# accurate: 689, total: 725
# fake frames:
# accurate: 220, total: 3275
# real frames:
# accurate: 741, total: 781
# fake frames:
# accurate: 233, total: 4219
# real frames:
# accurate: 800, total: 847
# fake frames:
# accurate: 273, total: 5153
# real frames:
# accurate: 977, total: 1050
# fake frames:
# accurate: 422, total: 5950
# real frames:
# accurate: 1257, total: 1335
# fake frames:
# accurate: 437, total: 6665
# real frames:
# accurate: 1293, total: 1377
# fake frames:
# accurate: 507, total: 7623
# real frames:
# accurate: 1336, total: 1420
# fake frames:
# accurate: 569, total: 8580
# real frames:
# accurate: 1389, total: 1477
# fake frames:
# accurate: 632, total: 9523
# real frames:
# accurate: 1425, total: 1516
# fake frames:
# accurate: 693, total: 10484
# real frames:
# accurate: 1457, total: 1551
# fake frames:
# accurate: 746, total: 11449
# real frames:
# accurate: 1488, total: 1585
# fake frames:
# accurate: 813, total: 12415
# real frames:
# accurate: 1614, total: 1739
# fake frames:
# accurate: 1032, total: 13261
# real frames:
# accurate: 1786, total: 1942
# fake frames:
# accurate: 1132, total: 14058
# real frames:
# accurate: 2087, total: 2287
# fake frames:
# accurate: 1272, total: 14713
# real frames:
# accurate: 2178, total: 2398
# fake frames:
# accurate: 1429, total: 15602
# real frames:
# accurate: 2242, total: 2475
# fake frames:
# accurate: 1590, total: 16525
# real frames:
# accurate: 2338, total: 2575
# fake frames:
# accurate: 1675, total: 17425
# real frames:
# accurate: 2451, total: 2702
# fake frames:
# accurate: 1791, total: 18298
# real frames:
# accurate: 2743, total: 2996
# fake frames:
# accurate: 1800, total: 19004
# real frames:
# accurate: 2927, total: 3184
# fake frames:
# accurate: 1869, total: 19816
# real frames:
# accurate: 3036, total: 3320
# fake frames:
# accurate: 1993, total: 20680
# real frames:
# accurate: 3144, total: 3454
# fake frames:
# accurate: 2305, total: 21546
# real frames:
# accurate: 3256, total: 3589
# fake frames:
# accurate: 2445, total: 22411
# real frames:
# accurate: 3475, total: 3892
# fake frames:
# accurate: 2624, total: 23108
# real frames:
# accurate: 3543, total: 3962
# fake frames:
# accurate: 2678, total: 24038
# real frames:
# accurate: 3666, total: 4085
# fake frames:
# accurate: 2681, total: 24915
# real frames:
# accurate: 3820, total: 4264
# fake frames:
# accurate: 2841, total: 25736
# real frames:
# accurate: 4055, total: 4618
# fake frames:
# accurate: 3074, total: 26382
# real frames:
# accurate: 4184, total: 4750
# fake frames:
# accurate: 3145, total: 27250
# real frames:
# accurate: 4278, total: 4851
# fake frames:
# accurate: 3249, total: 28149
# real frames:
# accurate: 4391, total: 4982
# fake frames:
# accurate: 3352, total: 29018
# real frames:
# accurate: 4562, total: 5160
# fake frames:
# accurate: 3376, total: 29840
# real frames:
# accurate: 4843, total: 5470
# fake frames:
# accurate: 3481, total: 30530
# real frames:
# accurate: 4970, total: 5627
# fake frames:
# accurate: 3702, total: 31373
# real frames:
# accurate: 5029, total: 5693
# fake frames:
# accurate: 3887, total: 32307
# real frames:
# accurate: 5078, total: 5751
# fake frames:
# accurate: 4094, total: 33249
# real frames:
# accurate: 5207, total: 5909
# fake frames:
# accurate: 4364, total: 34091
# real frames:
# accurate: 5377, total: 6105
# fake frames:
# accurate: 4453, total: 34895
# real frames:
# accurate: 5711, total: 6483
# fake frames:
# accurate: 4660, total: 35517
# real frames:
# accurate: 5790, total: 6563
# fake frames:
# accurate: 4707, total: 36437
# real frames:
# accurate: 5864, total: 6643
# fake frames:
# accurate: 4761, total: 37357
# real frames:
# accurate: 5972, total: 6786
# fake frames:
# accurate: 5050, total: 38214
# real frames:
# accurate: 6186, total: 7000
# fake frames:
# accurate: 5050, total: 39000
# real frames:
# accurate: 6403, total: 7301
# fake frames:
# accurate: 5202, total: 39699
# real frames:
# accurate: 6477, total: 7397
# fake frames:
# accurate: 5375, total: 40603
# real frames:
# accurate: 6570, total: 7506
# fake frames:
# accurate: 5600, total: 41494
# real frames:
# accurate: 6656, total: 7607
# fake frames:
# accurate: 5822, total: 42393
# real frames:
# accurate: 6817, total: 7784
# fake frames:
# accurate: 5893, total: 43216
# real frames:
# accurate: 7034, total: 8010
# fake frames:
# accurate: 5930, total: 43990
# real frames:
# accurate: 229, total: 241
# fake frames:
# accurate: 43, total: 759
# real frames:
# accurate: 299, total: 312
# fake frames:
# accurate: 45, total: 1688
# real frames:
# accurate: 397, total: 410
# fake frames:
# accurate: 47, total: 2590
# real frames:
# accurate: 544, total: 566
# fake frames:
# accurate: 87, total: 3434
# real frames:
# accurate: 771, total: 844
# fake frames:
# accurate: 169, total: 4156
# real frames:
# accurate: 915, total: 1013
# fake frames:
# accurate: 254, total: 4987
# real frames:
# accurate: 1012, total: 1126
# fake frames:
# accurate: 300, total: 5874
# real frames:
# accurate: 1111, total: 1283
# fake frames:
# accurate: 543, total: 6717
# real frames:
# accurate: 1281, total: 1487
# fake frames:
# accurate: 665, total: 7513
# real frames:
# accurate: 1569, total: 1840
# fake frames:
# accurate: 777, total: 8160
# real frames:
# accurate: 1690, total: 2015
# fake frames:
# accurate: 948, total: 8985
# real frames:
# accurate: 1748, total: 2086
# fake frames:
# accurate: 1129, total: 9914
# real frames:
# accurate: 1881, total: 2221
# fake frames:
# accurate: 1163, total: 10779
# real frames:
# accurate: 2052, total: 2392
# fake frames:
# accurate: 1163, total: 11608
# real frames:
# accurate: 2234, total: 2651
# fake frames:
# accurate: 1374, total: 12349
# real frames:
# accurate: 2407, total: 2877
# fake frames:
# accurate: 1527, total: 13123
# real frames:
# accurate: 2494, total: 2972
# fake frames:
# accurate: 1672, total: 14028
# real frames:
# accurate: 2596, total: 3084
# fake frames:
# accurate: 1818, total: 14916
# real frames:
# accurate: 2661, total: 3187
# fake frames:
# accurate: 2034, total: 15813
# real frames:
# accurate: 2803, total: 3346
# fake frames:
# accurate: 2193, total: 16654
# real frames:
# accurate: 3010, total: 3618
# fake frames:
# accurate: 2324, total: 17382
# real frames:
# accurate: 3187, total: 3814
# fake frames:
# accurate: 2410, total: 18186
# real frames:
# accurate: 3240, total: 3868
# fake frames:
# accurate: 2492, total: 19132
# real frames:
# accurate: 3272, total: 3977
# fake frames:
# accurate: 3162, total: 20023
# real frames:
# accurate: 3397, total: 4163
# fake frames:
# accurate: 3455, total: 20837
# real frames:
# accurate: 3602, total: 4402
# fake frames:
# accurate: 3548, total: 21598
# real frames:
# accurate: 3813, total: 4677
# fake frames:
# accurate: 3640, total: 22323
# real frames:
# accurate: 3929, total: 4798
# fake frames:
# accurate: 3704, total: 23202
# real frames:
# accurate: 4026, total: 4908
# fake frames:
# accurate: 3764, total: 24092
# real frames:
# accurate: 4181, total: 5075
# fake frames:
# accurate: 3862, total: 24925
# real frames:
# accurate: 4392, total: 5294
# fake frames:
# accurate: 3919, total: 25706
# real frames:
# accurate: 4602, total: 5533
# fake frames:
# accurate: 3988, total: 26467
# real frames:
# accurate: 4742, total: 5688
# fake frames:
# accurate: 4071, total: 27312
# real frames:
# accurate: 4832, total: 5780
# fake frames:
# accurate: 4151, total: 28220
# real frames:
# accurate: 4945, total: 5915
# fake frames:
# accurate: 4296, total: 29085
# real frames:
# accurate: 5114, total: 6114
# fake frames:
# accurate: 4454, total: 29886
# real frames:
# accurate: 5294, total: 6443
# fake frames:
# accurate: 4694, total: 30557
# real frames:
# accurate: 5367, total: 6537
# fake frames:
# accurate: 4975, total: 31463
# real frames:
# accurate: 5500, total: 6691
# fake frames:
# accurate: 5111, total: 32309
# real frames:
# accurate: 5777, total: 6975
# fake frames:
# accurate: 5145, total: 33025
# real frames:
# accurate: 6003, total: 7206
# fake frames:
# accurate: 5174, total: 33794
# real frames:
# accurate: 6180, total: 7394
# fake frames:
# accurate: 5205, total: 34606
# real frames:
# accurate: 6231, total: 7447
# fake frames:
# accurate: 5234, total: 35553
# real frames:
# accurate: 6354, total: 7573
# fake frames:
# accurate: 5248, total: 36427
# real frames:
# accurate: 6465, total: 7729
# fake frames:
# accurate: 5437, total: 37271
# real frames:
# accurate: 6694, total: 8005
# fake frames:
# accurate: 5626, total: 37995
# real frames:
# accurate: 6952, total: 8333
# fake frames:
# accurate: 5804, total: 38667
# real frames:
# accurate: 7077, total: 8461
# fake frames:
# accurate: 5810, total: 39539
# real frames:
# accurate: 7188, total: 8580
# fake frames:
# accurate: 5844, total: 40420
# real frames:
# accurate: 7375, total: 8799
# fake frames:
# accurate: 5974, total: 41201
# real frames:
# accurate: 271, total: 347
# fake frames:
# accurate: 162, total: 653
# real frames:
# accurate: 393, total: 486
# fake frames:
# accurate: 233, total: 1514
# real frames:
# accurate: 465, total: 568
# fake frames:
# accurate: 266, total: 2432
# real frames:
# accurate: 640, total: 754
# fake frames:
# accurate: 294, total: 3246
# real frames:
# accurate: 807, total: 952
# fake frames:
# accurate: 388, total: 4048
# real frames:
# accurate: 972, total: 1148
# fake frames:
# accurate: 473, total: 4852
# real frames:
# accurate: 1166, total: 1407
# fake frames:
# accurate: 574, total: 5593
# real frames:
# accurate: 1366, total: 1607
# fake frames:
# accurate: 579, total: 6393
# real frames:
# accurate: 1474, total: 1725
# fake frames:
# accurate: 637, total: 7275
# real frames:
# accurate: 1628, total: 1884
# fake frames:
# accurate: 653, total: 8116
# real frames:
# accurate: 1847, total: 2108
# fake frames:
# accurate: 688, total: 8892
# real frames:
# accurate: 2044, total: 2314
# fake frames:
# accurate: 756, total: 9686
# real frames:
# accurate: 2111, total: 2409
# fake frames:
# accurate: 910, total: 10591
# real frames:
# accurate: 2205, total: 2541
# fake frames:
# accurate: 1160, total: 11459
# real frames:
# accurate: 2368, total: 2757
# fake frames:
# accurate: 1362, total: 12243
# real frames:
# accurate: 2612, total: 3035
# fake frames:
# accurate: 1483, total: 12965
# real frames:
# accurate: 2694, total: 3181
# fake frames:
# accurate: 2071, total: 13819
# real frames:
# accurate: 2732, total: 3303
# fake frames:
# accurate: 2746, total: 14697
# real frames:
# accurate: 2802, total: 3412
# fake frames:
# accurate: 3121, total: 15588
# real frames:
# accurate: 2917, total: 3550
# fake frames:
# accurate: 3236, total: 16450
# real frames:
# accurate: 3093, total: 3727
# fake frames:
# accurate: 3237, total: 17273
# real frames:
# accurate: 3305, total: 3972
# fake frames:
# accurate: 3318, total: 18028
# real frames:
# accurate: 3436, total: 4135
# fake frames:
# accurate: 3493, total: 18865
# real frames:
# accurate: 3531, total: 4238
# fake frames:
# accurate: 3640, total: 19762
# real frames:
# accurate: 3694, total: 4404
# fake frames:
# accurate: 3649, total: 20596
# real frames:
# accurate: 3836, total: 4567
# fake frames:
# accurate: 3766, total: 21433
# real frames:
# accurate: 3974, total: 4709
# fake frames:
# accurate: 3803, total: 22291
# real frames:
# accurate: 4251, total: 5004
# fake frames:
# accurate: 3875, total: 22996
# real frames:
# accurate: 4338, total: 5092
# fake frames:
# accurate: 3893, total: 23908
# real frames:
# accurate: 4389, total: 5144
# fake frames:
# accurate: 3950, total: 24856
# real frames:
# accurate: 4472, total: 5273
# fake frames:
# accurate: 4201, total: 25727
# real frames:
# accurate: 4599, total: 5554
# fake frames:
# accurate: 4683, total: 26446
# real frames:
# accurate: 4758, total: 5779
# fake frames:
# accurate: 4978, total: 27221
# real frames:
# accurate: 4834, total: 5897
# fake frames:
# accurate: 5298, total: 28103
# real frames:
# accurate: 4921, total: 5984
# fake frames:
# accurate: 5306, total: 29016
# real frames:
# accurate: 5070, total: 6133
# fake frames:
# accurate: 5306, total: 29867
# real frames:
# accurate: 5277, total: 6340
# fake frames:
# accurate: 5317, total: 30660
# real frames:
# accurate: 5604, total: 6685
# fake frames:
# accurate: 5397, total: 31315
# real frames:
# accurate: 5691, total: 6809
# fake frames:
# accurate: 5774, total: 32191
# real frames:
# accurate: 5776, total: 6929
# fake frames:
# accurate: 6167, total: 33071
# real frames:
# accurate: 5939, total: 7109
# fake frames:
# accurate: 6334, total: 33891
# real frames:
# accurate: 6087, total: 7283
# fake frames:
# accurate: 6477, total: 34717
# real frames:
# accurate: 6396, total: 7606
# fake frames:
# accurate: 6523, total: 35394
# real frames:
# accurate: 6567, total: 7797
# fake frames:
# accurate: 6639, total: 36203
# real frames:
# accurate: 6664, total: 7909
# fake frames:
# accurate: 6736, total: 37091
# real frames:
# accurate: 6743, total: 8023
# fake frames:
# accurate: 7063, total: 37977
# real frames:
# accurate: 6839, total: 8121
# fake frames:
# accurate: 7111, total: 38879
# real frames:
# accurate: 6985, total: 8301
# fake frames:
# accurate: 7241, total: 39699
# real frames:
# accurate: 7274, total: 8620
# fake frames:
# accurate: 7344, total: 40380
# real frames:
# accurate: 7411, total: 8761
# fake frames:
# accurate: 7381, total: 41239
# real frames:
# accurate: 7487, total: 8866
# fake frames:
# accurate: 7631, total: 42134
# real frames:
# accurate: 88, total: 131
# fake frames:
# accurate: 278, total: 869
# real frames:
# accurate: 282, total: 363
# fake frames:
# accurate: 455, total: 1637
# real frames:
# accurate: 521, total: 686
# fake frames:
# accurate: 670, total: 2314
# real frames:
# accurate: 640, total: 813
# fake frames:
# accurate: 758, total: 3187
# real frames:
# accurate: 743, total: 927
# fake frames:
# accurate: 810, total: 4073
# real frames:
# accurate: 820, total: 1004
# fake frames:
# accurate: 844, total: 4996
# real frames:
# accurate: 1015, total: 1211
# fake frames:
# accurate: 935, total: 5789
# real frames:
# accurate: 1245, total: 1489
# fake frames:
# accurate: 1051, total: 6511
# real frames:
# accurate: 1394, total: 1656
# fake frames:
# accurate: 1110, total: 7344
# real frames:
# accurate: 1496, total: 1758
# fake frames:
# accurate: 1111, total: 8242
# real frames:
# accurate: 1653, total: 1919
# fake frames:
# accurate: 1144, total: 9081
# real frames:
# accurate: 1784, total: 2061
# fake frames:
# accurate: 1226, total: 9939
# real frames:
# accurate: 1896, total: 2196
# fake frames:
# accurate: 1345, total: 10804
# real frames:
# accurate: 2037, total: 2361
# fake frames:
# accurate: 1454, total: 11639
# real frames:
# accurate: 2345, total: 2698
# fake frames:
# accurate: 1543, total: 12302
# real frames:
# accurate: 2485, total: 2863
# fake frames:
# accurate: 1640, total: 13137
# real frames:
# accurate: 2568, total: 2946
# fake frames:
# accurate: 1650, total: 14054
# real frames:
# accurate: 2661, total: 3050
# fake frames:
# accurate: 1735, total: 14950
# real frames:
# accurate: 2763, total: 3163
# fake frames:
# accurate: 1861, total: 15837
# real frames:
# accurate: 2890, total: 3329
# fake frames:
# accurate: 2021, total: 16671
# real frames:
# accurate: 3194, total: 3702
# fake frames:
# accurate: 2126, total: 17298
# real frames:
# accurate: 3301, total: 3821
# fake frames:
# accurate: 2335, total: 18179
# real frames:
# accurate: 3394, total: 3946
# fake frames:
# accurate: 2648, total: 19054
# real frames:
# accurate: 3457, total: 4053
# fake frames:
# accurate: 3117, total: 19947
# real frames:
# accurate: 3597, total: 4199
# fake frames:
# accurate: 3274, total: 20801
# real frames:
# accurate: 3791, total: 4399
# fake frames:
# accurate: 3305, total: 21601
# real frames:
# accurate: 4022, total: 4709
# fake frames:
# accurate: 3456, total: 22291
# real frames:
# accurate: 4155, total: 4871
# fake frames:
# accurate: 3572, total: 23129
# real frames:
# accurate: 4237, total: 4994
# fake frames:
# accurate: 3926, total: 24006
# real frames:
# accurate: 4323, total: 5128
# fake frames:
# accurate: 4264, total: 24872
# real frames:
# accurate: 4488, total: 5375
# fake frames:
# accurate: 4457, total: 25625
# real frames:
# accurate: 4657, total: 5633
# fake frames:
# accurate: 4670, total: 26367
# real frames:
# accurate: 4783, total: 5785
# fake frames:
# accurate: 4786, total: 27215
# real frames:
# accurate: 4901, total: 5906
# fake frames:
# accurate: 4809, total: 28094
# real frames:
# accurate: 5035, total: 6046
# fake frames:
# accurate: 4877, total: 28954
# real frames:
# accurate: 5238, total: 6275
# fake frames:
# accurate: 4974, total: 29725
# real frames:
# accurate: 5460, total: 6513
# fake frames:
# accurate: 5040, total: 30487
# real frames:
# accurate: 5554, total: 6610
# fake frames:
# accurate: 5086, total: 31390
# real frames:
# accurate: 5704, total: 6760
# fake frames:
# accurate: 5092, total: 32240
# real frames:
# accurate: 5816, total: 6872
# fake frames:
# accurate: 5093, total: 33128
# real frames:
# accurate: 6073, total: 7137
# fake frames:
# accurate: 5166, total: 33863
# real frames:
# accurate: 6289, total: 7405
# fake frames:
# accurate: 5313, total: 34595
# real frames:
# accurate: 6414, total: 7544
# fake frames:
# accurate: 5419, total: 35456
# real frames:
# accurate: 6529, total: 7672
# fake frames:
# accurate: 5463, total: 36328
# real frames:
# accurate: 6653, total: 7808
# fake frames:
# accurate: 5508, total: 37192
# real frames:
# accurate: 6832, total: 7996
# fake frames:
# accurate: 5571, total: 38004
# real frames:
# accurate: 7000, total: 8233
# fake frames:
# accurate: 5887, total: 38767
# real frames:
# accurate: 7151, total: 8388
# fake frames:
# accurate: 5902, total: 39612
# real frames:
# accurate: 7289, total: 8528
# fake frames:
# accurate: 5932, total: 40472
# real frames:
# accurate: 7402, total: 8654
# fake frames:
# accurate: 5975, total: 41346
# real frames:
# accurate: 7537, total: 8790
# fake frames:
# accurate: 5998, total: 42210
# real frames:
# accurate: 7689, total: 8949
# fake frames:
# accurate: 6075, total: 43051
# real frames:
# accurate: 7874, total: 9138
# fake frames:
# accurate: 6148, total: 43862
# real frames:
# accurate: 7995, total: 9266
# fake frames:
# accurate: 6247, total: 44734

# %%
print('{}/{} real frames predicted correctly, and {}/{} fake frames predicted correctly'.format(correct_real,
                                                                                                total_real,
                                                                                                correct_fake,
                                                                                                total_fake))
# Out:
# 35657/42036 real frames predicted correctly, and 37064/222156 fake frames predicted correctly
