# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.cloud import storage
from google.oauth2 import service_account
import os

# %%
from google.cloud import storage
try:
    from google.colab import auth
    auth.authenticate_user()
    credentials=None
except ModuleNotFoundError:

    credentials = service_account.Credentials.from_service_account_file( #file location of GCS private key
        '/Users/jeremiahherberg/Downloads/deepfake-research-a6b5e4f02da6.json')

# %%
client = storage.Client(project='deepfake-research', credentials=credentials)
video_frame_bucket_name = 'deepfake-dataset'
#bucket containing test data
video_frame_bucket = client.bucket(video_frame_bucket_name)
model_bucket_name = 'jh-gan-testing'
#bucket containing model
model_bucket = client.bucket(model_bucket_name)

# %%
#download and load model
model_name = 'disc1.h5'
model_blob = model_bucket.blob(model_name)
model_blob.download_to_filename(model_name)
model = tf.keras.models.load_model(model_name)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
def make_single_prediction(frame,
                          frame_shape=(225, 146, 3),
                          model_input_shape=(192, 128, 3),
                          model=model):
    '''
    function to make a prediction if a single frame in test dataset is real or not
    
    inputs:
        frame - array with a shape of (frame_shape[0] * frame_shape[1] * frame_shape[2],)
        
        frame_shape - tuple that describes the shape of the image, defaults to (225, 146, 3)
        the last dim must be 3 (RGB)
        
        model_input_shape - tuple that describes the shape of the input that will be passed into model
        defaults to (192, 128, 3), the last dim must be 3 (RGB)
        
        model - tensorflow model that will be used to make prediction, defaults to 'model'
    returns:
        prediction - Bool, True if model predicts frame is real, False if prediction is frame is fake
        raw_prediction - float, range of -inf to inf, negative number indicates prediction is that 
        frame is fake and positive indicates the prediction is the frame is real
        the closer to 0 the raw_prediction, the less confident the model is
    ''' 
    assert(frame_shape[2] == model_input_shape[2] == 3), 'the last dim must equal 3 in the model and frame shapes'
    frame_reshaped = frame.reshape(frame_shape)
    #resize frame to be compatable with model
    frame_resized = tf.image.resize_with_pad(frame_reshaped, model_input_shape[0], model_input_shape[1])
    # (H, W, RGB) -> (1, H, W, RGB)
    frame_expanded = tf.expand_dims(frame_resized, 0)
    #convert values to between -1 and 1 (0 to 255 -> -1 to 1) (this is how the model was trained)
    frame_expanded = (tf.cast(frame_expanded, tf.float32) - 127.5) / 127.5
    #we are only making a single prediction
    raw_prediction = model.predict(frame_expanded)[0][0]
    
    if raw_prediction > 0:
        prediction = True
    else:
        prediction = False
    
    return prediction, raw_prediction

# %%
def prediction_batch(idx,
                    bucket=video_frame_bucket,
                    test_ds_file_name='face_arrays',
                    ground_file_name='labels_and_video_names'):
    '''
    function to make a batch of predictions 
    test dataset is split up into 5 files
    
    inputs:
        idx - int with a value between 1 to 5 that represents which test ds file is being used for predictions
        
        bucket - GCS bucket variable that contains files with test data, default is video_frame_bucket
        
        test_ds_file_name - str - beginning of file name of files containing test ds, default is face_arrays
        
        ground_file_name - str - beginning of file name of files containing the ground truth of each frame 
    
    returns:
        correct_real - int - the number of real frames correctly predicted
        
        total_real - int - total number of real frames
        
        correct_fake - int - the number of fake frames correctly predicted
        
        total_fake - int - total number of fake frames
        
        prediction_df - DataFrame  with the following columns:
            raw_prediction - float, range of -inf to inf, negative number indicates prediction
            is frame is fake and postive indicates the prediction is frame is real
            the closer to 0 of the value, the less confident the model is regarding the prediction
            
            accurate - Bool - reflects if the model accurately predicted if the frame is real or fake
            
            ground_truth - Bool - reflects if the frame is real or fake

    '''
    #downlaod files:
    ds_file_name = '{}{}.npz'.format(test_ds_file_name, idx)
    ground_file_name = '{}{}.csv'.format(ground_file_name, idx)
    ds_blob = bucket.blob('aaa_frames/' + ds_file_name)
    ds_blob.download_to_filename(ds_file_name)
    ground_blob = bucket.blob('aaa_frames/' + ground_file_name)
    ground_blob.download_to_filename(ground_file_name)
    
    data_file = np.load(ds_file_name)
    data = [data_file[key] for key in data_file]
    ground = pd.read_csv(ground_file_name)
    ground_list = ground['face_labels'].to_list()
    assert(len(ground_list) == len(data)), 'The len of the DS and ground truth do not match'
    
    total_real, total_fake, correct_real, correct_fake = 0, 0, 0, 0
    predictions = []
    ground_truths = []
    accurate_predictions = []
    
    for frame in range(len(data)):
        prediction, raw_prediction = make_single_prediction(data[frame])
        real = ground_list[frame]
        accurate_prediction = (real == prediction)
        if real:
            total_real +=1
            if accurate_prediction:
                correct_real +=1
        else:
            total_fake +=1
            if accurate_prediction: 
                correct_fake +=1
        predictions.append(raw_prediction)
        ground_truths.append(real)
        accurate_predictions.append(accurate_prediction)
        if frame % 1000 == 999:
          print('real frames:')
          print('accurate: {}, total: {}'.format(correct_real, total_real))
          print('fake frames:')
          print('accurate: {}, total: {} '.format(correct_fake, total_fake))
    
    
    preds_dictionary = {
        'raw_prediction':predictions,
        'accurate': accurate_predictions,
        'ground_truth': ground_truths
    }
    prediction_df = pd.DataFrame(preds_dictionary)
        
    return correct_real, total_real, correct_fake, total_fake, prediction_df

# %%
def make_predictions(start, end):
    '''
    function to make predictions on entire dataset
    
    inputs:
        start - int, starting file number in test dataset
        
        end - int, ending file number in test dataset, must be greater than or equal to start
        
    returns:
    correct_real - int - the number of real frames correctly predicted

    total_real - int - total number of real frames

    correct_fake - int - the number of fake frames correctly predicted

    total_fake - int - total number of fake frames

    prediction_df - DataFrame  with the following columns:
        raw_prediction - float, range of -inf to inf, negative number indicates prediction
        is frame is fake and postive indicates the prediction is frame is real
        the closer to 0 of the value, the less confident the model is regarding the prediction

        accurate - Bool - reflects if the model accurately predicted if the frame is real or fake

        ground_truth - Bool - reflects if the frame is real or fake
    '''
    
    assert(start <= end), 'start must be less than or equal to end'
    
    total_real, total_fake, correct_real, correct_fake = 0, 0, 0, 0
    prediction_dfs = []
    for file in np.arange(start, end+1):
        cor_real_batch, real_batch, cor_fake_batch, fake_batch, df_batch = prediction_batch(file)
        total_real += real_batch
        total_fake += fake_batch
        correct_real +=cor_real_batch
        correct_fake += cor_fake_batch
        prediction_dfs.append(df_batch)
    
    prediction_df = pd.concat(prediction_dfs)
    
    return total_real, total_fake, correct_real, correct_fake, prediction_df

# %%
with tf.device('/device:GPU:0'):
    total_real, total_fake, correct_real, correct_fake, prediction_df = make_predictions(1, 5)
# Out:
# real frames:
# accurate: 51, total: 52
# fake frames:
# accurate: 0, total: 948
# real frames:
# accurate: 126, total: 127
# fake frames:
# accurate: 1, total: 1873
# real frames:
# accurate: 205, total: 206
# fake frames:
# accurate: 4, total: 2794
# real frames:
# accurate: 277, total: 281
# fake frames:
# accurate: 42, total: 3719
# real frames:
# accurate: 326, total: 333
# fake frames:
# accurate: 66, total: 4667
# real frames:
# accurate: 364, total: 373
# fake frames:
# accurate: 90, total: 5627
# real frames:
# accurate: 427, total: 443
# fake frames:
# accurate: 154, total: 6557
# real frames:
# accurate: 486, total: 513
# fake frames:
# accurate: 217, total: 7487
# real frames:
# accurate: 541, total: 579
# fake frames:
# accurate: 286, total: 8421
# real frames:
# accurate: 632, total: 674
# fake frames:
# accurate: 337, total: 9326
# real frames:
# accurate: 889, total: 946
# fake frames:
# accurate: 343, total: 10054
# real frames:
# accurate: 967, total: 1024
# fake frames:
# accurate: 347, total: 10976
# real frames:
# accurate: 1074, total: 1131
# fake frames:
# accurate: 348, total: 11869
# real frames:
# accurate: 1334, total: 1400
# fake frames:
# accurate: 351, total: 12600
# real frames:
# accurate: 1375, total: 1442
# fake frames:
# accurate: 370, total: 13558
# real frames:
# accurate: 1441, total: 1512
# fake frames:
# accurate: 395, total: 14488
# real frames:
# accurate: 1505, total: 1581
# fake frames:
# accurate: 416, total: 15419
# real frames:
# accurate: 1669, total: 1761
# fake frames:
# accurate: 438, total: 16239
# real frames:
# accurate: 1728, total: 1842
# fake frames:
# accurate: 468, total: 17158
# real frames:
# accurate: 1790, total: 1906
# fake frames:
# accurate: 469, total: 18094
# real frames:
# accurate: 1830, total: 1946
# fake frames:
# accurate: 473, total: 19054
# real frames:
# accurate: 1884, total: 2000
# fake frames:
# accurate: 476, total: 20000
# real frames:
# accurate: 2014, total: 2132
# fake frames:
# accurate: 479, total: 20868
# real frames:
# accurate: 2395, total: 2514
# fake frames:
# accurate: 479, total: 21486
# real frames:
# accurate: 2562, total: 2688
# fake frames:
# accurate: 496, total: 22312
# real frames:
# accurate: 2609, total: 2736
# fake frames:
# accurate: 531, total: 23264
# real frames:
# accurate: 2678, total: 2808
# fake frames:
# accurate: 539, total: 24192
# real frames:
# accurate: 2750, total: 2883
# fake frames:
# accurate: 555, total: 25117
# real frames:
# accurate: 2797, total: 2931
# fake frames:
# accurate: 572, total: 26069
# real frames:
# accurate: 2857, total: 2994
# fake frames:
# accurate: 587, total: 27006
# real frames:
# accurate: 3012, total: 3153
# fake frames:
# accurate: 595, total: 27847
# real frames:
# accurate: 3372, total: 3547
# fake frames:
# accurate: 632, total: 28453
# real frames:
# accurate: 3475, total: 3651
# fake frames:
# accurate: 637, total: 29349
# real frames:
# accurate: 3546, total: 3722
# fake frames:
# accurate: 637, total: 30278
# real frames:
# accurate: 3613, total: 3789
# fake frames:
# accurate: 637, total: 31211
# real frames:
# accurate: 3688, total: 3864
# fake frames:
# accurate: 639, total: 32136
# real frames:
# accurate: 3892, total: 4068
# fake frames:
# accurate: 639, total: 32932
# real frames:
# accurate: 4180, total: 4361
# fake frames:
# accurate: 648, total: 33639
# real frames:
# accurate: 4257, total: 4439
# fake frames:
# accurate: 678, total: 34561
# real frames:
# accurate: 4335, total: 4525
# fake frames:
# accurate: 707, total: 35475
# real frames:
# accurate: 4546, total: 4736
# fake frames:
# accurate: 707, total: 36264
# real frames:
# accurate: 4781, total: 4994
# fake frames:
# accurate: 708, total: 37006
# real frames:
# accurate: 4849, total: 5062
# fake frames:
# accurate: 713, total: 37938
# real frames:
# accurate: 4965, total: 5182
# fake frames:
# accurate: 714, total: 38818
# real frames:
# accurate: 5174, total: 5408
# fake frames:
# accurate: 766, total: 39592
# real frames:
# accurate: 5368, total: 5615
# fake frames:
# accurate: 804, total: 40385
# real frames:
# accurate: 5415, total: 5667
# fake frames:
# accurate: 854, total: 41333
# real frames:
# accurate: 5446, total: 5701
# fake frames:
# accurate: 894, total: 42299
# real frames:
# accurate: 5485, total: 5744
# fake frames:
# accurate: 936, total: 43256
# real frames:
# accurate: 5538, total: 5804
# fake frames:
# accurate: 999, total: 44196
# real frames:
# accurate: 5566, total: 5837
# fake frames:
# accurate: 1056, total: 45163
# real frames:
# accurate: 5602, total: 5878
# fake frames:
# accurate: 1110, total: 46122
# real frames:
# accurate: 5771, total: 6051
# fake frames:
# accurate: 1140, total: 46949
# real frames:
# accurate: 6081, total: 6363
# fake frames:
# accurate: 1141, total: 47637
# real frames:
# accurate: 6225, total: 6509
# fake frames:
# accurate: 1152, total: 48491
# real frames:
# accurate: 111, total: 114
# fake frames:
# accurate: 8, total: 886
# real frames:
# accurate: 366, total: 371
# fake frames:
# accurate: 9, total: 1629
# real frames:
# accurate: 658, total: 669
# fake frames:
# accurate: 20, total: 2331
# real frames:
# accurate: 698, total: 725
# fake frames:
# accurate: 82, total: 3275
# real frames:
# accurate: 742, total: 781
# fake frames:
# accurate: 146, total: 4219
# real frames:
# accurate: 802, total: 847
# fake frames:
# accurate: 222, total: 5153
# real frames:
# accurate: 1005, total: 1050
# fake frames:
# accurate: 222, total: 5950
# real frames:
# accurate: 1288, total: 1335
# fake frames:
# accurate: 223, total: 6665
# real frames:
# accurate: 1329, total: 1377
# fake frames:
# accurate: 225, total: 7623
# real frames:
# accurate: 1372, total: 1420
# fake frames:
# accurate: 230, total: 8580
# real frames:
# accurate: 1429, total: 1477
# fake frames:
# accurate: 232, total: 9523
# real frames:
# accurate: 1468, total: 1516
# fake frames:
# accurate: 233, total: 10484
# real frames:
# accurate: 1503, total: 1551
# fake frames:
# accurate: 236, total: 11449
# real frames:
# accurate: 1536, total: 1585
# fake frames:
# accurate: 239, total: 12415
# real frames:
# accurate: 1689, total: 1739
# fake frames:
# accurate: 275, total: 13261
# real frames:
# accurate: 1887, total: 1942
# fake frames:
# accurate: 280, total: 14058
# real frames:
# accurate: 2201, total: 2287
# fake frames:
# accurate: 324, total: 14713
# real frames:
# accurate: 2307, total: 2398
# fake frames:
# accurate: 324, total: 15602
# real frames:
# accurate: 2384, total: 2475
# fake frames:
# accurate: 324, total: 16525
# real frames:
# accurate: 2484, total: 2575
# fake frames:
# accurate: 324, total: 17425
# real frames:
# accurate: 2604, total: 2702
# fake frames:
# accurate: 354, total: 18298
# real frames:
# accurate: 2898, total: 2996
# fake frames:
# accurate: 356, total: 19004
# real frames:
# accurate: 3076, total: 3184
# fake frames:
# accurate: 377, total: 19816
# real frames:
# accurate: 3210, total: 3320
# fake frames:
# accurate: 394, total: 20680
# real frames:
# accurate: 3344, total: 3454
# fake frames:
# accurate: 400, total: 21546
# real frames:
# accurate: 3479, total: 3589
# fake frames:
# accurate: 401, total: 22411
# real frames:
# accurate: 3763, total: 3892
# fake frames:
# accurate: 427, total: 23108
# real frames:
# accurate: 3833, total: 3962
# fake frames:
# accurate: 428, total: 24038
# real frames:
# accurate: 3956, total: 4085
# fake frames:
# accurate: 428, total: 24915
# real frames:
# accurate: 4123, total: 4264
# fake frames:
# accurate: 473, total: 25736
# real frames:
# accurate: 4435, total: 4618
# fake frames:
# accurate: 527, total: 26382
# real frames:
# accurate: 4560, total: 4750
# fake frames:
# accurate: 555, total: 27250
# real frames:
# accurate: 4656, total: 4851
# fake frames:
# accurate: 580, total: 28149
# real frames:
# accurate: 4785, total: 4982
# fake frames:
# accurate: 593, total: 29018
# real frames:
# accurate: 4963, total: 5160
# fake frames:
# accurate: 596, total: 29840
# real frames:
# accurate: 5262, total: 5470
# fake frames:
# accurate: 606, total: 30530
# real frames:
# accurate: 5415, total: 5627
# fake frames:
# accurate: 611, total: 31373
# real frames:
# accurate: 5481, total: 5693
# fake frames:
# accurate: 626, total: 32307
# real frames:
# accurate: 5538, total: 5751
# fake frames:
# accurate: 641, total: 33249
# real frames:
# accurate: 5688, total: 5909
# fake frames:
# accurate: 671, total: 34091
# real frames:
# accurate: 5867, total: 6105
# fake frames:
# accurate: 709, total: 34895
# real frames:
# accurate: 6231, total: 6483
# fake frames:
# accurate: 730, total: 35517
# real frames:
# accurate: 6311, total: 6563
# fake frames:
# accurate: 730, total: 36437
# real frames:
# accurate: 6391, total: 6643
# fake frames:
# accurate: 733, total: 37357
# real frames:
# accurate: 6524, total: 6786
# fake frames:
# accurate: 778, total: 38214
# real frames:
# accurate: 6738, total: 7000
# fake frames:
# accurate: 778, total: 39000
# real frames:
# accurate: 6947, total: 7301
# fake frames:
# accurate: 815, total: 39699
# real frames:
# accurate: 7042, total: 7397
# fake frames:
# accurate: 839, total: 40603
# real frames:
# accurate: 7138, total: 7506
# fake frames:
# accurate: 896, total: 41494
# real frames:
# accurate: 7229, total: 7607
# fake frames:
# accurate: 945, total: 42393
# real frames:
# accurate: 7403, total: 7784
# fake frames:
# accurate: 948, total: 43216
# real frames:
# accurate: 7627, total: 8010
# fake frames:
# accurate: 955, total: 43990
# real frames:
# accurate: 237, total: 241
# fake frames:
# accurate: 14, total: 759
# real frames:
# accurate: 305, total: 312
# fake frames:
# accurate: 24, total: 1688
# real frames:
# accurate: 401, total: 410
# fake frames:
# accurate: 27, total: 2590
# real frames:
# accurate: 526, total: 566
# fake frames:
# accurate: 124, total: 3434
# real frames:
# accurate: 735, total: 844
# fake frames:
# accurate: 175, total: 4156
# real frames:
# accurate: 890, total: 1013
# fake frames:
# accurate: 180, total: 4987
# real frames:
# accurate: 1003, total: 1126
# fake frames:
# accurate: 180, total: 5874
# real frames:
# accurate: 1159, total: 1283
# fake frames:
# accurate: 183, total: 6717
# real frames:
# accurate: 1354, total: 1487
# fake frames:
# accurate: 201, total: 7513
# real frames:
# accurate: 1692, total: 1840
# fake frames:
# accurate: 214, total: 8160
# real frames:
# accurate: 1848, total: 2015
# fake frames:
# accurate: 225, total: 8985
# real frames:
# accurate: 1919, total: 2086
# fake frames:
# accurate: 228, total: 9914
# real frames:
# accurate: 2054, total: 2221
# fake frames:
# accurate: 228, total: 10779
# real frames:
# accurate: 2225, total: 2392
# fake frames:
# accurate: 228, total: 11608
# real frames:
# accurate: 2454, total: 2651
# fake frames:
# accurate: 319, total: 12349
# real frames:
# accurate: 2668, total: 2877
# fake frames:
# accurate: 355, total: 13123
# real frames:
# accurate: 2730, total: 2972
# fake frames:
# accurate: 518, total: 14028
# real frames:
# accurate: 2807, total: 3084
# fake frames:
# accurate: 668, total: 14916
# real frames:
# accurate: 2892, total: 3187
# fake frames:
# accurate: 706, total: 15813
# real frames:
# accurate: 3032, total: 3346
# fake frames:
# accurate: 707, total: 16654
# real frames:
# accurate: 3296, total: 3618
# fake frames:
# accurate: 721, total: 17382
# real frames:
# accurate: 3489, total: 3814
# fake frames:
# accurate: 726, total: 18186
# real frames:
# accurate: 3542, total: 3868
# fake frames:
# accurate: 726, total: 19132
# real frames:
# accurate: 3628, total: 3977
# fake frames:
# accurate: 873, total: 20023
# real frames:
# accurate: 3781, total: 4163
# fake frames:
# accurate: 994, total: 20837
# real frames:
# accurate: 3992, total: 4402
# fake frames:
# accurate: 1063, total: 21598
# real frames:
# accurate: 4249, total: 4677
# fake frames:
# accurate: 1103, total: 22323
# real frames:
# accurate: 4370, total: 4798
# fake frames:
# accurate: 1103, total: 23202
# real frames:
# accurate: 4466, total: 4908
# fake frames:
# accurate: 1121, total: 24092
# real frames:
# accurate: 4602, total: 5075
# fake frames:
# accurate: 1177, total: 24925
# real frames:
# accurate: 4814, total: 5294
# fake frames:
# accurate: 1183, total: 25706
# real frames:
# accurate: 5050, total: 5533
# fake frames:
# accurate: 1196, total: 26467
# real frames:
# accurate: 5204, total: 5688
# fake frames:
# accurate: 1196, total: 27312
# real frames:
# accurate: 5296, total: 5780
# fake frames:
# accurate: 1201, total: 28220
# real frames:
# accurate: 5426, total: 5915
# fake frames:
# accurate: 1205, total: 29085
# real frames:
# accurate: 5616, total: 6114
# fake frames:
# accurate: 1228, total: 29886
# real frames:
# accurate: 5920, total: 6443
# fake frames:
# accurate: 1235, total: 30557
# real frames:
# accurate: 6012, total: 6537
# fake frames:
# accurate: 1236, total: 31463
# real frames:
# accurate: 6164, total: 6691
# fake frames:
# accurate: 1246, total: 32309
# real frames:
# accurate: 6445, total: 6975
# fake frames:
# accurate: 1250, total: 33025
# real frames:
# accurate: 6671, total: 7206
# fake frames:
# accurate: 1266, total: 33794
# real frames:
# accurate: 6836, total: 7394
# fake frames:
# accurate: 1298, total: 34606
# real frames:
# accurate: 6889, total: 7447
# fake frames:
# accurate: 1301, total: 35553
# real frames:
# accurate: 7015, total: 7573
# fake frames:
# accurate: 1302, total: 36427
# real frames:
# accurate: 7171, total: 7729
# fake frames:
# accurate: 1304, total: 37271
# real frames:
# accurate: 7447, total: 8005
# fake frames:
# accurate: 1304, total: 37995
# real frames:
# accurate: 7766, total: 8333
# fake frames:
# accurate: 1307, total: 38667
# real frames:
# accurate: 7891, total: 8461
# fake frames:
# accurate: 1323, total: 39539
# real frames:
# accurate: 8010, total: 8580
# fake frames:
# accurate: 1324, total: 40420
# real frames:
# accurate: 8213, total: 8799
# fake frames:
# accurate: 1348, total: 41201
# real frames:
# accurate: 321, total: 347
# fake frames:
# accurate: 16, total: 653
# real frames:
# accurate: 460, total: 486
# fake frames:
# accurate: 21, total: 1514
# real frames:
# accurate: 542, total: 568
# fake frames:
# accurate: 23, total: 2432
# real frames:
# accurate: 728, total: 754
# fake frames:
# accurate: 23, total: 3246
# real frames:
# accurate: 899, total: 952
# fake frames:
# accurate: 116, total: 4048
# real frames:
# accurate: 1079, total: 1148
# fake frames:
# accurate: 178, total: 4852
# real frames:
# accurate: 1328, total: 1407
# fake frames:
# accurate: 196, total: 5593
# real frames:
# accurate: 1526, total: 1607
# fake frames:
# accurate: 197, total: 6393
# real frames:
# accurate: 1638, total: 1725
# fake frames:
# accurate: 219, total: 7275
# real frames:
# accurate: 1795, total: 1884
# fake frames:
# accurate: 230, total: 8116
# real frames:
# accurate: 2014, total: 2108
# fake frames:
# accurate: 235, total: 8892
# real frames:
# accurate: 2183, total: 2314
# fake frames:
# accurate: 267, total: 9686
# real frames:
# accurate: 2277, total: 2409
# fake frames:
# accurate: 267, total: 10591
# real frames:
# accurate: 2408, total: 2541
# fake frames:
# accurate: 271, total: 11459
# real frames:
# accurate: 2590, total: 2757
# fake frames:
# accurate: 292, total: 12243
# real frames:
# accurate: 2808, total: 3035
# fake frames:
# accurate: 422, total: 12965
# real frames:
# accurate: 2938, total: 3181
# fake frames:
# accurate: 502, total: 13819
# real frames:
# accurate: 3039, total: 3303
# fake frames:
# accurate: 592, total: 14697
# real frames:
# accurate: 3144, total: 3412
# fake frames:
# accurate: 623, total: 15588
# real frames:
# accurate: 3281, total: 3550
# fake frames:
# accurate: 624, total: 16450
# real frames:
# accurate: 3458, total: 3727
# fake frames:
# accurate: 624, total: 17273
# real frames:
# accurate: 3687, total: 3972
# fake frames:
# accurate: 656, total: 18028
# real frames:
# accurate: 3834, total: 4135
# fake frames:
# accurate: 678, total: 18865
# real frames:
# accurate: 3937, total: 4238
# fake frames:
# accurate: 683, total: 19762
# real frames:
# accurate: 4103, total: 4404
# fake frames:
# accurate: 684, total: 20596
# real frames:
# accurate: 4265, total: 4567
# fake frames:
# accurate: 685, total: 21433
# real frames:
# accurate: 4406, total: 4709
# fake frames:
# accurate: 687, total: 22291
# real frames:
# accurate: 4672, total: 5004
# fake frames:
# accurate: 690, total: 22996
# real frames:
# accurate: 4760, total: 5092
# fake frames:
# accurate: 690, total: 23908
# real frames:
# accurate: 4812, total: 5144
# fake frames:
# accurate: 696, total: 24856
# real frames:
# accurate: 4913, total: 5273
# fake frames:
# accurate: 750, total: 25727
# real frames:
# accurate: 5181, total: 5554
# fake frames:
# accurate: 814, total: 26446
# real frames:
# accurate: 5392, total: 5779
# fake frames:
# accurate: 835, total: 27221
# real frames:
# accurate: 5495, total: 5897
# fake frames:
# accurate: 856, total: 28103
# real frames:
# accurate: 5582, total: 5984
# fake frames:
# accurate: 856, total: 29016
# real frames:
# accurate: 5731, total: 6133
# fake frames:
# accurate: 856, total: 29867
# real frames:
# accurate: 5937, total: 6340
# fake frames:
# accurate: 857, total: 30660
# real frames:
# accurate: 6282, total: 6685
# fake frames:
# accurate: 875, total: 31315
# real frames:
# accurate: 6392, total: 6809
# fake frames:
# accurate: 886, total: 32191
# real frames:
# accurate: 6496, total: 6929
# fake frames:
# accurate: 901, total: 33071
# real frames:
# accurate: 6661, total: 7109
# fake frames:
# accurate: 956, total: 33891
# real frames:
# accurate: 6823, total: 7283
# fake frames:
# accurate: 963, total: 34717
# real frames:
# accurate: 7146, total: 7606
# fake frames:
# accurate: 963, total: 35394
# real frames:
# accurate: 7336, total: 7797
# fake frames:
# accurate: 969, total: 36203
# real frames:
# accurate: 7441, total: 7909
# fake frames:
# accurate: 980, total: 37091
# real frames:
# accurate: 7555, total: 8023
# fake frames:
# accurate: 981, total: 37977
# real frames:
# accurate: 7653, total: 8121
# fake frames:
# accurate: 981, total: 38879
# real frames:
# accurate: 7788, total: 8301
# fake frames:
# accurate: 1035, total: 39699
# real frames:
# accurate: 8101, total: 8620
# fake frames:
# accurate: 1046, total: 40380
# real frames:
# accurate: 8242, total: 8761
# fake frames:
# accurate: 1046, total: 41239
# real frames:
# accurate: 8329, total: 8866
# fake frames:
# accurate: 1143, total: 42134
# real frames:
# accurate: 112, total: 131
# fake frames:
# accurate: 66, total: 869
# real frames:
# accurate: 342, total: 363
# fake frames:
# accurate: 75, total: 1637
# real frames:
# accurate: 639, total: 686
# fake frames:
# accurate: 113, total: 2314
# real frames:
# accurate: 757, total: 813
# fake frames:
# accurate: 150, total: 3187
# real frames:
# accurate: 866, total: 927
# fake frames:
# accurate: 185, total: 4073
# real frames:
# accurate: 943, total: 1004
# fake frames:
# accurate: 207, total: 4996
# real frames:
# accurate: 1148, total: 1211
# fake frames:
# accurate: 221, total: 5789
# real frames:
# accurate: 1384, total: 1489
# fake frames:
# accurate: 310, total: 6511
# real frames:
# accurate: 1549, total: 1656
# fake frames:
# accurate: 311, total: 7344
# real frames:
# accurate: 1651, total: 1758
# fake frames:
# accurate: 311, total: 8242
# real frames:
# accurate: 1812, total: 1919
# fake frames:
# accurate: 312, total: 9081
# real frames:
# accurate: 1942, total: 2061
# fake frames:
# accurate: 382, total: 9939
# real frames:
# accurate: 2047, total: 2196
# fake frames:
# accurate: 579, total: 10804
# real frames:
# accurate: 2182, total: 2361
# fake frames:
# accurate: 731, total: 11639
# real frames:
# accurate: 2519, total: 2698
# fake frames:
# accurate: 733, total: 12302
# real frames:
# accurate: 2684, total: 2863
# fake frames:
# accurate: 733, total: 13137
# real frames:
# accurate: 2767, total: 2946
# fake frames:
# accurate: 733, total: 14054
# real frames:
# accurate: 2867, total: 3050
# fake frames:
# accurate: 765, total: 14950
# real frames:
# accurate: 2975, total: 3163
# fake frames:
# accurate: 797, total: 15837
# real frames:
# accurate: 3122, total: 3329
# fake frames:
# accurate: 838, total: 16671
# real frames:
# accurate: 3423, total: 3702
# fake frames:
# accurate: 915, total: 17298
# real frames:
# accurate: 3540, total: 3821
# fake frames:
# accurate: 920, total: 18179
# real frames:
# accurate: 3661, total: 3946
# fake frames:
# accurate: 928, total: 19054
# real frames:
# accurate: 3748, total: 4053
# fake frames:
# accurate: 970, total: 19947
# real frames:
# accurate: 3894, total: 4199
# fake frames:
# accurate: 973, total: 20801
# real frames:
# accurate: 4094, total: 4399
# fake frames:
# accurate: 975, total: 21601
# real frames:
# accurate: 4376, total: 4709
# fake frames:
# accurate: 1013, total: 22291
# real frames:
# accurate: 4502, total: 4871
# fake frames:
# accurate: 1080, total: 23129
# real frames:
# accurate: 4600, total: 4994
# fake frames:
# accurate: 1149, total: 24006
# real frames:
# accurate: 4692, total: 5128
# fake frames:
# accurate: 1361, total: 24872
# real frames:
# accurate: 4916, total: 5375
# fake frames:
# accurate: 1435, total: 25625
# real frames:
# accurate: 5169, total: 5633
# fake frames:
# accurate: 1452, total: 26367
# real frames:
# accurate: 5321, total: 5785
# fake frames:
# accurate: 1452, total: 27215
# real frames:
# accurate: 5442, total: 5906
# fake frames:
# accurate: 1452, total: 28094
# real frames:
# accurate: 5580, total: 6046
# fake frames:
# accurate: 1469, total: 28954
# real frames:
# accurate: 5794, total: 6275
# fake frames:
# accurate: 1489, total: 29725
# real frames:
# accurate: 6009, total: 6513
# fake frames:
# accurate: 1516, total: 30487
# real frames:
# accurate: 6106, total: 6610
# fake frames:
# accurate: 1516, total: 31390
# real frames:
# accurate: 6256, total: 6760
# fake frames:
# accurate: 1516, total: 32240
# real frames:
# accurate: 6368, total: 6872
# fake frames:
# accurate: 1516, total: 33128
# real frames:
# accurate: 6626, total: 7137
# fake frames:
# accurate: 1529, total: 33863
# real frames:
# accurate: 6894, total: 7405
# fake frames:
# accurate: 1529, total: 34595
# real frames:
# accurate: 7030, total: 7544
# fake frames:
# accurate: 1535, total: 35456
# real frames:
# accurate: 7157, total: 7672
# fake frames:
# accurate: 1546, total: 36328
# real frames:
# accurate: 7293, total: 7808
# fake frames:
# accurate: 1548, total: 37192
# real frames:
# accurate: 7480, total: 7996
# fake frames:
# accurate: 1548, total: 38004
# real frames:
# accurate: 7715, total: 8233
# fake frames:
# accurate: 1550, total: 38767
# real frames:
# accurate: 7861, total: 8388
# fake frames:
# accurate: 1594, total: 39612
# real frames:
# accurate: 7993, total: 8528
# fake frames:
# accurate: 1650, total: 40472
# real frames:
# accurate: 8119, total: 8654
# fake frames:
# accurate: 1653, total: 41346
# real frames:
# accurate: 8255, total: 8790
# fake frames:
# accurate: 1661, total: 42210
# real frames:
# accurate: 8412, total: 8949
# fake frames:
# accurate: 1664, total: 43051
# real frames:
# accurate: 8600, total: 9138
# fake frames:
# accurate: 1668, total: 43862
# real frames:
# accurate: 8727, total: 9266
# fake frames:
# accurate: 1668, total: 44734

# %%
print('{}/{} real frames predicted correctly, and {}/{} fake frames predicted correctly'.format(correct_real,
                                                                                                total_real,
                                                                                                correct_fake,
                                                                                                total_fake))
# Out:
# 39666/42036 real frames predicted correctly, and 6283/222156 fake frames predicted correctly

# %%
prediction_df.to_csv('predictions1.csv')
