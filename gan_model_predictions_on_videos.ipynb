# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.cloud import storage
from google.oauth2 import service_account
import os

# %%
from google.cloud import storage
try:
    from google.colab import auth
    auth.authenticate_user()
    credentials=None
except ModuleNotFoundError:

    credentials = service_account.Credentials.from_service_account_file( #file location of GCS private key
        '/Users/jeremiahherberg/Downloads/deepfake-research-a6b5e4f02da6.json')

# %%
client = storage.Client(project='deepfake-research', credentials=credentials)
video_frame_bucket_name = 'deepfake-dataset'
#bucket containing test data
video_frame_bucket = client.bucket(video_frame_bucket_name)
model_bucket_name = 'jh-gan-testing'
#bucket containing model
model_bucket = client.bucket(model_bucket_name)

# %%
#download and load model
model_name =  'disc5_epoch280.h5' #'disc5_epoch230.h5' #  200
model_blob = model_bucket.blob(model_name)
model_blob.download_to_filename(model_name)
model = tf.keras.models.load_model(model_name)

""" 
200:
real frames:
accurate: 314, total: 373
fake frames:
accurate: 1941, total: 5627 
"""
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# ' \n200:\nreal frames:\naccurate: 314, total: 373\nfake frames:\naccurate: 1941, total: 5627 \n'

# %%
def make_single_prediction(frame,
                          frame_shape=(225, 146, 3),
                          model_input_shape=(192, 128, 3),
                          model=model):
    '''
    function to make a prediction if a single frame in test dataset is real or not
    
    inputs:
        frame - array with a shape of (frame_shape[0] * frame_shape[1] * frame_shape[2],)
        
        frame_shape - tuple that describes the shape of the image, defaults to (225, 146, 3)
        the last dim must be 3 (RGB)
        
        model_input_shape - tuple that describes the shape of the input that will be passed into model
        defaults to (192, 128, 3), the last dim must be 3 (RGB)
        
        model - tensorflow model that will be used to make prediction, defaults to 'model'
    returns:
        prediction - Bool, True if model predicts frame is real, False if prediction is frame is fake
        raw_prediction - float, range of -inf to inf, negative number indicates prediction is that 
        frame is fake and positive indicates the prediction is the frame is real
        the closer to 0 the raw_prediction, the less confident the model is
    ''' 
    assert(frame_shape[2] == model_input_shape[2] == 3), 'the last dim must equal 3 in the model and frame shapes'
    frame_reshaped = frame.reshape(frame_shape)
    #resize frame to be compatable with model
    frame_resized = tf.image.resize_with_pad(frame_reshaped, model_input_shape[0], model_input_shape[1])
    # (H, W, RGB) -> (1, H, W, RGB)
    frame_expanded = tf.expand_dims(frame_resized, 0)
    #convert values to between -1 and 1 (0 to 255 -> -1 to 1) (this is how the model was trained)
    frame_expanded = (tf.cast(frame_expanded, tf.float32) - 127.5) / 127.5
    #we are only making a single prediction
    raw_prediction = model.predict(frame_expanded)[0][0]
    
    if raw_prediction > 0:
        prediction = True
    else:
        prediction = False
    
    return prediction, raw_prediction

# %%
def prediction_batch(idx,
                    bucket=video_frame_bucket,
                    test_ds_file_name='face_arrays',
                    ground_file_name='labels_and_video_names'):
    '''
    function to make a batch of predictions 
    test dataset is split up into 5 files
    
    inputs:
        idx - int with a value between 1 to 5 that represents which test ds file is being used for predictions
        
        bucket - GCS bucket variable that contains files with test data, default is video_frame_bucket
        
        test_ds_file_name - str - beginning of file name of files containing test ds, default is face_arrays
        
        ground_file_name - str - beginning of file name of files containing the ground truth of each frame 
    
    returns:
        correct_real - int - the number of real frames correctly predicted
        
        total_real - int - total number of real frames
        
        correct_fake - int - the number of fake frames correctly predicted
        
        total_fake - int - total number of fake frames
        
        prediction_df - DataFrame  with the following columns:
            raw_prediction - float, range of -inf to inf, negative number indicates prediction
            is frame is fake and postive indicates the prediction is frame is real
            the closer to 0 of the value, the less confident the model is regarding the prediction
            
            accurate - Bool - reflects if the model accurately predicted if the frame is real or fake
            
            ground_truth - Bool - reflects if the frame is real or fake

    '''
    #downlaod files:
    ds_file_name = '{}{}.npz'.format(test_ds_file_name, idx)
    ground_file_name = '{}{}.csv'.format(ground_file_name, idx)
    ds_blob = bucket.blob('aaa_frames/' + ds_file_name)
    ds_blob.download_to_filename(ds_file_name)
    ground_blob = bucket.blob('aaa_frames/' + ground_file_name)
    ground_blob.download_to_filename(ground_file_name)
    
    data_file = np.load(ds_file_name)
    data = [data_file[key] for key in data_file]
    ground = pd.read_csv(ground_file_name)
    ground_list = ground['face_labels'].to_list()
    assert(len(ground_list) == len(data)), 'The len of the DS and ground truth do not match'
    
    total_real, total_fake, correct_real, correct_fake = 0, 0, 0, 0
    predictions = []
    ground_truths = []
    accurate_predictions = []
    
    for frame in range(len(data)):
        prediction, raw_prediction = make_single_prediction(data[frame])
        real = ground_list[frame]
        accurate_prediction = (real == prediction)
        if real:
            total_real +=1
            if accurate_prediction:
                correct_real +=1
        else:
            total_fake +=1
            if accurate_prediction: 
                correct_fake +=1
        predictions.append(raw_prediction)
        ground_truths.append(real)
        accurate_predictions.append(accurate_prediction)
        if frame % 1000 == 999:
          print('real frames:')
          print('accurate: {}, total: {}'.format(correct_real, total_real))
          print('fake frames:')
          print('accurate: {}, total: {} '.format(correct_fake, total_fake))
    
    
    preds_dictionary = {
        'raw_prediction':predictions,
        'accurate': accurate_predictions,
        'ground_truth': ground_truths
    }
    prediction_df = pd.DataFrame(preds_dictionary)
        
    return correct_real, total_real, correct_fake, total_fake, prediction_df

# %%
def make_predictions(start, end):
    '''
    function to make predictions on entire dataset
    
    inputs:
        start - int, starting file number in test dataset
        
        end - int, ending file number in test dataset, must be greater than or equal to start
        
    returns:
    correct_real - int - the number of real frames correctly predicted

    total_real - int - total number of real frames

    correct_fake - int - the number of fake frames correctly predicted

    total_fake - int - total number of fake frames

    prediction_df - DataFrame  with the following columns:
        raw_prediction - float, range of -inf to inf, negative number indicates prediction
        is frame is fake and postive indicates the prediction is frame is real
        the closer to 0 of the value, the less confident the model is regarding the prediction

        accurate - Bool - reflects if the model accurately predicted if the frame is real or fake

        ground_truth - Bool - reflects if the frame is real or fake
    '''
    
    assert(start <= end), 'start must be less than or equal to end'
    
    total_real, total_fake, correct_real, correct_fake = 0, 0, 0, 0
    prediction_dfs = []
    for file in np.arange(start, end+1):
        cor_real_batch, real_batch, cor_fake_batch, fake_batch, df_batch = prediction_batch(file)
        total_real += real_batch
        total_fake += fake_batch
        correct_real +=cor_real_batch
        correct_fake += cor_fake_batch
        prediction_dfs.append(df_batch)
    
    prediction_df = pd.concat(prediction_dfs)
    
    return total_real, total_fake, correct_real, correct_fake, prediction_df

# %%
with tf.device('/device:GPU:0'):
    total_real, total_fake, correct_real, correct_fake, prediction_df = make_predictions(1, 5)
# Out:
# real frames:
# accurate: 51, total: 52
# fake frames:
# accurate: 61, total: 948
# real frames:
# accurate: 125, total: 127
# fake frames:
# accurate: 108, total: 1873
# real frames:
# accurate: 200, total: 206
# fake frames:
# accurate: 219, total: 2794
# real frames:
# accurate: 271, total: 281
# fake frames:
# accurate: 477, total: 3719
# real frames:
# accurate: 315, total: 333
# fake frames:
# accurate: 734, total: 4667
# real frames:
# accurate: 352, total: 373
# fake frames:
# accurate: 1013, total: 5627
# real frames:
# accurate: 419, total: 443
# fake frames:
# accurate: 1210, total: 6557
# real frames:
# accurate: 478, total: 513
# fake frames:
# accurate: 1402, total: 7487
# real frames:
# accurate: 530, total: 579
# fake frames:
# accurate: 1601, total: 8421
# real frames:
# accurate: 609, total: 674
# fake frames:
# accurate: 1783, total: 9326
# real frames:
# accurate: 867, total: 946
# fake frames:
# accurate: 1817, total: 10054
# real frames:
# accurate: 944, total: 1024
# fake frames:
# accurate: 1830, total: 10976
# real frames:
# accurate: 1049, total: 1131
# fake frames:
# accurate: 1847, total: 11869
# real frames:
# accurate: 1314, total: 1400
# fake frames:
# accurate: 1863, total: 12600
# real frames:
# accurate: 1356, total: 1442
# fake frames:
# accurate: 1884, total: 13558
# real frames:
# accurate: 1424, total: 1512
# fake frames:
# accurate: 1904, total: 14488
# real frames:
# accurate: 1492, total: 1581
# fake frames:
# accurate: 1927, total: 15419
# real frames:
# accurate: 1654, total: 1761
# fake frames:
# accurate: 1954, total: 16239
# real frames:
# accurate: 1704, total: 1842
# fake frames:
# accurate: 2241, total: 17158
# real frames:
# accurate: 1746, total: 1906
# fake frames:
# accurate: 2548, total: 18094
# real frames:
# accurate: 1776, total: 1946
# fake frames:
# accurate: 2884, total: 19054
# real frames:
# accurate: 1816, total: 2000
# fake frames:
# accurate: 3206, total: 20000
# real frames:
# accurate: 1943, total: 2132
# fake frames:
# accurate: 3451, total: 20868
# real frames:
# accurate: 2255, total: 2514
# fake frames:
# accurate: 3563, total: 21486
# real frames:
# accurate: 2424, total: 2688
# fake frames:
# accurate: 3577, total: 22312
# real frames:
# accurate: 2472, total: 2736
# fake frames:
# accurate: 3587, total: 23264
# real frames:
# accurate: 2544, total: 2808
# fake frames:
# accurate: 3603, total: 24192
# real frames:
# accurate: 2619, total: 2883
# fake frames:
# accurate: 3608, total: 25117
# real frames:
# accurate: 2667, total: 2931
# fake frames:
# accurate: 3618, total: 26069
# real frames:
# accurate: 2727, total: 2994
# fake frames:
# accurate: 3636, total: 27006
# real frames:
# accurate: 2874, total: 3153
# fake frames:
# accurate: 3676, total: 27847
# real frames:
# accurate: 3179, total: 3547
# fake frames:
# accurate: 3833, total: 28453
# real frames:
# accurate: 3281, total: 3651
# fake frames:
# accurate: 3841, total: 29349
# real frames:
# accurate: 3352, total: 3722
# fake frames:
# accurate: 3854, total: 30278
# real frames:
# accurate: 3419, total: 3789
# fake frames:
# accurate: 3874, total: 31211
# real frames:
# accurate: 3494, total: 3864
# fake frames:
# accurate: 3887, total: 32136
# real frames:
# accurate: 3698, total: 4068
# fake frames:
# accurate: 3910, total: 32932
# real frames:
# accurate: 3967, total: 4361
# fake frames:
# accurate: 3979, total: 33639
# real frames:
# accurate: 4045, total: 4439
# fake frames:
# accurate: 4053, total: 34561
# real frames:
# accurate: 4126, total: 4525
# fake frames:
# accurate: 4110, total: 35475
# real frames:
# accurate: 4332, total: 4736
# fake frames:
# accurate: 4150, total: 36264
# real frames:
# accurate: 4581, total: 4994
# fake frames:
# accurate: 4213, total: 37006
# real frames:
# accurate: 4644, total: 5062
# fake frames:
# accurate: 4303, total: 37938
# real frames:
# accurate: 4755, total: 5182
# fake frames:
# accurate: 4391, total: 38818
# real frames:
# accurate: 4955, total: 5408
# fake frames:
# accurate: 4479, total: 39592
# real frames:
# accurate: 5119, total: 5615
# fake frames:
# accurate: 4677, total: 40385
# real frames:
# accurate: 5164, total: 5667
# fake frames:
# accurate: 4915, total: 41333
# real frames:
# accurate: 5194, total: 5701
# fake frames:
# accurate: 5142, total: 42299
# real frames:
# accurate: 5231, total: 5744
# fake frames:
# accurate: 5379, total: 43256
# real frames:
# accurate: 5282, total: 5804
# fake frames:
# accurate: 5631, total: 44196
# real frames:
# accurate: 5306, total: 5837
# fake frames:
# accurate: 5833, total: 45163
# real frames:
# accurate: 5341, total: 5878
# fake frames:
# accurate: 6079, total: 46122
# real frames:
# accurate: 5476, total: 6051
# fake frames:
# accurate: 6259, total: 46949
# real frames:
# accurate: 5716, total: 6363
# fake frames:
# accurate: 6453, total: 47637
# real frames:
# accurate: 5856, total: 6509
# fake frames:
# accurate: 6541, total: 48491
# real frames:
# accurate: 111, total: 114
# fake frames:
# accurate: 82, total: 886
# real frames:
# accurate: 365, total: 371
# fake frames:
# accurate: 86, total: 1629
# real frames:
# accurate: 636, total: 669
# fake frames:
# accurate: 147, total: 2331
# real frames:
# accurate: 692, total: 725
# fake frames:
# accurate: 161, total: 3275
# real frames:
# accurate: 746, total: 781
# fake frames:
# accurate: 172, total: 4219
# real frames:
# accurate: 804, total: 847
# fake frames:
# accurate: 198, total: 5153
# real frames:
# accurate: 988, total: 1050
# fake frames:
# accurate: 305, total: 5950
# real frames:
# accurate: 1273, total: 1335
# fake frames:
# accurate: 309, total: 6665
# real frames:
# accurate: 1313, total: 1377
# fake frames:
# accurate: 352, total: 7623
# real frames:
# accurate: 1351, total: 1420
# fake frames:
# accurate: 412, total: 8580
# real frames:
# accurate: 1407, total: 1477
# fake frames:
# accurate: 471, total: 9523
# real frames:
# accurate: 1443, total: 1516
# fake frames:
# accurate: 516, total: 10484
# real frames:
# accurate: 1476, total: 1551
# fake frames:
# accurate: 560, total: 11449
# real frames:
# accurate: 1507, total: 1585
# fake frames:
# accurate: 609, total: 12415
# real frames:
# accurate: 1643, total: 1739
# fake frames:
# accurate: 778, total: 13261
# real frames:
# accurate: 1830, total: 1942
# fake frames:
# accurate: 864, total: 14058
# real frames:
# accurate: 2151, total: 2287
# fake frames:
# accurate: 934, total: 14713
# real frames:
# accurate: 2238, total: 2398
# fake frames:
# accurate: 1123, total: 15602
# real frames:
# accurate: 2301, total: 2475
# fake frames:
# accurate: 1340, total: 16525
# real frames:
# accurate: 2397, total: 2575
# fake frames:
# accurate: 1466, total: 17425
# real frames:
# accurate: 2504, total: 2702
# fake frames:
# accurate: 1610, total: 18298
# real frames:
# accurate: 2790, total: 2996
# fake frames:
# accurate: 1645, total: 19004
# real frames:
# accurate: 2974, total: 3184
# fake frames:
# accurate: 1701, total: 19816
# real frames:
# accurate: 3085, total: 3320
# fake frames:
# accurate: 1783, total: 20680
# real frames:
# accurate: 3195, total: 3454
# fake frames:
# accurate: 1947, total: 21546
# real frames:
# accurate: 3321, total: 3589
# fake frames:
# accurate: 2023, total: 22411
# real frames:
# accurate: 3566, total: 3892
# fake frames:
# accurate: 2170, total: 23108
# real frames:
# accurate: 3635, total: 3962
# fake frames:
# accurate: 2196, total: 24038
# real frames:
# accurate: 3758, total: 4085
# fake frames:
# accurate: 2198, total: 24915
# real frames:
# accurate: 3937, total: 4264
# fake frames:
# accurate: 2263, total: 25736
# real frames:
# accurate: 4247, total: 4618
# fake frames:
# accurate: 2347, total: 26382
# real frames:
# accurate: 4379, total: 4750
# fake frames:
# accurate: 2383, total: 27250
# real frames:
# accurate: 4475, total: 4851
# fake frames:
# accurate: 2433, total: 28149
# real frames:
# accurate: 4592, total: 4982
# fake frames:
# accurate: 2508, total: 29018
# real frames:
# accurate: 4763, total: 5160
# fake frames:
# accurate: 2526, total: 29840
# real frames:
# accurate: 5049, total: 5470
# fake frames:
# accurate: 2600, total: 30530
# real frames:
# accurate: 5175, total: 5627
# fake frames:
# accurate: 2787, total: 31373
# real frames:
# accurate: 5230, total: 5693
# fake frames:
# accurate: 2960, total: 32307
# real frames:
# accurate: 5280, total: 5751
# fake frames:
# accurate: 3163, total: 33249
# real frames:
# accurate: 5417, total: 5909
# fake frames:
# accurate: 3365, total: 34091
# real frames:
# accurate: 5571, total: 6105
# fake frames:
# accurate: 3497, total: 34895
# real frames:
# accurate: 5945, total: 6483
# fake frames:
# accurate: 3602, total: 35517
# real frames:
# accurate: 6025, total: 6563
# fake frames:
# accurate: 3643, total: 36437
# real frames:
# accurate: 6097, total: 6643
# fake frames:
# accurate: 3693, total: 37357
# real frames:
# accurate: 6213, total: 6786
# fake frames:
# accurate: 3958, total: 38214
# real frames:
# accurate: 6419, total: 7000
# fake frames:
# accurate: 4010, total: 39000
# real frames:
# accurate: 6684, total: 7301
# fake frames:
# accurate: 4095, total: 39699
# real frames:
# accurate: 6769, total: 7397
# fake frames:
# accurate: 4191, total: 40603
# real frames:
# accurate: 6876, total: 7506
# fake frames:
# accurate: 4287, total: 41494
# real frames:
# accurate: 6970, total: 7607
# fake frames:
# accurate: 4418, total: 42393
# real frames:
# accurate: 7128, total: 7784
# fake frames:
# accurate: 4498, total: 43216
# real frames:
# accurate: 7350, total: 8010
# fake frames:
# accurate: 4503, total: 43990
# real frames:
# accurate: 236, total: 241
# fake frames:
# accurate: 30, total: 759
# real frames:
# accurate: 306, total: 312
# fake frames:
# accurate: 43, total: 1688
# real frames:
# accurate: 404, total: 410
# fake frames:
# accurate: 49, total: 2590
# real frames:
# accurate: 558, total: 566
# fake frames:
# accurate: 55, total: 3434
# real frames:
# accurate: 826, total: 844
# fake frames:
# accurate: 84, total: 4156
# real frames:
# accurate: 985, total: 1013
# fake frames:
# accurate: 137, total: 4987
# real frames:
# accurate: 1087, total: 1126
# fake frames:
# accurate: 183, total: 5874
# real frames:
# accurate: 1210, total: 1283
# fake frames:
# accurate: 318, total: 6717
# real frames:
# accurate: 1387, total: 1487
# fake frames:
# accurate: 438, total: 7513
# real frames:
# accurate: 1704, total: 1840
# fake frames:
# accurate: 528, total: 8160
# real frames:
# accurate: 1843, total: 2015
# fake frames:
# accurate: 628, total: 8985
# real frames:
# accurate: 1910, total: 2086
# fake frames:
# accurate: 678, total: 9914
# real frames:
# accurate: 2045, total: 2221
# fake frames:
# accurate: 686, total: 10779
# real frames:
# accurate: 2214, total: 2392
# fake frames:
# accurate: 699, total: 11608
# real frames:
# accurate: 2407, total: 2651
# fake frames:
# accurate: 938, total: 12349
# real frames:
# accurate: 2624, total: 2877
# fake frames:
# accurate: 1023, total: 13123
# real frames:
# accurate: 2704, total: 2972
# fake frames:
# accurate: 1185, total: 14028
# real frames:
# accurate: 2799, total: 3084
# fake frames:
# accurate: 1353, total: 14916
# real frames:
# accurate: 2870, total: 3187
# fake frames:
# accurate: 1530, total: 15813
# real frames:
# accurate: 3012, total: 3346
# fake frames:
# accurate: 1634, total: 16654
# real frames:
# accurate: 3263, total: 3618
# fake frames:
# accurate: 1708, total: 17382
# real frames:
# accurate: 3454, total: 3814
# fake frames:
# accurate: 1744, total: 18186
# real frames:
# accurate: 3508, total: 3868
# fake frames:
# accurate: 1745, total: 19132
# real frames:
# accurate: 3563, total: 3977
# fake frames:
# accurate: 2245, total: 20023
# real frames:
# accurate: 3705, total: 4163
# fake frames:
# accurate: 2467, total: 20837
# real frames:
# accurate: 3917, total: 4402
# fake frames:
# accurate: 2556, total: 21598
# real frames:
# accurate: 4148, total: 4677
# fake frames:
# accurate: 2627, total: 22323
# real frames:
# accurate: 4269, total: 4798
# fake frames:
# accurate: 2651, total: 23202
# real frames:
# accurate: 4377, total: 4908
# fake frames:
# accurate: 2672, total: 24092
# real frames:
# accurate: 4542, total: 5075
# fake frames:
# accurate: 2695, total: 24925
# real frames:
# accurate: 4758, total: 5294
# fake frames:
# accurate: 2742, total: 25706
# real frames:
# accurate: 4964, total: 5533
# fake frames:
# accurate: 2792, total: 26467
# real frames:
# accurate: 5110, total: 5688
# fake frames:
# accurate: 2910, total: 27312
# real frames:
# accurate: 5198, total: 5780
# fake frames:
# accurate: 3016, total: 28220
# real frames:
# accurate: 5325, total: 5915
# fake frames:
# accurate: 3110, total: 29085
# real frames:
# accurate: 5516, total: 6114
# fake frames:
# accurate: 3172, total: 29886
# real frames:
# accurate: 5739, total: 6443
# fake frames:
# accurate: 3363, total: 30557
# real frames:
# accurate: 5823, total: 6537
# fake frames:
# accurate: 3548, total: 31463
# real frames:
# accurate: 5962, total: 6691
# fake frames:
# accurate: 3626, total: 32309
# real frames:
# accurate: 6241, total: 6975
# fake frames:
# accurate: 3644, total: 33025
# real frames:
# accurate: 6467, total: 7206
# fake frames:
# accurate: 3673, total: 33794
# real frames:
# accurate: 6650, total: 7394
# fake frames:
# accurate: 3680, total: 34606
# real frames:
# accurate: 6702, total: 7447
# fake frames:
# accurate: 3682, total: 35553
# real frames:
# accurate: 6818, total: 7573
# fake frames:
# accurate: 3736, total: 36427
# real frames:
# accurate: 6952, total: 7729
# fake frames:
# accurate: 3851, total: 37271
# real frames:
# accurate: 7203, total: 8005
# fake frames:
# accurate: 3921, total: 37995
# real frames:
# accurate: 7480, total: 8333
# fake frames:
# accurate: 4048, total: 38667
# real frames:
# accurate: 7605, total: 8461
# fake frames:
# accurate: 4050, total: 39539
# real frames:
# accurate: 7711, total: 8580
# fake frames:
# accurate: 4098, total: 40420
# real frames:
# accurate: 7902, total: 8799
# fake frames:
# accurate: 4202, total: 41201
# real frames:
# accurate: 282, total: 347
# fake frames:
# accurate: 115, total: 653
# real frames:
# accurate: 405, total: 486
# fake frames:
# accurate: 210, total: 1514
# real frames:
# accurate: 487, total: 568
# fake frames:
# accurate: 279, total: 2432
# real frames:
# accurate: 673, total: 754
# fake frames:
# accurate: 291, total: 3246
# real frames:
# accurate: 853, total: 952
# fake frames:
# accurate: 365, total: 4048
# real frames:
# accurate: 1029, total: 1148
# fake frames:
# accurate: 435, total: 4852
# real frames:
# accurate: 1244, total: 1407
# fake frames:
# accurate: 502, total: 5593
# real frames:
# accurate: 1444, total: 1607
# fake frames:
# accurate: 504, total: 6393
# real frames:
# accurate: 1561, total: 1725
# fake frames:
# accurate: 515, total: 7275
# real frames:
# accurate: 1716, total: 1884
# fake frames:
# accurate: 540, total: 8116
# real frames:
# accurate: 1940, total: 2108
# fake frames:
# accurate: 569, total: 8892
# real frames:
# accurate: 2143, total: 2314
# fake frames:
# accurate: 628, total: 9686
# real frames:
# accurate: 2216, total: 2409
# fake frames:
# accurate: 768, total: 10591
# real frames:
# accurate: 2332, total: 2541
# fake frames:
# accurate: 943, total: 11459
# real frames:
# accurate: 2538, total: 2757
# fake frames:
# accurate: 1003, total: 12243
# real frames:
# accurate: 2804, total: 3035
# fake frames:
# accurate: 1067, total: 12965
# real frames:
# accurate: 2914, total: 3181
# fake frames:
# accurate: 1475, total: 13819
# real frames:
# accurate: 2968, total: 3303
# fake frames:
# accurate: 2007, total: 14697
# real frames:
# accurate: 3042, total: 3412
# fake frames:
# accurate: 2344, total: 15588
# real frames:
# accurate: 3158, total: 3550
# fake frames:
# accurate: 2475, total: 16450
# real frames:
# accurate: 3329, total: 3727
# fake frames:
# accurate: 2483, total: 17273
# real frames:
# accurate: 3551, total: 3972
# fake frames:
# accurate: 2538, total: 18028
# real frames:
# accurate: 3692, total: 4135
# fake frames:
# accurate: 2671, total: 18865
# real frames:
# accurate: 3783, total: 4238
# fake frames:
# accurate: 2810, total: 19762
# real frames:
# accurate: 3949, total: 4404
# fake frames:
# accurate: 2823, total: 20596
# real frames:
# accurate: 4099, total: 4567
# fake frames:
# accurate: 2869, total: 21433
# real frames:
# accurate: 4238, total: 4709
# fake frames:
# accurate: 2895, total: 22291
# real frames:
# accurate: 4511, total: 5004
# fake frames:
# accurate: 2970, total: 22996
# real frames:
# accurate: 4599, total: 5092
# fake frames:
# accurate: 2970, total: 23908
# real frames:
# accurate: 4648, total: 5144
# fake frames:
# accurate: 3019, total: 24856
# real frames:
# accurate: 4760, total: 5273
# fake frames:
# accurate: 3154, total: 25727
# real frames:
# accurate: 4954, total: 5554
# fake frames:
# accurate: 3430, total: 26446
# real frames:
# accurate: 5136, total: 5779
# fake frames:
# accurate: 3660, total: 27221
# real frames:
# accurate: 5215, total: 5897
# fake frames:
# accurate: 3958, total: 28103
# real frames:
# accurate: 5302, total: 5984
# fake frames:
# accurate: 3962, total: 29016
# real frames:
# accurate: 5451, total: 6133
# fake frames:
# accurate: 3962, total: 29867
# real frames:
# accurate: 5658, total: 6340
# fake frames:
# accurate: 3962, total: 30660
# real frames:
# accurate: 6001, total: 6685
# fake frames:
# accurate: 3978, total: 31315
# real frames:
# accurate: 6104, total: 6809
# fake frames:
# accurate: 4391, total: 32191
# real frames:
# accurate: 6197, total: 6929
# fake frames:
# accurate: 4787, total: 33071
# real frames:
# accurate: 6351, total: 7109
# fake frames:
# accurate: 4924, total: 33891
# real frames:
# accurate: 6509, total: 7283
# fake frames:
# accurate: 4996, total: 34717
# real frames:
# accurate: 6826, total: 7606
# fake frames:
# accurate: 5029, total: 35394
# real frames:
# accurate: 7013, total: 7797
# fake frames:
# accurate: 5082, total: 36203
# real frames:
# accurate: 7108, total: 7909
# fake frames:
# accurate: 5191, total: 37091
# real frames:
# accurate: 7190, total: 8023
# fake frames:
# accurate: 5540, total: 37977
# real frames:
# accurate: 7284, total: 8121
# fake frames:
# accurate: 5596, total: 38879
# real frames:
# accurate: 7460, total: 8301
# fake frames:
# accurate: 5731, total: 39699
# real frames:
# accurate: 7777, total: 8620
# fake frames:
# accurate: 5771, total: 40380
# real frames:
# accurate: 7917, total: 8761
# fake frames:
# accurate: 5786, total: 41239
# real frames:
# accurate: 7999, total: 8866
# fake frames:
# accurate: 5992, total: 42134
# real frames:
# accurate: 116, total: 131
# fake frames:
# accurate: 191, total: 869
# real frames:
# accurate: 329, total: 363
# fake frames:
# accurate: 278, total: 1637
# real frames:
# accurate: 614, total: 686
# fake frames:
# accurate: 350, total: 2314
# real frames:
# accurate: 734, total: 813
# fake frames:
# accurate: 405, total: 3187
# real frames:
# accurate: 842, total: 927
# fake frames:
# accurate: 434, total: 4073
# real frames:
# accurate: 919, total: 1004
# fake frames:
# accurate: 435, total: 4996
# real frames:
# accurate: 1114, total: 1211
# fake frames:
# accurate: 484, total: 5789
# real frames:
# accurate: 1362, total: 1489
# fake frames:
# accurate: 534, total: 6511
# real frames:
# accurate: 1519, total: 1656
# fake frames:
# accurate: 565, total: 7344
# real frames:
# accurate: 1619, total: 1758
# fake frames:
# accurate: 587, total: 8242
# real frames:
# accurate: 1776, total: 1919
# fake frames:
# accurate: 609, total: 9081
# real frames:
# accurate: 1900, total: 2061
# fake frames:
# accurate: 702, total: 9939
# real frames:
# accurate: 2006, total: 2196
# fake frames:
# accurate: 911, total: 10804
# real frames:
# accurate: 2139, total: 2361
# fake frames:
# accurate: 1065, total: 11639
# real frames:
# accurate: 2468, total: 2698
# fake frames:
# accurate: 1091, total: 12302
# real frames:
# accurate: 2632, total: 2863
# fake frames:
# accurate: 1123, total: 13137
# real frames:
# accurate: 2715, total: 2946
# fake frames:
# accurate: 1124, total: 14054
# real frames:
# accurate: 2813, total: 3050
# fake frames:
# accurate: 1248, total: 14950
# real frames:
# accurate: 2916, total: 3163
# fake frames:
# accurate: 1403, total: 15837
# real frames:
# accurate: 3045, total: 3329
# fake frames:
# accurate: 1509, total: 16671
# real frames:
# accurate: 3395, total: 3702
# fake frames:
# accurate: 1583, total: 17298
# real frames:
# accurate: 3505, total: 3821
# fake frames:
# accurate: 1780, total: 18179
# real frames:
# accurate: 3610, total: 3946
# fake frames:
# accurate: 2073, total: 19054
# real frames:
# accurate: 3690, total: 4053
# fake frames:
# accurate: 2400, total: 19947
# real frames:
# accurate: 3827, total: 4199
# fake frames:
# accurate: 2603, total: 20801
# real frames:
# accurate: 4026, total: 4399
# fake frames:
# accurate: 2634, total: 21601
# real frames:
# accurate: 4272, total: 4709
# fake frames:
# accurate: 2701, total: 22291
# real frames:
# accurate: 4428, total: 4871
# fake frames:
# accurate: 2730, total: 23129
# real frames:
# accurate: 4519, total: 4994
# fake frames:
# accurate: 3064, total: 24006
# real frames:
# accurate: 4618, total: 5128
# fake frames:
# accurate: 3310, total: 24872
# real frames:
# accurate: 4782, total: 5375
# fake frames:
# accurate: 3470, total: 25625
# real frames:
# accurate: 5018, total: 5633
# fake frames:
# accurate: 3623, total: 26367
# real frames:
# accurate: 5121, total: 5785
# fake frames:
# accurate: 3864, total: 27215
# real frames:
# accurate: 5233, total: 5906
# fake frames:
# accurate: 3909, total: 28094
# real frames:
# accurate: 5373, total: 6046
# fake frames:
# accurate: 3921, total: 28954
# real frames:
# accurate: 5600, total: 6275
# fake frames:
# accurate: 3950, total: 29725
# real frames:
# accurate: 5828, total: 6513
# fake frames:
# accurate: 3980, total: 30487
# real frames:
# accurate: 5923, total: 6610
# fake frames:
# accurate: 3990, total: 31390
# real frames:
# accurate: 6059, total: 6760
# fake frames:
# accurate: 4014, total: 32240
# real frames:
# accurate: 6171, total: 6872
# fake frames:
# accurate: 4022, total: 33128
# real frames:
# accurate: 6433, total: 7137
# fake frames:
# accurate: 4038, total: 33863
# real frames:
# accurate: 6682, total: 7405
# fake frames:
# accurate: 4128, total: 34595
# real frames:
# accurate: 6806, total: 7544
# fake frames:
# accurate: 4267, total: 35456
# real frames:
# accurate: 6934, total: 7672
# fake frames:
# accurate: 4269, total: 36328
# real frames:
# accurate: 7067, total: 7808
# fake frames:
# accurate: 4292, total: 37192
# real frames:
# accurate: 7253, total: 7996
# fake frames:
# accurate: 4406, total: 38004
# real frames:
# accurate: 7443, total: 8233
# fake frames:
# accurate: 4692, total: 38767
# real frames:
# accurate: 7596, total: 8388
# fake frames:
# accurate: 4701, total: 39612
# real frames:
# accurate: 7732, total: 8528
# fake frames:
# accurate: 4709, total: 40472
# real frames:
# accurate: 7851, total: 8654
# fake frames:
# accurate: 4743, total: 41346
# real frames:
# accurate: 7984, total: 8790
# fake frames:
# accurate: 4758, total: 42210
# real frames:
# accurate: 8142, total: 8949
# fake frames:
# accurate: 4770, total: 43051
# real frames:
# accurate: 8331, total: 9138
# fake frames:
# accurate: 4782, total: 43862
# real frames:
# accurate: 8449, total: 9266
# fake frames:
# accurate: 4930, total: 44734

# %%
print('{}/{} real frames predicted correctly, and {}/{} fake frames predicted correctly'.format(correct_real,
                                                                                                total_real,
                                                                                                correct_fake,
                                                                                                total_fake))
# Out:
# 38065/42036 real frames predicted correctly, and 26429/222156 fake frames predicted correctly

# %%
prediction_df.to_csv('predictions130.csv')

# %%
blob = model_bucket.blob('predictions130.csv')
blob.upload_from_filename('predictions130.csv')
