# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.cloud import storage
from google.oauth2 import service_account
import os

# %%
from google.cloud import storage
try:
    from google.colab import auth
    auth.authenticate_user()
    credentials=None
except ModuleNotFoundError:

    credentials = service_account.Credentials.from_service_account_file( #file location of GCS private key
        '/Users/jeremiahherberg/Downloads/deepfake-research-a6b5e4f02da6.json')

# %%
client = storage.Client(project='deepfake-research', credentials=credentials)
video_frame_bucket_name = 'deepfake-dataset'
#bucket containing test data
video_frame_bucket = client.bucket(video_frame_bucket_name)
model_bucket_name = 'jh-gan-testing'
#bucket containing model
model_bucket = client.bucket(model_bucket_name)

# %%
#download and load model
model_name = 'disc4_epoch140.h5'
model_blob = model_bucket.blob(model_name)
model_blob.download_to_filename(model_name)
model = tf.keras.models.load_model(model_name)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
def make_single_prediction(frame,
                          frame_shape=(225, 146, 3),
                          model_input_shape=(192, 128, 3),
                          model=model):
    '''
    function to make a prediction if a single frame in test dataset is real or not
    
    inputs:
        frame - array with a shape of (frame_shape[0] * frame_shape[1] * frame_shape[2],)
        
        frame_shape - tuple that describes the shape of the image, defaults to (225, 146, 3)
        the last dim must be 3 (RGB)
        
        model_input_shape - tuple that describes the shape of the input that will be passed into model
        defaults to (192, 128, 3), the last dim must be 3 (RGB)
        
        model - tensorflow model that will be used to make prediction, defaults to 'model'
    returns:
        prediction - Bool, True if model predicts frame is real, False if prediction is frame is fake
        raw_prediction - float, range of -inf to inf, negative number indicates prediction is that 
        frame is fake and positive indicates the prediction is the frame is real
        the closer to 0 the raw_prediction, the less confident the model is
    ''' 
    assert(frame_shape[2] == model_input_shape[2] == 3), 'the last dim must equal 3 in the model and frame shapes'
    frame_reshaped = frame.reshape(frame_shape)
    #resize frame to be compatable with model
    frame_resized = tf.image.resize_with_pad(frame_reshaped, model_input_shape[0], model_input_shape[1])
    # (H, W, RGB) -> (1, H, W, RGB)
    frame_expanded = tf.expand_dims(frame_resized, 0)
    #convert values to between -1 and 1 (0 to 255 -> -1 to 1) (this is how the model was trained)
    frame_expanded = (tf.cast(frame_expanded, tf.float32) - 127.5) / 127.5
    #we are only making a single prediction
    raw_prediction = model.predict(frame_expanded)[0][0]
    
    if raw_prediction > 0:
        prediction = True
    else:
        prediction = False
    
    return prediction, raw_prediction

# %%
def prediction_batch(idx,
                    bucket=video_frame_bucket,
                    test_ds_file_name='face_arrays',
                    ground_file_name='labels_and_video_names'):
    '''
    function to make a batch of predictions 
    test dataset is split up into 5 files
    
    inputs:
        idx - int with a value between 1 to 5 that represents which test ds file is being used for predictions
        
        bucket - GCS bucket variable that contains files with test data, default is video_frame_bucket
        
        test_ds_file_name - str - beginning of file name of files containing test ds, default is face_arrays
        
        ground_file_name - str - beginning of file name of files containing the ground truth of each frame 
    
    returns:
        correct_real - int - the number of real frames correctly predicted
        
        total_real - int - total number of real frames
        
        correct_fake - int - the number of fake frames correctly predicted
        
        total_fake - int - total number of fake frames
        
        prediction_df - DataFrame  with the following columns:
            raw_prediction - float, range of -inf to inf, negative number indicates prediction
            is frame is fake and postive indicates the prediction is frame is real
            the closer to 0 of the value, the less confident the model is regarding the prediction
            
            accurate - Bool - reflects if the model accurately predicted if the frame is real or fake
            
            ground_truth - Bool - reflects if the frame is real or fake

    '''
    #downlaod files:
    ds_file_name = '{}{}.npz'.format(test_ds_file_name, idx)
    ground_file_name = '{}{}.csv'.format(ground_file_name, idx)
    ds_blob = bucket.blob('aaa_frames/' + ds_file_name)
    ds_blob.download_to_filename(ds_file_name)
    ground_blob = bucket.blob('aaa_frames/' + ground_file_name)
    ground_blob.download_to_filename(ground_file_name)
    
    data_file = np.load(ds_file_name)
    data = [data_file[key] for key in data_file]
    ground = pd.read_csv(ground_file_name)
    ground_list = ground['face_labels'].to_list()
    assert(len(ground_list) == len(data)), 'The len of the DS and ground truth do not match'
    
    total_real, total_fake, correct_real, correct_fake = 0, 0, 0, 0
    predictions = []
    ground_truths = []
    accurate_predictions = []
    
    for frame in range(len(data)):
        prediction, raw_prediction = make_single_prediction(data[frame])
        real = ground_list[frame]
        accurate_prediction = (real == prediction)
        if real:
            total_real +=1
            if accurate_prediction:
                correct_real +=1
        else:
            total_fake +=1
            if accurate_prediction: 
                correct_fake +=1
        predictions.append(raw_prediction)
        ground_truths.append(real)
        accurate_predictions.append(accurate_prediction)
        if frame % 1000 == 999:
          print('real frames:')
          print('accurate: {}, total: {}'.format(correct_real, total_real))
          print('fake frames:')
          print('accurate: {}, total: {} '.format(correct_fake, total_fake))
    
    
    preds_dictionary = {
        'raw_prediction':predictions,
        'accurate': accurate_predictions,
        'ground_truth': ground_truths
    }
    prediction_df = pd.DataFrame(preds_dictionary)
        
    return correct_real, total_real, correct_fake, total_fake, prediction_df

# %%
def make_predictions(start, end):
    '''
    function to make predictions on entire dataset
    
    inputs:
        start - int, starting file number in test dataset
        
        end - int, ending file number in test dataset, must be greater than or equal to start
        
    returns:
    correct_real - int - the number of real frames correctly predicted

    total_real - int - total number of real frames

    correct_fake - int - the number of fake frames correctly predicted

    total_fake - int - total number of fake frames

    prediction_df - DataFrame  with the following columns:
        raw_prediction - float, range of -inf to inf, negative number indicates prediction
        is frame is fake and postive indicates the prediction is frame is real
        the closer to 0 of the value, the less confident the model is regarding the prediction

        accurate - Bool - reflects if the model accurately predicted if the frame is real or fake

        ground_truth - Bool - reflects if the frame is real or fake
    '''
    
    assert(start <= end), 'start must be less than or equal to end'
    
    total_real, total_fake, correct_real, correct_fake = 0, 0, 0, 0
    prediction_dfs = []
    for file in np.arange(start, end+1):
        cor_real_batch, real_batch, cor_fake_batch, fake_batch, df_batch = prediction_batch(file)
        total_real += real_batch
        total_fake += fake_batch
        correct_real +=cor_real_batch
        correct_fake += cor_fake_batch
        prediction_dfs.append(df_batch)
    
    prediction_df = pd.concat(prediction_dfs)
    
    return total_real, total_fake, correct_real, correct_fake, prediction_df

# %%
with tf.device('/device:GPU:0'):
    total_real, total_fake, correct_real, correct_fake, prediction_df = make_predictions(1, 5)
# Out:
# real frames:
# accurate: 47, total: 52
# fake frames:
# accurate: 165, total: 948
# real frames:
# accurate: 114, total: 127
# fake frames:
# accurate: 313, total: 1873
# real frames:
# accurate: 179, total: 206
# fake frames:
# accurate: 495, total: 2794
# real frames:
# accurate: 232, total: 281
# fake frames:
# accurate: 791, total: 3719
# real frames:
# accurate: 272, total: 333
# fake frames:
# accurate: 1099, total: 4667
# real frames:
# accurate: 299, total: 373
# fake frames:
# accurate: 1452, total: 5627
# real frames:
# accurate: 353, total: 443
# fake frames:
# accurate: 1672, total: 6557
# real frames:
# accurate: 404, total: 513
# fake frames:
# accurate: 1881, total: 7487
# real frames:
# accurate: 449, total: 579
# fake frames:
# accurate: 2085, total: 8421
# real frames:
# accurate: 510, total: 674
# fake frames:
# accurate: 2317, total: 9326
# real frames:
# accurate: 719, total: 946
# fake frames:
# accurate: 2394, total: 10054
# real frames:
# accurate: 796, total: 1024
# fake frames:
# accurate: 2401, total: 10976
# real frames:
# accurate: 896, total: 1131
# fake frames:
# accurate: 2477, total: 11869
# real frames:
# accurate: 1107, total: 1400
# fake frames:
# accurate: 2569, total: 12600
# real frames:
# accurate: 1148, total: 1442
# fake frames:
# accurate: 2622, total: 13558
# real frames:
# accurate: 1218, total: 1512
# fake frames:
# accurate: 2692, total: 14488
# real frames:
# accurate: 1286, total: 1581
# fake frames:
# accurate: 2757, total: 15419
# real frames:
# accurate: 1430, total: 1761
# fake frames:
# accurate: 2859, total: 16239
# real frames:
# accurate: 1464, total: 1842
# fake frames:
# accurate: 3441, total: 17158
# real frames:
# accurate: 1476, total: 1906
# fake frames:
# accurate: 4057, total: 18094
# real frames:
# accurate: 1490, total: 1946
# fake frames:
# accurate: 4724, total: 19054
# real frames:
# accurate: 1505, total: 2000
# fake frames:
# accurate: 5353, total: 20000
# real frames:
# accurate: 1580, total: 2132
# fake frames:
# accurate: 5854, total: 20868
# real frames:
# accurate: 1750, total: 2514
# fake frames:
# accurate: 6153, total: 21486
# real frames:
# accurate: 1899, total: 2688
# fake frames:
# accurate: 6225, total: 22312
# real frames:
# accurate: 1945, total: 2736
# fake frames:
# accurate: 6264, total: 23264
# real frames:
# accurate: 2015, total: 2808
# fake frames:
# accurate: 6308, total: 24192
# real frames:
# accurate: 2089, total: 2883
# fake frames:
# accurate: 6337, total: 25117
# real frames:
# accurate: 2136, total: 2931
# fake frames:
# accurate: 6371, total: 26069
# real frames:
# accurate: 2198, total: 2994
# fake frames:
# accurate: 6420, total: 27006
# real frames:
# accurate: 2343, total: 3153
# fake frames:
# accurate: 6463, total: 27847
# real frames:
# accurate: 2599, total: 3547
# fake frames:
# accurate: 6605, total: 28453
# real frames:
# accurate: 2688, total: 3651
# fake frames:
# accurate: 6712, total: 29349
# real frames:
# accurate: 2753, total: 3722
# fake frames:
# accurate: 6827, total: 30278
# real frames:
# accurate: 2813, total: 3789
# fake frames:
# accurate: 6922, total: 31211
# real frames:
# accurate: 2887, total: 3864
# fake frames:
# accurate: 7013, total: 32136
# real frames:
# accurate: 3065, total: 4068
# fake frames:
# accurate: 7080, total: 32932
# real frames:
# accurate: 3297, total: 4361
# fake frames:
# accurate: 7313, total: 33639
# real frames:
# accurate: 3369, total: 4439
# fake frames:
# accurate: 7519, total: 34561
# real frames:
# accurate: 3435, total: 4525
# fake frames:
# accurate: 7746, total: 35475
# real frames:
# accurate: 3606, total: 4736
# fake frames:
# accurate: 7945, total: 36264
# real frames:
# accurate: 3799, total: 4994
# fake frames:
# accurate: 8106, total: 37006
# real frames:
# accurate: 3837, total: 5062
# fake frames:
# accurate: 8534, total: 37938
# real frames:
# accurate: 3920, total: 5182
# fake frames:
# accurate: 8897, total: 38818
# real frames:
# accurate: 4036, total: 5408
# fake frames:
# accurate: 9187, total: 39592
# real frames:
# accurate: 4150, total: 5615
# fake frames:
# accurate: 9597, total: 40385
# real frames:
# accurate: 4175, total: 5667
# fake frames:
# accurate: 10173, total: 41333
# real frames:
# accurate: 4197, total: 5701
# fake frames:
# accurate: 10761, total: 42299
# real frames:
# accurate: 4220, total: 5744
# fake frames:
# accurate: 11363, total: 43256
# real frames:
# accurate: 4251, total: 5804
# fake frames:
# accurate: 11947, total: 44196
# real frames:
# accurate: 4261, total: 5837
# fake frames:
# accurate: 12522, total: 45163
# real frames:
# accurate: 4278, total: 5878
# fake frames:
# accurate: 13094, total: 46122
# real frames:
# accurate: 4388, total: 6051
# fake frames:
# accurate: 13442, total: 46949
# real frames:
# accurate: 4555, total: 6363
# fake frames:
# accurate: 13793, total: 47637
# real frames:
# accurate: 4666, total: 6509
# fake frames:
# accurate: 13910, total: 48491
# real frames:
# accurate: 97, total: 114
# fake frames:
# accurate: 173, total: 886
# real frames:
# accurate: 325, total: 371
# fake frames:
# accurate: 256, total: 1629
# real frames:
# accurate: 583, total: 669
# fake frames:
# accurate: 344, total: 2331
# real frames:
# accurate: 636, total: 725
# fake frames:
# accurate: 453, total: 3275
# real frames:
# accurate: 682, total: 781
# fake frames:
# accurate: 580, total: 4219
# real frames:
# accurate: 738, total: 847
# fake frames:
# accurate: 730, total: 5153
# real frames:
# accurate: 860, total: 1050
# fake frames:
# accurate: 1080, total: 5950
# real frames:
# accurate: 1115, total: 1335
# fake frames:
# accurate: 1164, total: 6665
# real frames:
# accurate: 1151, total: 1377
# fake frames:
# accurate: 1234, total: 7623
# real frames:
# accurate: 1189, total: 1420
# fake frames:
# accurate: 1319, total: 8580
# real frames:
# accurate: 1245, total: 1477
# fake frames:
# accurate: 1400, total: 9523
# real frames:
# accurate: 1281, total: 1516
# fake frames:
# accurate: 1476, total: 10484
# real frames:
# accurate: 1313, total: 1551
# fake frames:
# accurate: 1549, total: 11449
# real frames:
# accurate: 1344, total: 1585
# fake frames:
# accurate: 1627, total: 12415
# real frames:
# accurate: 1445, total: 1739
# fake frames:
# accurate: 1918, total: 13261
# real frames:
# accurate: 1597, total: 1942
# fake frames:
# accurate: 2083, total: 14058
# real frames:
# accurate: 1883, total: 2287
# fake frames:
# accurate: 2208, total: 14713
# real frames:
# accurate: 1965, total: 2398
# fake frames:
# accurate: 2473, total: 15602
# real frames:
# accurate: 2019, total: 2475
# fake frames:
# accurate: 2775, total: 16525
# real frames:
# accurate: 2110, total: 2575
# fake frames:
# accurate: 2929, total: 17425
# real frames:
# accurate: 2224, total: 2702
# fake frames:
# accurate: 2977, total: 18298
# real frames:
# accurate: 2491, total: 2996
# fake frames:
# accurate: 3064, total: 19004
# real frames:
# accurate: 2652, total: 3184
# fake frames:
# accurate: 3201, total: 19816
# real frames:
# accurate: 2741, total: 3320
# fake frames:
# accurate: 3462, total: 20680
# real frames:
# accurate: 2810, total: 3454
# fake frames:
# accurate: 3873, total: 21546
# real frames:
# accurate: 2923, total: 3589
# fake frames:
# accurate: 4008, total: 22411
# real frames:
# accurate: 3089, total: 3892
# fake frames:
# accurate: 4323, total: 23108
# real frames:
# accurate: 3128, total: 3962
# fake frames:
# accurate: 4672, total: 24038
# real frames:
# accurate: 3246, total: 4085
# fake frames:
# accurate: 4718, total: 24915
# real frames:
# accurate: 3374, total: 4264
# fake frames:
# accurate: 4966, total: 25736
# real frames:
# accurate: 3606, total: 4618
# fake frames:
# accurate: 5165, total: 26382
# real frames:
# accurate: 3725, total: 4750
# fake frames:
# accurate: 5238, total: 27250
# real frames:
# accurate: 3809, total: 4851
# fake frames:
# accurate: 5367, total: 28149
# real frames:
# accurate: 3916, total: 4982
# fake frames:
# accurate: 5668, total: 29018
# real frames:
# accurate: 4059, total: 5160
# fake frames:
# accurate: 5807, total: 29840
# real frames:
# accurate: 4312, total: 5470
# fake frames:
# accurate: 5959, total: 30530
# real frames:
# accurate: 4434, total: 5627
# fake frames:
# accurate: 6194, total: 31373
# real frames:
# accurate: 4484, total: 5693
# fake frames:
# accurate: 6453, total: 32307
# real frames:
# accurate: 4530, total: 5751
# fake frames:
# accurate: 6725, total: 33249
# real frames:
# accurate: 4646, total: 5909
# fake frames:
# accurate: 6995, total: 34091
# real frames:
# accurate: 4723, total: 6105
# fake frames:
# accurate: 7400, total: 34895
# real frames:
# accurate: 4932, total: 6483
# fake frames:
# accurate: 7720, total: 35517
# real frames:
# accurate: 5006, total: 6563
# fake frames:
# accurate: 7790, total: 36437
# real frames:
# accurate: 5074, total: 6643
# fake frames:
# accurate: 7878, total: 37357
# real frames:
# accurate: 5146, total: 6786
# fake frames:
# accurate: 8308, total: 38214
# real frames:
# accurate: 5344, total: 7000
# fake frames:
# accurate: 8378, total: 39000
# real frames:
# accurate: 5535, total: 7301
# fake frames:
# accurate: 8614, total: 39699
# real frames:
# accurate: 5592, total: 7397
# fake frames:
# accurate: 8909, total: 40603
# real frames:
# accurate: 5664, total: 7506
# fake frames:
# accurate: 9053, total: 41494
# real frames:
# accurate: 5736, total: 7607
# fake frames:
# accurate: 9229, total: 42393
# real frames:
# accurate: 5849, total: 7784
# fake frames:
# accurate: 9515, total: 43216
# real frames:
# accurate: 6026, total: 8010
# fake frames:
# accurate: 9666, total: 43990
# real frames:
# accurate: 186, total: 241
# fake frames:
# accurate: 231, total: 759
# real frames:
# accurate: 230, total: 312
# fake frames:
# accurate: 780, total: 1688
# real frames:
# accurate: 301, total: 410
# fake frames:
# accurate: 1051, total: 2590
# real frames:
# accurate: 423, total: 566
# fake frames:
# accurate: 1192, total: 3434
# real frames:
# accurate: 576, total: 844
# fake frames:
# accurate: 1376, total: 4156
# real frames:
# accurate: 698, total: 1013
# fake frames:
# accurate: 1550, total: 4987
# real frames:
# accurate: 777, total: 1126
# fake frames:
# accurate: 1711, total: 5874
# real frames:
# accurate: 819, total: 1283
# fake frames:
# accurate: 2268, total: 6717
# real frames:
# accurate: 944, total: 1487
# fake frames:
# accurate: 2613, total: 7513
# real frames:
# accurate: 1195, total: 1840
# fake frames:
# accurate: 2765, total: 8160
# real frames:
# accurate: 1315, total: 2015
# fake frames:
# accurate: 2878, total: 8985
# real frames:
# accurate: 1379, total: 2086
# fake frames:
# accurate: 2996, total: 9914
# real frames:
# accurate: 1484, total: 2221
# fake frames:
# accurate: 3111, total: 10779
# real frames:
# accurate: 1645, total: 2392
# fake frames:
# accurate: 3174, total: 11608
# real frames:
# accurate: 1811, total: 2651
# fake frames:
# accurate: 3405, total: 12349
# real frames:
# accurate: 1986, total: 2877
# fake frames:
# accurate: 3485, total: 13123
# real frames:
# accurate: 2051, total: 2972
# fake frames:
# accurate: 3634, total: 14028
# real frames:
# accurate: 2127, total: 3084
# fake frames:
# accurate: 3795, total: 14916
# real frames:
# accurate: 2192, total: 3187
# fake frames:
# accurate: 4015, total: 15813
# real frames:
# accurate: 2293, total: 3346
# fake frames:
# accurate: 4402, total: 16654
# real frames:
# accurate: 2435, total: 3618
# fake frames:
# accurate: 4655, total: 17382
# real frames:
# accurate: 2587, total: 3814
# fake frames:
# accurate: 4805, total: 18186
# real frames:
# accurate: 2640, total: 3868
# fake frames:
# accurate: 4870, total: 19132
# real frames:
# accurate: 2655, total: 3977
# fake frames:
# accurate: 5500, total: 20023
# real frames:
# accurate: 2746, total: 4163
# fake frames:
# accurate: 5878, total: 20837
# real frames:
# accurate: 2906, total: 4402
# fake frames:
# accurate: 6036, total: 21598
# real frames:
# accurate: 3115, total: 4677
# fake frames:
# accurate: 6185, total: 22323
# real frames:
# accurate: 3222, total: 4798
# fake frames:
# accurate: 6274, total: 23202
# real frames:
# accurate: 3299, total: 4908
# fake frames:
# accurate: 6449, total: 24092
# real frames:
# accurate: 3401, total: 5075
# fake frames:
# accurate: 6775, total: 24925
# real frames:
# accurate: 3584, total: 5294
# fake frames:
# accurate: 6879, total: 25706
# real frames:
# accurate: 3764, total: 5533
# fake frames:
# accurate: 7010, total: 26467
# real frames:
# accurate: 3887, total: 5688
# fake frames:
# accurate: 7104, total: 27312
# real frames:
# accurate: 3977, total: 5780
# fake frames:
# accurate: 7147, total: 28220
# real frames:
# accurate: 4104, total: 5915
# fake frames:
# accurate: 7227, total: 29085
# real frames:
# accurate: 4259, total: 6114
# fake frames:
# accurate: 7394, total: 29886
# real frames:
# accurate: 4406, total: 6443
# fake frames:
# accurate: 7635, total: 30557
# real frames:
# accurate: 4481, total: 6537
# fake frames:
# accurate: 7912, total: 31463
# real frames:
# accurate: 4596, total: 6691
# fake frames:
# accurate: 8078, total: 32309
# real frames:
# accurate: 4830, total: 6975
# fake frames:
# accurate: 8180, total: 33025
# real frames:
# accurate: 5045, total: 7206
# fake frames:
# accurate: 8253, total: 33794
# real frames:
# accurate: 5215, total: 7394
# fake frames:
# accurate: 8308, total: 34606
# real frames:
# accurate: 5263, total: 7447
# fake frames:
# accurate: 8334, total: 35553
# real frames:
# accurate: 5376, total: 7573
# fake frames:
# accurate: 8386, total: 36427
# real frames:
# accurate: 5494, total: 7729
# fake frames:
# accurate: 8595, total: 37271
# real frames:
# accurate: 5712, total: 8005
# fake frames:
# accurate: 8767, total: 37995
# real frames:
# accurate: 5916, total: 8333
# fake frames:
# accurate: 9083, total: 38667
# real frames:
# accurate: 6038, total: 8461
# fake frames:
# accurate: 9137, total: 39539
# real frames:
# accurate: 6142, total: 8580
# fake frames:
# accurate: 9251, total: 40420
# real frames:
# accurate: 6256, total: 8799
# fake frames:
# accurate: 9559, total: 41201
# real frames:
# accurate: 235, total: 347
# fake frames:
# accurate: 200, total: 653
# real frames:
# accurate: 289, total: 486
# fake frames:
# accurate: 798, total: 1514
# real frames:
# accurate: 323, total: 568
# fake frames:
# accurate: 1290, total: 2432
# real frames:
# accurate: 438, total: 754
# fake frames:
# accurate: 1486, total: 3246
# real frames:
# accurate: 581, total: 952
# fake frames:
# accurate: 1603, total: 4048
# real frames:
# accurate: 707, total: 1148
# fake frames:
# accurate: 1757, total: 4852
# real frames:
# accurate: 849, total: 1407
# fake frames:
# accurate: 2059, total: 5593
# real frames:
# accurate: 993, total: 1607
# fake frames:
# accurate: 2269, total: 6393
# real frames:
# accurate: 1081, total: 1725
# fake frames:
# accurate: 2474, total: 7275
# real frames:
# accurate: 1170, total: 1884
# fake frames:
# accurate: 2772, total: 8116
# real frames:
# accurate: 1362, total: 2108
# fake frames:
# accurate: 2854, total: 8892
# real frames:
# accurate: 1507, total: 2314
# fake frames:
# accurate: 3079, total: 9686
# real frames:
# accurate: 1559, total: 2409
# fake frames:
# accurate: 3394, total: 10591
# real frames:
# accurate: 1619, total: 2541
# fake frames:
# accurate: 3861, total: 11459
# real frames:
# accurate: 1715, total: 2757
# fake frames:
# accurate: 4277, total: 12243
# real frames:
# accurate: 1936, total: 3035
# fake frames:
# accurate: 4476, total: 12965
# real frames:
# accurate: 2025, total: 3181
# fake frames:
# accurate: 4963, total: 13819
# real frames:
# accurate: 2068, total: 3303
# fake frames:
# accurate: 5562, total: 14697
# real frames:
# accurate: 2105, total: 3412
# fake frames:
# accurate: 6086, total: 15588
# real frames:
# accurate: 2188, total: 3550
# fake frames:
# accurate: 6454, total: 16450
# real frames:
# accurate: 2333, total: 3727
# fake frames:
# accurate: 6597, total: 17273
# real frames:
# accurate: 2508, total: 3972
# fake frames:
# accurate: 6744, total: 18028
# real frames:
# accurate: 2634, total: 4135
# fake frames:
# accurate: 6949, total: 18865
# real frames:
# accurate: 2722, total: 4238
# fake frames:
# accurate: 7114, total: 19762
# real frames:
# accurate: 2887, total: 4404
# fake frames:
# accurate: 7126, total: 20596
# real frames:
# accurate: 2996, total: 4567
# fake frames:
# accurate: 7340, total: 21433
# real frames:
# accurate: 3105, total: 4709
# fake frames:
# accurate: 7430, total: 22291
# real frames:
# accurate: 3342, total: 5004
# fake frames:
# accurate: 7578, total: 22996
# real frames:
# accurate: 3422, total: 5092
# fake frames:
# accurate: 7636, total: 23908
# real frames:
# accurate: 3471, total: 5144
# fake frames:
# accurate: 7710, total: 24856
# real frames:
# accurate: 3537, total: 5273
# fake frames:
# accurate: 7999, total: 25727
# real frames:
# accurate: 3596, total: 5554
# fake frames:
# accurate: 8556, total: 26446
# real frames:
# accurate: 3739, total: 5779
# fake frames:
# accurate: 8918, total: 27221
# real frames:
# accurate: 3795, total: 5897
# fake frames:
# accurate: 9416, total: 28103
# real frames:
# accurate: 3865, total: 5984
# fake frames:
# accurate: 9541, total: 29016
# real frames:
# accurate: 4005, total: 6133
# fake frames:
# accurate: 9609, total: 29867
# real frames:
# accurate: 4198, total: 6340
# fake frames:
# accurate: 9715, total: 30660
# real frames:
# accurate: 4505, total: 6685
# fake frames:
# accurate: 9814, total: 31315
# real frames:
# accurate: 4536, total: 6809
# fake frames:
# accurate: 10545, total: 32191
# real frames:
# accurate: 4563, total: 6929
# fake frames:
# accurate: 11252, total: 33071
# real frames:
# accurate: 4700, total: 7109
# fake frames:
# accurate: 11540, total: 33891
# real frames:
# accurate: 4803, total: 7283
# fake frames:
# accurate: 11865, total: 34717
# real frames:
# accurate: 5084, total: 7606
# fake frames:
# accurate: 11944, total: 35394
# real frames:
# accurate: 5236, total: 7797
# fake frames:
# accurate: 12141, total: 36203
# real frames:
# accurate: 5295, total: 7909
# fake frames:
# accurate: 12433, total: 37091
# real frames:
# accurate: 5339, total: 8023
# fake frames:
# accurate: 12891, total: 37977
# real frames:
# accurate: 5432, total: 8121
# fake frames:
# accurate: 12977, total: 38879
# real frames:
# accurate: 5556, total: 8301
# fake frames:
# accurate: 13445, total: 39699
# real frames:
# accurate: 5823, total: 8620
# fake frames:
# accurate: 13553, total: 40380
# real frames:
# accurate: 5937, total: 8761
# fake frames:
# accurate: 13785, total: 41239
# real frames:
# accurate: 5985, total: 8866
# fake frames:
# accurate: 14280, total: 42134
# real frames:
# accurate: 15, total: 131
# fake frames:
# accurate: 686, total: 869
# real frames:
# accurate: 132, total: 363
# fake frames:
# accurate: 1068, total: 1637
# real frames:
# accurate: 317, total: 686
# fake frames:
# accurate: 1263, total: 2314
# real frames:
# accurate: 398, total: 813
# fake frames:
# accurate: 1548, total: 3187
# real frames:
# accurate: 484, total: 927
# fake frames:
# accurate: 1766, total: 4073
# real frames:
# accurate: 555, total: 1004
# fake frames:
# accurate: 1806, total: 4996
# real frames:
# accurate: 722, total: 1211
# fake frames:
# accurate: 1949, total: 5789
# real frames:
# accurate: 902, total: 1489
# fake frames:
# accurate: 2192, total: 6511
# real frames:
# accurate: 1040, total: 1656
# fake frames:
# accurate: 2272, total: 7344
# real frames:
# accurate: 1130, total: 1758
# fake frames:
# accurate: 2332, total: 8242
# real frames:
# accurate: 1249, total: 1919
# fake frames:
# accurate: 2492, total: 9081
# real frames:
# accurate: 1330, total: 2061
# fake frames:
# accurate: 2841, total: 9939
# real frames:
# accurate: 1404, total: 2196
# fake frames:
# accurate: 3276, total: 10804
# real frames:
# accurate: 1509, total: 2361
# fake frames:
# accurate: 3584, total: 11639
# real frames:
# accurate: 1770, total: 2698
# fake frames:
# accurate: 3690, total: 12302
# real frames:
# accurate: 1914, total: 2863
# fake frames:
# accurate: 3746, total: 13137
# real frames:
# accurate: 1995, total: 2946
# fake frames:
# accurate: 3762, total: 14054
# real frames:
# accurate: 2056, total: 3050
# fake frames:
# accurate: 4106, total: 14950
# real frames:
# accurate: 2102, total: 3163
# fake frames:
# accurate: 4569, total: 15837
# real frames:
# accurate: 2211, total: 3329
# fake frames:
# accurate: 4736, total: 16671
# real frames:
# accurate: 2440, total: 3702
# fake frames:
# accurate: 4955, total: 17298
# real frames:
# accurate: 2523, total: 3821
# fake frames:
# accurate: 5331, total: 18179
# real frames:
# accurate: 2596, total: 3946
# fake frames:
# accurate: 5804, total: 19054
# real frames:
# accurate: 2642, total: 4053
# fake frames:
# accurate: 6349, total: 19947
# real frames:
# accurate: 2735, total: 4199
# fake frames:
# accurate: 6769, total: 20801
# real frames:
# accurate: 2901, total: 4399
# fake frames:
# accurate: 6892, total: 21601
# real frames:
# accurate: 3092, total: 4709
# fake frames:
# accurate: 7107, total: 22291
# real frames:
# accurate: 3210, total: 4871
# fake frames:
# accurate: 7290, total: 23129
# real frames:
# accurate: 3251, total: 4994
# fake frames:
# accurate: 7734, total: 24006
# real frames:
# accurate: 3308, total: 5128
# fake frames:
# accurate: 8221, total: 24872
# real frames:
# accurate: 3412, total: 5375
# fake frames:
# accurate: 8559, total: 25625
# real frames:
# accurate: 3577, total: 5633
# fake frames:
# accurate: 8792, total: 26367
# real frames:
# accurate: 3661, total: 5785
# fake frames:
# accurate: 9103, total: 27215
# real frames:
# accurate: 3766, total: 5906
# fake frames:
# accurate: 9158, total: 28094
# real frames:
# accurate: 3889, total: 6046
# fake frames:
# accurate: 9294, total: 28954
# real frames:
# accurate: 4090, total: 6275
# fake frames:
# accurate: 9427, total: 29725
# real frames:
# accurate: 4305, total: 6513
# fake frames:
# accurate: 9529, total: 30487
# real frames:
# accurate: 4390, total: 6610
# fake frames:
# accurate: 9635, total: 31390
# real frames:
# accurate: 4530, total: 6760
# fake frames:
# accurate: 9772, total: 32240
# real frames:
# accurate: 4637, total: 6872
# fake frames:
# accurate: 9821, total: 33128
# real frames:
# accurate: 4866, total: 7137
# fake frames:
# accurate: 9999, total: 33863
# real frames:
# accurate: 5080, total: 7405
# fake frames:
# accurate: 10149, total: 34595
# real frames:
# accurate: 5179, total: 7544
# fake frames:
# accurate: 10367, total: 35456
# real frames:
# accurate: 5235, total: 7672
# fake frames:
# accurate: 10716, total: 36328
# real frames:
# accurate: 5333, total: 7808
# fake frames:
# accurate: 10900, total: 37192
# real frames:
# accurate: 5464, total: 7996
# fake frames:
# accurate: 11157, total: 38004
# real frames:
# accurate: 5583, total: 8233
# fake frames:
# accurate: 11527, total: 38767
# real frames:
# accurate: 5720, total: 8388
# fake frames:
# accurate: 11578, total: 39612
# real frames:
# accurate: 5849, total: 8528
# fake frames:
# accurate: 11627, total: 40472
# real frames:
# accurate: 5960, total: 8654
# fake frames:
# accurate: 11748, total: 41346
# real frames:
# accurate: 6083, total: 8790
# fake frames:
# accurate: 11892, total: 42210
# real frames:
# accurate: 6237, total: 8949
# fake frames:
# accurate: 11985, total: 43051
# real frames:
# accurate: 6421, total: 9138
# fake frames:
# accurate: 12051, total: 43862
# real frames:
# accurate: 6535, total: 9266
# fake frames:
# accurate: 12249, total: 44734

# %%
print('{}/{} real frames predicted correctly, and {}/{} fake frames predicted correctly'.format(correct_real,
                                                                                                total_real,
                                                                                                correct_fake,
                                                                                                total_fake))
# Out:
# 29797/42036 real frames predicted correctly, and 60113/222156 fake frames predicted correctly

# %%
prediction_df.to_csv('predictions1.csv')

# %%
blob = model_bucket.blob('predictions1.csv')
blob.upload_from_filename('predictions1.csv')
